# %%
# %matplotlib inline 
from matplotlib import pyplot as plt
import numpy as np
import pandas as pd
import pickle
import warnings
import tensorflow as tf
import random
import scipy
import cv2
from tensorflow.keras.utils import Sequence, to_categorical, plot_model
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.utils import class_weight
from tensorflow import keras
from tensorflow.keras import backend as K
from tensorflow.keras.callbacks import TensorBoard
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import Dense, Conv3D, MaxPool3D, Dropout, \
        Flatten, Conv3DTranspose, UpSampling3D, Reshape, Input, concatenate
from tensorflow.keras.regularizers import l1_l2
from google.colab import drive
import time

# %%
warnings.filterwarnings('ignore')
print('Tensorflow version:', tf.__version__)
print(tf.test.gpu_device_name())
print(tf.python.client.device_lib.list_local_devices())
# Out:
# Tensorflow version: 2.2.0
# /device:GPU:0
# [name: "/device:CPU:0"
# device_type: "CPU"
# memory_limit: 268435456
# locality {
# }
# incarnation: 12734722198702928119
# , name: "/device:XLA_CPU:0"
# device_type: "XLA_CPU"
# memory_limit: 17179869184
# locality {
# }
# incarnation: 11744756472646539731
# physical_device_desc: "device: XLA_CPU device"
# , name: "/device:XLA_GPU:0"
# device_type: "XLA_GPU"
# memory_limit: 17179869184
# locality {
# }
# incarnation: 18268549404208786499
# physical_device_desc: "device: XLA_GPU device"
# , name: "/device:GPU:0"
# device_type: "GPU"
# memory_limit: 15701463552
# locality {
#   bus_id: 1
#   links {
#   }
# }
# incarnation: 15042776734609441574
# physical_device_desc: "device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0"
# ]

# %%
# !cat /proc/meminfo

# %%
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# #### Create Train/Validation/Test Subsets

# %%
# %cd /content/drive/My Drive/AD_MRI

# Load list of records
with open('AD_MRI_Master', 'rb') as f:
    master_list = pickle.load(f)
    
master_sheet = pd.DataFrame.from_dict(master_list, orient='index')
display(master_sheet.head())
print(master_sheet.shape)
print()

###
# Split: 80% train, 10% test; of train: 10% validation
# train_list, test_list, train_label, test_label = \
#         train_test_split(master_sheet.subject.values, 
#                          master_sheet.diagnosis.values, 
#                          random_state = 1337, 
#                          test_size=0.1)
        
# train_list, val_list, train_label, val_label = \
#         train_test_split(train_list, 
#                          train_label, 
#                          random_state = 0, 
#                          test_size=0.1)
###

###
# Split: 80% train, 10% validation, 10% test
train_list, test_list, train_label, test_label = \
        train_test_split(master_sheet.subject.values, 
                         master_sheet.diagnosis.values, 
                         random_state = 1337, 
                         test_size=0.2)
        
test_list, val_list, test_label, val_label = \
        train_test_split(test_list, 
                         test_label, 
                         random_state = 0, 
                         test_size=0.5)
###

# Check for ratios of AD to NC to be consistent among sets
AD_count = 0
for lab in train_label:
    if lab == 'AD':
        AD_count +=1
print('train_ratio AD: ', round(AD_count/len(train_label), 3))

AD_count = 0
for lab in val_label:
    if lab == 'AD':
        AD_count +=1
print('val_ratio AD: ', round(AD_count/len(val_label), 3))

AD_count = 0
for lab in test_label:
    if lab == 'AD':
        AD_count +=1
print('test_ratio AD: ', round(AD_count/len(test_label), 3))

print('\nNumber of records\ntrain:', len(train_list), 
      '\nvalidation:', len(val_list), '\ntest:', len(test_list))
# Out:
# /content/drive/.shortcut-targets-by-id/1oU0ruELKPJf457X2y4uyGIpFkyyxaQyv/AD_MRI
#            subject   age diagnosis            scan_ID
# OAS30001  OAS30001  65.0        CN  OAS30001_MR_d0129
# OAS30002  OAS30002  68.0        CN  OAS30002_MR_d0371
# OAS30003  OAS30003  60.0        CN  OAS30003_MR_d0558
# OAS30004  OAS30004  58.0        CN  OAS30004_MR_d1101
# OAS30005  OAS30005  48.0        CN  OAS30005_MR_d0143
# (980, 4)
#
# train_ratio AD:  0.369
# val_ratio AD:  0.357
# test_ratio AD:  0.367
#
# Number of records
# train: 784
# validation: 98
# test: 98

# %% [markdown]
# ### Create Generator

# %%
processed_dir = '/content/drive/My Drive/AD_MRI/PROCESSED/'

# Convert categorical labels
# CN: 0, AD: 1
def labels_to_categorical(labels):
    le = LabelEncoder()
    le.fit(["CN", "AD"])
    num_labels = to_categorical(le.transform(labels), num_classes=2)
    return num_labels


# Custom data generator
class MyDataGenerator(Sequence):
    """Generates data for Keras Sequence based data generator. 
    Suitable for building data generator for training and prediction.
    """
    def __init__(self, list_IDs, processed_dir, augment=False, 
                 to_fit=True, batch_size=32, dim=(120, 160, 120, 1),
                 n_classes=2, shuffle=True, ventricles_only=True, 
                 slice_start=50, slice_end=66, sample_weight=None):
        """Initialization
        :param list_IDs: list of all 'label' PATHS
        :param processed_dir: path to directory of processed images
        :param augment
        :param to_fit: True to return X and y, False to return X only
        :param batch_size: batch size at each iteration
        :param dim: tuple indicating image dimension
        :param n_classes: number of output masks
        :param shuffle: True to shuffle label indexes after every epoch
        :param ventricles_only: reduce dimensions to relevant slice
        """
        self.list_IDs = list_IDs
        self.processed_dir = processed_dir
        self.augment = augment
        self.to_fit = to_fit
        self.batch_size = batch_size
        self.dim = dim
        self.n_classes = n_classes
        self.shuffle = shuffle
        self.ventricles_only = ventricles_only
        self.on_epoch_end()
        self.slice_start = slice_start
        self.slice_end = slice_end
        if self.ventricles_only == False:
            self.slice_size = 120
        else:
            self.slice_size = slice_end - slice_start
        self.sample_weight = sample_weight
        # sample_weight needs to be provided if to_fit=True


    def __len__(self):
        """Denotes the number of batches per epoch
        :return: number of batches per epoch
        """
        return int(np.floor(len(self.list_IDs) / self.batch_size))


    def __getitem__(self, index):
        """Generate one batch of data
        :param index: index of the batch
        :return: X and y when fitting. X only when predicting
        """
        # Generate indexes of the batch
        indexes = self.indexes[index 
                               * self.batch_size:(index + 1) 
                               * self.batch_size]

        # Find list of IDs
        list_IDs_temp = [self.list_IDs[k] for k in indexes]
        
        # Generate data
        X, y = self._load_data(list_IDs_temp)
        X = np.float32(X)
        if self.ventricles_only == True:
          X = X[:, :, :, self.slice_start:self.slice_end, :]
        if self.to_fit:
            y = {'ICAE_classifier': y, 'ICAE_decoder': X}
            return X, y, self.sample_weight
        else:
            return X


    def on_epoch_end(self):
        """Updates indexes after each epoch
        """
        self.indexes = np.arange(len(self.list_IDs))
        if self.shuffle == True:
            np.random.shuffle(self.indexes)


    def _load_data(self, list_IDs_temp):
        """Generates data containing batch_size images
        :param list_IDs_temp: list of label ids to load
        :return: batch of images
        """
        # Initialization
        X = np.empty((self.batch_size, *self.dim))
        y = np.empty((self.batch_size, self.n_classes), dtype=int)
        
        # Generate data
        for i, ID in enumerate(list_IDs_temp):
            
            # start X
            with open(self.processed_dir+ID+'_data','rb') as f:
                data = pickle.load(f)
                
            # third dimension = 120, error using self.slice_size for value 16
            x_reshape= np.reshape(data['image'], (120, 160, 120, 1))
            if self.augment == True:
                x_reshape = scipy.ndimage.rotate(x_reshape, 
                                axes=random.choice([(0, 1), (0, 2), (1, 2)]), 
                                angle=random.choice([360-15, 15]), 
                                reshape=False)
            X[i,] = x_reshape
            
            #start y
            y[i,] = labels_to_categorical([data['diagnosis']])

        return X, y

# %%
# Class imbalance handling
balancing_weights = class_weight.compute_sample_weight('balanced', train_label)
len(balancing_weights)
# Out:
# 784

# %%
mdg = MyDataGenerator(test_list, processed_dir, to_fit=True, augment=True, 
                      sample_weight=balancing_weights)

X, pred, weights = mdg.__getitem__(0)

# %%
X.shape
# Out:
# (32, 120, 160, 16, 1)

# %%
len(weights)
# Out:
# 784

# %% [markdown]
# #### Building CAE Encoder

# %%
dropout = 0.2

input_img = Input(shape=(120, 160, 16, 1), name='Input')
print('\ninput shape:', input_img.shape)

x = Conv3D(10, (3, 3, 3), activation='relu', padding='same', 
           name='Convolution_1')(input_img)
x = MaxPool3D((2, 2, 2), name='MaxPooling_1')(x)
x = Dropout(dropout, name='DropOut_1')(x)

x = Conv3D(10, (3, 3, 3), activation='relu', padding='same', 
           name='Convolution_2')(x)
x = MaxPool3D((2, 2, 2), name='MaxPooling_2')(x)
x = Dropout(dropout, name='DropOut_2')(x)

x = Conv3D(10, (3, 3, 3), activation='relu', padding='same', 
           name='Convolution_3')(x)
x = MaxPool3D((2, 2, 2), name='MaxPooling_3')(x)
x = Dropout(dropout, name='DropOut_3')(x)

encoded = x
encoded_shape = K.int_shape(encoded)
print('output shape:', encoded_shape, '\n')

CAE_encoder = Model(input_img, encoded, name='CAE_encoder')
CAE_encoder.summary()
# Out:
# input shape: (None, 120, 160, 16, 1)
# output shape: (None, 15, 20, 2, 10)
#
# Model: "CAE_encoder"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# Input (InputLayer)           [(None, 120, 160, 16, 1)] 0
# _________________________________________________________________
# Convolution_1 (Conv3D)       (None, 120, 160, 16, 10)  280
# _________________________________________________________________
# MaxPooling_1 (MaxPooling3D)  (None, 60, 80, 8, 10)     0
# _________________________________________________________________
# DropOut_1 (Dropout)          (None, 60, 80, 8, 10)     0
# _________________________________________________________________
# Convolution_2 (Conv3D)       (None, 60, 80, 8, 10)     2710
# _________________________________________________________________
# MaxPooling_2 (MaxPooling3D)  (None, 30, 40, 4, 10)     0
# _________________________________________________________________
# DropOut_2 (Dropout)          (None, 30, 40, 4, 10)     0
# _________________________________________________________________
# Convolution_3 (Conv3D)       (None, 30, 40, 4, 10)     2710
# _________________________________________________________________
# MaxPooling_3 (MaxPooling3D)  (None, 15, 20, 2, 10)     0
# _________________________________________________________________
# DropOut_3 (Dropout)          (None, 15, 20, 2, 10)     0
# =================================================================
# Total params: 5,700
# Trainable params: 5,700
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# #### Building CAE Decoder

# %%
encoded_shape
# Out:
# (None, 15, 20, 2, 10)

# %%
encoded_input = Input(shape=(encoded_shape[1],encoded_shape[2], 
                             encoded_shape[3], encoded_shape[4],), 
                      name='Encoded')

print('\ninput shape:', encoded_input.shape)
x = encoded_input

x = Conv3DTranspose(10, (3, 3, 3), activation='relu', padding='same', 
                    name='Convolution_3')(x)
x = UpSampling3D((2, 2, 2), name='UpSampling_3')(x)
x = Dropout(dropout, name='DropOut_3')(x)

x = Conv3DTranspose(10, (3, 3, 3), activation='relu', padding='same', 
                    name='Convolution_2')(x)
x = UpSampling3D((2, 2, 2), name='UpSampling_2')(x)
x = Dropout(dropout, name='DropOut_2')(x)

x = Conv3DTranspose(10, (3, 3, 3), activation='relu', padding='same', 
                    name='Convolution_1')(x)
x = UpSampling3D((2, 2, 2), name='UpSampling_1')(x)
x = Dropout(dropout, name='DropOut_1')(x)

decoded = Conv3DTranspose(1, (3, 3, 3), activation='sigmoid', padding='same', 
                          name='Output')(x)

print('output shape:', K.int_shape(decoded), '\n')

CAE_decoder = Model(encoded_input, decoded, name='CAE_decoder')
CAE_decoder.summary()
# Out:
# input shape: (None, 15, 20, 2, 10)
# output shape: (None, 120, 160, 16, 1)
#
# Model: "CAE_decoder"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# Encoded (InputLayer)         [(None, 15, 20, 2, 10)]   0
# _________________________________________________________________
# Convolution_3 (Conv3DTranspo (None, 15, 20, 2, 10)     2710
# _________________________________________________________________
# UpSampling_3 (UpSampling3D)  (None, 30, 40, 4, 10)     0
# _________________________________________________________________
# DropOut_3 (Dropout)          (None, 30, 40, 4, 10)     0
# _________________________________________________________________
# Convolution_2 (Conv3DTranspo (None, 30, 40, 4, 10)     2710
# _________________________________________________________________
# UpSampling_2 (UpSampling3D)  (None, 60, 80, 8, 10)     0
# _________________________________________________________________
# DropOut_2 (Dropout)          (None, 60, 80, 8, 10)     0
# _________________________________________________________________
# Convolution_1 (Conv3DTranspo (None, 60, 80, 8, 10)     2710
# _________________________________________________________________
# UpSampling_1 (UpSampling3D)  (None, 120, 160, 16, 10)  0
# _________________________________________________________________
# DropOut_1 (Dropout)          (None, 120, 160, 16, 10)  0
# _________________________________________________________________
# Output (Conv3DTranspose)     (None, 120, 160, 16, 1)   271
# =================================================================
# Total params: 8,401
# Trainable params: 8,401
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# #### Building CAE Autoencoder

# %%
CAE_autoencoder = Model(input_img, CAE_decoder(CAE_encoder(input_img)), 
                        name='CAE_autoencoder')
CAE_autoencoder.summary()
# Out:
# Model: "CAE_autoencoder"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# Input (InputLayer)           [(None, 120, 160, 16, 1)] 0
# _________________________________________________________________
# CAE_encoder (Model)          (None, 15, 20, 2, 10)     5700
# _________________________________________________________________
# CAE_decoder (Model)          (None, 120, 160, 16, 1)   8401
# =================================================================
# Total params: 14,101
# Trainable params: 14,101
# Non-trainable params: 0
# _________________________________________________________________

# %%
CAE_autoencoder.compile(optimizer='adam', loss='binary_crossentropy')

# %% [markdown]
# ### ICAE Inception Model

# %% [markdown]
# #### Building ICAE Encoder

# %%
def inception_module(input, filter_operation):
    """
    filter_operation is a list of inception operations for:
        1x1x1 kernel, 
        1x1x1 then 3x3x3 kernels, 
        1x1x1 then 3x3x3 then 3x3x3 kernels, 
        and 3x3x3 maxpooling then 1x1x1 kernels, 
            respectively.
    """
    
    # According to Nature paper (Oh et. al.), l1 and l2 values of 10e-4 
    # performed the best from experimentation with 0.01, 0.001, 0.0001, 0.00001 
    # values.
    l1_value = 10e-3 #10e-4
    l2_value = 10e-3 #10e-4

    # Branch A
    branch_1x1x1 = Conv3D(filter_operation[0], kernel_size=(1, 1, 1), 
                          activation='relu', padding='same', 
                          kernel_regularizer=l1_l2(l1_value, l2_value), 
                          name='Branch_A_1x1x1')(input)

    # Branch B
    branch_3x3x3_initial = Conv3D(filter_operation[1], kernel_size=(1, 1, 1), 
                                  activation='relu', padding='same', 
                                  kernel_regularizer=l1_l2(l1_value, l2_value), 
                                  name='Branch_B_1x1x1')(input)
    branch_3x3x3 = Conv3D(filter_operation[1], kernel_size=(3, 3, 3), 
                          activation='relu', padding='same', 
                          kernel_regularizer=l1_l2(l1_value, l2_value), 
                          name='Branch_B_3x3x3')(branch_3x3x3_initial)

    # Branch C
    branch_double_3x3x3_initial = Conv3D(filter_operation[2], 
                                         kernel_size=(1, 1, 1), 
                                         activation='relu', padding='same', 
                                         kernel_regularizer=l1_l2(l1_value, 
                                                                  l2_value), 
                                         name='Branch_C_1x1x1')(input)
    branch_double_3x3x3_middle = Conv3D(filter_operation[2], 
                                        kernel_size=(3, 3, 3), 
                                        activation='relu', padding='same', 
                                        kernel_regularizer=l1_l2(l1_value, 
                                                                 l2_value), 
                                        name='Branch_C_1st_3x3x3')\
                                        (branch_double_3x3x3_initial)
    branch_double_3x3x3 = Conv3D(filter_operation[2], kernel_size=(3, 3, 3), 
                                 activation='relu', padding='same', 
                                 kernel_regularizer=l1_l2(l1_value, l2_value), 
                                 name='Branch_C_2nd_3x3x3')\
                                 (branch_double_3x3x3_middle)

    # Branch D
    branch_maxpool_3x3x3_initial = MaxPool3D(pool_size=(3, 3, 3), 
                                             strides=(1, 1, 1), padding='same', 
                                             name='Branch_D_3x3x3_maxpool')\
                                             (input)
    branch_maxpool_3x3x3 = Conv3D(filter_operation[3], kernel_size=(1, 1, 1), 
                                  activation='relu', padding='same', 
                                  kernel_regularizer=l1_l2(l1_value, l2_value), 
                                  name='Branch_D_1x1x1')\
                                  (branch_maxpool_3x3x3_initial)
    
    # Merge branches
    modules = [branch_1x1x1, branch_3x3x3, branch_double_3x3x3, 
               branch_maxpool_3x3x3]
    merged_module = concatenate(modules, name='Inception_Merged')
    
    return merged_module

# %%
filter_operations = [10, 10, 10, 10]
dropout = 0.2

input_img = Input(shape= (120, 160, 16, 1), name='Input')
print('\ninput shape:', input_img.shape)

x = Conv3D(10, (3, 3, 3), activation='relu', padding='same', 
           name='Convolution_1')(input_img)
x = MaxPool3D((2, 2, 2), name='MaxPooling_1')(x)
x = Dropout(dropout, name='DropOut_1')(x)

x = Conv3D(10, (3, 3, 3), activation='relu', padding='same', 
           name='Convolution_2')(x)
x = MaxPool3D((2, 2, 2), name='MaxPooling_2')(x)
x = Dropout(dropout, name='DropOut_2')(x)

x = inception_module(x, filter_operations)
x = MaxPool3D((2, 2, 2), name='Inception_MaxPooling')(x)
x = Dropout(dropout, name='DropOut_3')(x)

encoded = x
encoded_shape = K.int_shape(encoded)
print('output shape:', encoded_shape, '\n')

ICAE_encoder = Model(input_img, encoded, name='ICAE_encoder')
ICAE_encoder.summary(positions=[.35, .64, .71, 1.]) 
# `positions` adjusts print settings to minimize truncation
# Out:
# input shape: (None, 120, 160, 16, 1)
# output shape: (None, 15, 20, 2, 40)
#
# Model: "ICAE_encoder"
# __________________________________________________________________________________________________
# Layer (type)                      Output Shape                Param  Connected to
# ==================================================================================================
# Input (InputLayer)                [(None, 120, 160, 16, 1)]   0
# __________________________________________________________________________________________________
# Convolution_1 (Conv3D)            (None, 120, 160, 16, 10)    280    Input[0][0]
# __________________________________________________________________________________________________
# MaxPooling_1 (MaxPooling3D)       (None, 60, 80, 8, 10)       0      Convolution_1[0][0]
# __________________________________________________________________________________________________
# DropOut_1 (Dropout)               (None, 60, 80, 8, 10)       0      MaxPooling_1[0][0]
# __________________________________________________________________________________________________
# Convolution_2 (Conv3D)            (None, 60, 80, 8, 10)       2710   DropOut_1[0][0]
# __________________________________________________________________________________________________
# MaxPooling_2 (MaxPooling3D)       (None, 30, 40, 4, 10)       0      Convolution_2[0][0]
# __________________________________________________________________________________________________
# DropOut_2 (Dropout)               (None, 30, 40, 4, 10)       0      MaxPooling_2[0][0]
# __________________________________________________________________________________________________
# Branch_C_1x1x1 (Conv3D)           (None, 30, 40, 4, 10)       110    DropOut_2[0][0]
# __________________________________________________________________________________________________
# Branch_B_1x1x1 (Conv3D)           (None, 30, 40, 4, 10)       110    DropOut_2[0][0]
# __________________________________________________________________________________________________
# Branch_C_1st_3x3x3 (Conv3D)       (None, 30, 40, 4, 10)       2710   Branch_C_1x1x1[0][0]
# __________________________________________________________________________________________________
# Branch_D_3x3x3_maxpool (MaxPoolin (None, 30, 40, 4, 10)       0      DropOut_2[0][0]
# __________________________________________________________________________________________________
# Branch_A_1x1x1 (Conv3D)           (None, 30, 40, 4, 10)       110    DropOut_2[0][0]
# __________________________________________________________________________________________________
# Branch_B_3x3x3 (Conv3D)           (None, 30, 40, 4, 10)       2710   Branch_B_1x1x1[0][0]
# __________________________________________________________________________________________________
# Branch_C_2nd_3x3x3 (Conv3D)       (None, 30, 40, 4, 10)       2710   Branch_C_1st_3x3x3[0][0]
# __________________________________________________________________________________________________
# Branch_D_1x1x1 (Conv3D)           (None, 30, 40, 4, 10)       110    Branch_D_3x3x3_maxpool[0][0]
# __________________________________________________________________________________________________
# Inception_Merged (Concatenate)    (None, 30, 40, 4, 40)       0      Branch_A_1x1x1[0][0]
#                                                                      Branch_B_3x3x3[0][0]
#                                                                      Branch_C_2nd_3x3x3[0][0]
#                                                                      Branch_D_1x1x1[0][0]
# __________________________________________________________________________________________________
# Inception_MaxPooling (MaxPooling3 (None, 15, 20, 2, 40)       0      Inception_Merged[0][0]
# __________________________________________________________________________________________________
# DropOut_3 (Dropout)               (None, 15, 20, 2, 40)       0      Inception_MaxPooling[0][0]
# ==================================================================================================
# Total params: 11,560
# Trainable params: 11,560
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %% [markdown]
# #### Building ICAE Decoder

# %%
encoded_input= Input(shape=(encoded_shape[1],encoded_shape[2], 
                            encoded_shape[3], encoded_shape[4],), 
                     name='Encoded')
print('\ninput shape:', encoded_input.shape)

combined_dim = sum(filter_operations) 
# `filter_operations` taken from ICAE encoder

x = encoded_input

x = inception_module(x, filter_operations)
x = UpSampling3D((2, 2, 2), name='Inception_Upsampling')(x)
x = Dropout(dropout, name='DropOut_3')(x)

x = Conv3DTranspose(10, (3, 3, 3), activation='relu', padding='same', 
                    name='Convolution_2')(x)
x = UpSampling3D((2, 2, 2), name='Upsampling_2')(x)
x = Dropout(dropout, name='DropOut_2')(x)

x = Conv3DTranspose(10, (3, 3, 3), activation='relu', padding='same', 
                    name='Convolution_1')(x)
x = UpSampling3D((2, 2, 2), name='Upsampling_1')(x)
x = Dropout(dropout, name='DropOut_1')(x)

decoded = Conv3DTranspose(1, (3, 3, 3), activation='sigmoid', padding='same', 
                          name='Output')(x)

print('output shape:', K.int_shape(decoded), '\n')

ICAE_decoder = Model(encoded_input, decoded, name='ICAE_decoder')
ICAE_decoder.summary(positions=[.35, .64, .71, 1.])
# Out:
# input shape: (None, 15, 20, 2, 40)
# output shape: (None, 120, 160, 16, 1)
#
# Model: "ICAE_decoder"
# __________________________________________________________________________________________________
# Layer (type)                      Output Shape                Param  Connected to
# ==================================================================================================
# Encoded (InputLayer)              [(None, 15, 20, 2, 40)]     0
# __________________________________________________________________________________________________
# Branch_C_1x1x1 (Conv3D)           (None, 15, 20, 2, 10)       410    Encoded[0][0]
# __________________________________________________________________________________________________
# Branch_B_1x1x1 (Conv3D)           (None, 15, 20, 2, 10)       410    Encoded[0][0]
# __________________________________________________________________________________________________
# Branch_C_1st_3x3x3 (Conv3D)       (None, 15, 20, 2, 10)       2710   Branch_C_1x1x1[0][0]
# __________________________________________________________________________________________________
# Branch_D_3x3x3_maxpool (MaxPoolin (None, 15, 20, 2, 40)       0      Encoded[0][0]
# __________________________________________________________________________________________________
# Branch_A_1x1x1 (Conv3D)           (None, 15, 20, 2, 10)       410    Encoded[0][0]
# __________________________________________________________________________________________________
# Branch_B_3x3x3 (Conv3D)           (None, 15, 20, 2, 10)       2710   Branch_B_1x1x1[0][0]
# __________________________________________________________________________________________________
# Branch_C_2nd_3x3x3 (Conv3D)       (None, 15, 20, 2, 10)       2710   Branch_C_1st_3x3x3[0][0]
# __________________________________________________________________________________________________
# Branch_D_1x1x1 (Conv3D)           (None, 15, 20, 2, 10)       410    Branch_D_3x3x3_maxpool[0][0]
# __________________________________________________________________________________________________
# Inception_Merged (Concatenate)    (None, 15, 20, 2, 40)       0      Branch_A_1x1x1[0][0]
#                                                                      Branch_B_3x3x3[0][0]
#                                                                      Branch_C_2nd_3x3x3[0][0]
#                                                                      Branch_D_1x1x1[0][0]
# __________________________________________________________________________________________________
# Inception_Upsampling (UpSampling3 (None, 30, 40, 4, 40)       0      Inception_Merged[0][0]
# __________________________________________________________________________________________________
# DropOut_3 (Dropout)               (None, 30, 40, 4, 40)       0      Inception_Upsampling[0][0]
# __________________________________________________________________________________________________
# Convolution_2 (Conv3DTranspose)   (None, 30, 40, 4, 10)       10810  DropOut_3[0][0]
# __________________________________________________________________________________________________
# Upsampling_2 (UpSampling3D)       (None, 60, 80, 8, 10)       0      Convolution_2[0][0]
# __________________________________________________________________________________________________
# DropOut_2 (Dropout)               (None, 60, 80, 8, 10)       0      Upsampling_2[0][0]
# __________________________________________________________________________________________________
# Convolution_1 (Conv3DTranspose)   (None, 60, 80, 8, 10)       2710   DropOut_2[0][0]
# __________________________________________________________________________________________________
# Upsampling_1 (UpSampling3D)       (None, 120, 160, 16, 10)    0      Convolution_1[0][0]
# __________________________________________________________________________________________________
# DropOut_1 (Dropout)               (None, 120, 160, 16, 10)    0      Upsampling_1[0][0]
# __________________________________________________________________________________________________
# Output (Conv3DTranspose)          (None, 120, 160, 16, 1)     271    DropOut_1[0][0]
# ==================================================================================================
# Total params: 23,561
# Trainable params: 23,561
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %% [markdown]
# #### Building ICAE Classifier

# %%
# ICAE Classifier

encoded_input = Input(shape=(encoded_shape[1], encoded_shape[2], 
                             encoded_shape[3], encoded_shape[4],), 
                      name='Encoded')

y = encoded_input

y = Conv3D(10, (1, 1, 1), padding='same', name='Linear')(y)
y = Flatten(name='Flatten')(y)
y = Dense(128, activation='selu', name='SELU_1')(y) #32
y = Dense(64, activation='selu', name='SELU_2')(y) #16
y = Dense(2, activation='softmax', name='Prediction')(y)

ICAE_pred = y

ICAE_classifier = Model(encoded_input, ICAE_pred, name='ICAE_classifier')
ICAE_classifier.summary()
# Out:
# Model: "ICAE_classifier"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# Encoded (InputLayer)         [(None, 15, 20, 2, 40)]   0
# _________________________________________________________________
# Linear (Conv3D)              (None, 15, 20, 2, 10)     410
# _________________________________________________________________
# Flatten (Flatten)            (None, 6000)              0
# _________________________________________________________________
# SELU_1 (Dense)               (None, 128)               768128
# _________________________________________________________________
# SELU_2 (Dense)               (None, 64)                8256
# _________________________________________________________________
# Prediction (Dense)           (None, 2)                 130
# =================================================================
# Total params: 776,924
# Trainable params: 776,924
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ####  Building Autoencoder

# %%
ICAE_autoencoder = Model(inputs=input_img, 
                         outputs=[ICAE_decoder(ICAE_encoder(input_img)), 
                                  ICAE_classifier(ICAE_encoder(input_img))],
                   name='ICAE_autoencoder')
ICAE_autoencoder.summary(positions=[.35, .64, .71, 1.])
# Out:
# Model: "ICAE_autoencoder"
# __________________________________________________________________________________________________
# Layer (type)                      Output Shape                Param  Connected to
# ==================================================================================================
# Input (InputLayer)                [(None, 120, 160, 16, 1)]   0
# __________________________________________________________________________________________________
# ICAE_encoder (Model)              (None, 15, 20, 2, 40)       11560  Input[0][0]
#                                                                      Input[0][0]
# __________________________________________________________________________________________________
# ICAE_decoder (Model)              (None, 120, 160, 16, 1)     23561  ICAE_encoder[1][0]
# __________________________________________________________________________________________________
# ICAE_classifier (Model)           (None, 2)                   776924 ICAE_encoder[2][0]
# ==================================================================================================
# Total params: 812,045
# Trainable params: 812,045
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %% [markdown]
# #### Plot Models

# %%
plot_model(ICAE_encoder, to_file='outputs_AC/ICAE_encoder_noaug.png', show_shapes=True, show_layer_names=False)

# %%
plot_model(ICAE_classifier, to_file='outputs_AC/ICAE_classifier_noaug.png', show_shapes=True, show_layer_names=True)

# %%
plot_model(ICAE_decoder, to_file='outputs_AC/ICAE_decoder_noaug.png', show_shapes=True, show_layer_names=True)

# %% [markdown]
# #### Training Setup

# %%
losses = {'ICAE_decoder':'mse', 'ICAE_classifier':'categorical_crossentropy'}
metrics = {'ICAE_decoder':'mae', 'ICAE_classifier':[\
                            tf.keras.metrics.BinaryAccuracy(name='accuracy'),
                            tf.keras.metrics.Precision(name='precision'), 
                            tf.keras.metrics.Recall(name='recall')]}
loss_weights = {'ICAE_decoder':0.5, 'ICAE_classifier':0.5}

ICAE_autoencoder.compile(optimizer='sgd', 
                         loss=losses,
                         loss_weights=loss_weights,
                         metrics=metrics)

my_callbacks = [
    tf.keras.callbacks.EarlyStopping(patience=10),
    tf.keras.callbacks.ModelCheckpoint(\
        filepath=\
        'outputs_AC/ICAE_experimentation_AC_1205.{epoch:02d}-{val_loss:.2f}.h5'),
    tf.keras.callbacks.TensorBoard(log_dir='./logs_AC')] # initialed AC

# %%
train_generator = MyDataGenerator(train_list, processed_dir, to_fit=True, 
                                  augment=False, batch_size=32)
val_generator = MyDataGenerator(val_list, processed_dir, to_fit=False, 
                                  augment=False, batch_size=32)

# %% [markdown]
# #### Training

# %%
start_time = time.time()

history_ICAE = ICAE_autoencoder.fit(train_generator, epochs=100, 
                                    validation_data=val_generator, 
                                    shuffle=True, use_multiprocessing=False, 
                                    callbacks=my_callbacks)
# given the warning, if this hangs, try default use_multiprocessing=False

duration = round((time.time() - start_time) / 60, 2)

print('Time taken:', duration, 'minutes')
# Out:
# Epoch 1/100
# 24/24 [==============================] - 425s 18s/step - loss: 14.2761 - ICAE_decoder_loss: 0.1299 - ICAE_classifier_loss: 0.7188 - ICAE_decoder_mae: 0.3186 - ICAE_classifier_accuracy: 0.5846 - ICAE_classifier_precision: 0.5846 - ICAE_classifier_recall: 0.5846 - val_loss: 13.5585 - val_ICAE_decoder_loss: 0.0000e+00 - val_ICAE_classifier_loss: 0.0000e+00 - val_ICAE_decoder_mae: 0.0000e+00 - val_ICAE_classifier_accuracy: 0.0000e+00 - val_ICAE_classifier_precision: 0.0000e+00 - val_ICAE_classifier_recall: 0.0000e+00
# Epoch 2/100
# 24/24 [==============================] - 281s 12s/step - loss: 13.6830 - ICAE_decoder_loss: 0.1117 - ICAE_classifier_loss: 0.6678 - ICAE_decoder_mae: 0.2892 - ICAE_classifier_accuracy: 0.5924 - ICAE_classifier_precision: 0.5924 - ICAE_classifier_recall: 0.5924 - val_loss: 13.0076 - val_ICAE_decoder_loss: 0.0000e+00 - val_ICAE_classifier_loss: 0.0000e+00 - val_ICAE_decoder_mae: 0.0000e+00 - val_ICAE_classifier_accuracy: 0.0000e+00 - val_ICAE_classifier_precision: 0.0000e+00 - val_ICAE_classifier_recall: 0.0000e+00
# Epoch 3/100
# 24/24 [==============================] - 271s 11s/step - loss: 13.1313 - ICAE_decoder_loss: 0.1053 - ICAE_classifier_loss: 0.6586 - ICAE_decoder_mae: 0.2783 - ICAE_classifier_accuracy: 0.6224 - ICAE_classifier_precision: 0.6224 - ICAE_classifier_recall: 0.6224 - val_loss: 12.4709 - val_ICAE_decoder_loss: 0.0000e+00 - val_ICAE_classifier_loss: 0.0000e+00 - val_ICAE_decoder_mae: 0.0000e+00 - val_ICAE_classifier_accuracy: 0.0000e+00 - val_ICAE_classifier_precision: 0.0000e+00 - val_ICAE_classifier_recall: 0.0000e+00
# Epoch 4/100
# 24/24 [==============================] - 266s 11s/step - loss: 12.5976 - ICAE_decoder_loss: 0.0997 - ICAE_classifier_loss: 0.6572 - ICAE_decoder_mae: 0.2689 - ICAE_classifier_accuracy: 0.6133 - ICAE_classifier_precision: 0.6133 - ICAE_classifier_recall: 0.6133 - val_loss: 11.9482 - val_ICAE_decoder_loss: 0.0000e+00 - val_ICAE_classifier_loss: 0.0000e+00 - val_ICAE_decoder_mae: 0.0000e+00 - val_ICAE_classifier_accuracy: 0.0000e+00 - val_ICAE_classifier_precision: 0.0000e+00 - val_ICAE_classifier_recall: 0.0000e+00
# Epoch 5/100
# 24/24 [==============================] - 249s 10s/step - loss: 12.0798 - ICAE_decoder_loss: 0.0942 - ICAE_classifier_loss: 0.6581 - ICAE_decoder_mae: 0.2596 - ICAE_classifier_accuracy: 0.6263 - ICAE_classifier_precision: 0.6263 - ICAE_classifier_recall: 0.6263 - val_loss: 11.4401 - val_ICAE_decoder_loss: 0.0000e+00 - val_ICAE_classifier_loss: 0.0000e+00 - val_ICAE_decoder_mae: 0.0000e+00 - val_ICAE_classifier_accuracy: 0.0000e+00 - val_ICAE_classifier_precision: 0.0000e+00 - val_ICAE_classifier_recall: 0.0000e+00
# Epoch 6/100
# 24/24 [==============================] - 253s 11s/step - loss: 11.5766 - ICAE_decoder_loss: 0.0888 - ICAE_classifier_loss: 0.6601 - ICAE_decoder_mae: 0.2506 - ICAE_classifier_accuracy: 0.6354 - ICAE_classifier_precision: 0.6354 - ICAE_classifier_recall: 0.6354 - val_loss: 10.9459 - val_ICAE_decoder_loss: 0.0000e+00 - val_ICAE_classifier_loss: 0.0000e+00 - val_ICAE_decoder_mae: 0.0000e+00 - val_ICAE_classifier_accuracy: 0.0000e+00 - val_ICAE_classifier_precision: 0.0000e+00 - val_ICAE_classifier_recall: 0.0000e+00
# Epoch 7/100
# 24/24 [==============================] - 261s 11s/step - loss: 11.0864 - ICAE_decoder_loss: 0.0833 - ICAE_classifier_loss: 0.6595 - ICAE_decoder_mae: 0.2415 - ICAE_classifier_accuracy: 0.6133 - ICAE_classifier_precision: 0.6133 - ICAE_classifier_recall: 0.6133 - val_loss: 10.4665 - val_ICAE_decoder_loss: 0.0000e+00 - val_ICAE_classifier_loss: 0.0000e+00 - val_ICAE_decoder_mae: 0.0000e+00 - val_ICAE_classifier_accuracy: 0.0000e+00 - val_ICAE_classifier_precision: 0.0000e+00 - val_ICAE_classifier_recall: 0.0000e+00
# Epoch 8/100
# 24/24 [==============================] - 252s 11s/step - loss: 10.6040 - ICAE_decoder_loss: 0.0768 - ICAE_classifier_loss: 0.6470 - ICAE_decoder_mae: 0.2307 - ICAE_classifier_accuracy: 0.6445 - ICAE_classifier_precision: 0.6445 - ICAE_classifier_recall: 0.6445 - val_loss: 10.0008 - val_ICAE_decoder_loss: 0.0000e+00 - val_ICAE_classifier_loss: 0.0000e+00 - val_ICAE_decoder_mae: 0.0000e+00 - val_ICAE_classifier_accuracy: 0.0000e+00 - val_ICAE_classifier_precision: 0.0000e+00 - val_ICAE_classifier_recall: 0.0000e+00
# Epoch 9/100
# 24/24 [==============================] - 261s 11s/step - loss: 10.1407 - ICAE_decoder_loss: 0.0701 - ICAE_classifier_loss: 0.6447 - ICAE_decoder_mae: 0.2198 - ICAE_classifier_accuracy: 0.6315 - ICAE_classifier_precision: 0.6315 - ICAE_classifier_recall: 0.6315 - val_loss: 9.5494 - val_ICAE_decoder_loss: 0.0000e+00 - val_ICAE_classifier_loss: 0.0000e+00 - val_ICAE_decoder_mae: 0.0000e+00 - val_ICAE_classifier_accuracy: 0.0000e+00 - val_ICAE_classifier_precision: 0.0000e+00 - val_ICAE_classifier_recall: 0.0000e+00
# Epoch 10/100
# 24/24 [==============================] - 250s 10s/step - loss: 9.6971 - ICAE_decoder_loss: 0.0643 - ICAE_classifier_loss: 0.6528 - ICAE_decoder_mae: 0.2106 - ICAE_classifier_accuracy: 0.6276 - ICAE_classifier_precision: 0.6276 - ICAE_classifier_recall: 0.6276 - val_loss: 9.1119 - val_ICAE_decoder_loss: 0.0000e+00 - val_ICAE_classifier_loss: 0.0000e+00 - val_ICAE_decoder_mae: 0.0000e+00 - val_ICAE_classifier_accuracy: 0.0000e+00 - val_ICAE_classifier_precision: 0.0000e+00 - val_ICAE_classifier_recall: 0.0000e+00
# Epoch 11/100
# 24/24 [==============================] - 250s 10s/step - loss: 9.2606 - ICAE_decoder_loss: 0.0590 - ICAE_classifier_loss: 0.6469 - ICAE_decoder_mae: 0.2023 - ICAE_classifier_accuracy: 0.6276 - ICAE_classifier_precision: 0.6276 - ICAE_classifier_recall: 0.6276 - val_loss: 8.6878 - val_ICAE_decoder_loss: 0.0000e+00 - val_ICAE_classifier_loss: 0.0000e+00 - val_ICAE_decoder_mae: 0.0000e+00 - val_ICAE_classifier_accuracy: 0.0000e+00 - val_ICAE_classifier_precision: 0.0000e+00 - val_ICAE_classifier_recall: 0.0000e+00
# Epoch 12/100
# 24/24 [==============================] - 258s 11s/step - loss: 8.8381 - ICAE_decoder_loss: 0.0548 - ICAE_classifier_loss: 0.6421 - ICAE_decoder_mae: 0.1959 - ICAE_classifier_accuracy: 0.6328 - ICAE_classifier_precision: 0.6328 - ICAE_classifier_recall: 0.6328 - val_loss: 8.2768 - val_ICAE_decoder_loss: 0.0000e+00 - val_ICAE_classifier_loss: 0.0000e+00 - val_ICAE_decoder_mae: 0.0000e+00 - val_ICAE_classifier_accuracy: 0.0000e+00 - val_ICAE_classifier_precision: 0.0000e+00 - val_ICAE_classifier_recall: 0.0000e+00
# Epoch 13/100
# 24/24 [==============================] - 253s 11s/step - loss: 8.4361 - ICAE_decoder_loss: 0.0513 - ICAE_classifier_loss: 0.6499 - ICAE_decoder_mae: 0.1906 - ICAE_classifier_accuracy: 0.6328 - ICAE_classifier_precision: 0.6328 - ICAE_classifier_recall: 0.6328 - val_loss: 7.8798 - val_ICAE_decoder_loss: 0.0000e+00 - val_ICAE_classifier_loss: 0.0000e+00 - val_ICAE_decoder_mae: 0.0000e+00 - val_ICAE_classifier_accuracy: 0.0000e+00 - val_ICAE_classifier_precision: 0.0000e+00 - val_ICAE_classifier_recall: 0.0000e+00
# Epoch 14/100
# 24/24 [==============================] - 259s 11s/step - loss: 8.0408 - ICAE_decoder_loss: 0.0490 - ICAE_classifier_loss: 0.6429 - ICAE_decoder_mae: 0.1872 - ICAE_classifier_accuracy: 0.6484 - ICAE_classifier_precision: 0.6484 - ICAE_classifier_recall: 0.6484 - val_loss: 7.4963 - val_ICAE_decoder_loss: 0.0000e+00 - val_ICAE_classifier_loss: 0.0000e+00 - val_ICAE_decoder_mae: 0.0000e+00 - val_ICAE_classifier_accuracy: 0.0000e+00 - val_ICAE_classifier_precision: 0.0000e+00 - val_ICAE_classifier_recall: 0.0000e+00
# Epoch 15/100
# 24/24 [==============================] - 263s 11s/step - loss: 7.6612 - ICAE_decoder_loss: 0.0470 - ICAE_classifier_loss: 0.6399 - ICAE_decoder_mae: 0.1842 - ICAE_classifier_accuracy: 0.6432 - ICAE_classifier_precision: 0.6432 - ICAE_classifier_recall: 0.6432 - val_loss: 7.1259 - val_ICAE_decoder_loss: 0.0000e+00 - val_ICAE_classifier_loss: 0.0000e+00 - val_ICAE_decoder_mae: 0.0000e+00 - val_ICAE_classifier_accuracy: 0.0000e+00 - val_ICAE_classifier_precision: 0.0000e+00 - val_ICAE_classifier_recall: 0.0000e+00
# Epoch 16/100
# 24/24 [==============================] - 263s 11s/step - loss: 7.2977 - ICAE_decoder_loss: 0.0456 - ICAE_classifier_loss: 0.6429 - ICAE_decoder_mae: 0.1820 - ICAE_classifier_accuracy: 0.6354 - ICAE_classifier_precision: 0.6354 - ICAE_classifier_recall: 0.6354 - val_loss: 6.7681 - val_ICAE_decoder_loss: 0.0000e+00 - val_ICAE_classifier_loss: 0.0000e+00 - val_ICAE_decoder_mae: 0.0000e+00 - val_ICAE_classifier_accuracy: 0.0000e+00 - val_ICAE_classifier_precision: 0.0000e+00 - val_ICAE_classifier_recall: 0.0000e+00
# Epoch 17/100
# 24/24 [==============================] - 259s 11s/step - loss: 6.9417 - ICAE_decoder_loss: 0.0446 - ICAE_classifier_loss: 0.6347 - ICAE_decoder_mae: 0.1803 - ICAE_classifier_accuracy: 0.6432 - ICAE_classifier_precision: 0.6432 - ICAE_classifier_recall: 0.6432 - val_loss: 6.4238 - val_ICAE_decoder_loss: 0.0000e+00 - val_ICAE_classifier_loss: 0.0000e+00 - val_ICAE_decoder_mae: 0.0000e+00 - val_ICAE_classifier_accuracy: 0.0000e+00 - val_ICAE_classifier_precision: 0.0000e+00 - val_ICAE_classifier_recall: 0.0000e+00
# Epoch 18/100
# 24/24 [==============================] - 258s 11s/step - loss: 6.6070 - ICAE_decoder_loss: 0.0438 - ICAE_classifier_loss: 0.6417 - ICAE_decoder_mae: 0.1790 - ICAE_classifier_accuracy: 0.6341 - ICAE_classifier_precision: 0.6341 - ICAE_classifier_recall: 0.6341 - val_loss: 6.0928 - val_ICAE_decoder_loss: 0.0000e+00 - val_ICAE_classifier_loss: 0.0000e+00 - val_ICAE_decoder_mae: 0.0000e+00 - val_ICAE_classifier_accuracy: 0.0000e+00 - val_ICAE_classifier_precision: 0.0000e+00 - val_ICAE_classifier_recall: 0.0000e+00
# Epoch 19/100
# 24/24 [==============================] - 253s 11s/step - loss: 6.2744 - ICAE_decoder_loss: 0.0430 - ICAE_classifier_loss: 0.6267 - ICAE_decoder_mae: 0.1776 - ICAE_classifier_accuracy: 0.6628 - ICAE_classifier_precision: 0.6628 - ICAE_classifier_recall: 0.6628 - val_loss: 5.7751 - val_ICAE_decoder_loss: 0.0000e+00 - val_ICAE_classifier_loss: 0.0000e+00 - val_ICAE_decoder_mae: 0.0000e+00 - val_ICAE_classifier_accuracy: 0.0000e+00 - val_ICAE_classifier_precision: 0.0000e+00 - val_ICAE_classifier_recall: 0.0000e+00
# Epoch 20/100
# 24/24 [==============================] - 259s 11s/step - loss: 5.9654 - ICAE_decoder_loss: 0.0424 - ICAE_classifier_loss: 0.6327 - ICAE_decoder_mae: 0.1767 - ICAE_classifier_accuracy: 0.6510 - ICAE_classifier_precision: 0.6510 - ICAE_classifier_recall: 0.6510 - val_loss: 5.4698 - val_ICAE_decoder_loss: 0.0000e+00 - val_ICAE_classifier_loss: 0.0000e+00 - val_ICAE_decoder_mae: 0.0000e+00 - val_ICAE_classifier_accuracy: 0.0000e+00 - val_ICAE_classifier_precision: 0.0000e+00 - val_ICAE_classifier_recall: 0.0000e+00
# Epoch 21/100
# 24/24 [==============================] - 259s 11s/step - loss: 5.6634 - ICAE_decoder_loss: 0.0418 - ICAE_classifier_loss: 0.6282 - ICAE_decoder_mae: 0.1754 - ICAE_classifier_accuracy: 0.6549 - ICAE_classifier_precision: 0.6549 - ICAE_classifier_recall: 0.6549 - val_loss: 5.1771 - val_ICAE_decoder_loss: 0.0000e+00 - val_ICAE_classifier_loss: 0.0000e+00 - val_ICAE_decoder_mae: 0.0000e+00 - val_ICAE_classifier_accuracy: 0.0000e+00 - val_ICAE_classifier_precision: 0.0000e+00 - val_ICAE_classifier_recall: 0.0000e+00
# Epoch 22/100
# 24/24 [==============================] - 268s 11s/step - loss: 5.3765 - ICAE_decoder_loss: 0.0412 - ICAE_classifier_loss: 0.6278 - ICAE_decoder_mae: 0.1742 - ICAE_classifier_accuracy: 0.6536 - ICAE_classifier_precision: 0.6536 - ICAE_classifier_recall: 0.6536 - val_loss: 4.8975 - val_ICAE_decoder_loss: 0.0000e+00 - val_ICAE_classifier_loss: 0.0000e+00 - val_ICAE_decoder_mae: 0.0000e+00 - val_ICAE_classifier_accuracy: 0.0000e+00 - val_ICAE_classifier_precision: 0.0000e+00 - val_ICAE_classifier_recall: 0.0000e+00
# Epoch 23/100
# 24/24 [==============================] - 267s 11s/step - loss: 5.1031 - ICAE_decoder_loss: 0.0407 - ICAE_classifier_loss: 0.6282 - ICAE_decoder_mae: 0.1735 - ICAE_classifier_accuracy: 0.6445 - ICAE_classifier_precision: 0.6445 - ICAE_classifier_recall: 0.6445 - val_loss: 4.6308 - val_ICAE_decoder_loss: 0.0000e+00 - val_ICAE_classifier_loss: 0.0000e+00 - val_ICAE_decoder_mae: 0.0000e+00 - val_ICAE_classifier_accuracy: 0.0000e+00 - val_ICAE_classifier_precision: 0.0000e+00 - val_ICAE_classifier_recall: 0.0000e+00
# Epoch 24/100
# 24/24 [==============================] - 257s 11s/step - loss: 4.8430 - ICAE_decoder_loss: 0.0401 - ICAE_classifier_loss: 0.6295 - ICAE_decoder_mae: 0.1721 - ICAE_classifier_accuracy: 0.6576 - ICAE_classifier_precision: 0.6576 - ICAE_classifier_recall: 0.6576 - val_loss: 4.3771 - val_ICAE_decoder_loss: 0.0000e+00 - val_ICAE_classifier_loss: 0.0000e+00 - val_ICAE_decoder_mae: 0.0000e+00 - val_ICAE_classifier_accuracy: 0.0000e+00 - val_ICAE_classifier_precision: 0.0000e+00 - val_ICAE_classifier_recall: 0.0000e+00
# Epoch 25/100
# 24/24 [==============================] - 257s 11s/step - loss: 4.5971 - ICAE_decoder_loss: 0.0397 - ICAE_classifier_loss: 0.6328 - ICAE_decoder_mae: 0.1713 - ICAE_classifier_accuracy: 0.6615 - ICAE_classifier_precision: 0.6615 - ICAE_classifier_recall: 0.6615 - val_loss: 4.1366 - val_ICAE_decoder_loss: 0.0000e+00 - val_ICAE_classifier_loss: 0.0000e+00 - val_ICAE_decoder_mae: 0.0000e+00 - val_ICAE_classifier_accuracy: 0.0000e+00 - val_ICAE_classifier_precision: 0.0000e+00 - val_ICAE_classifier_recall: 0.0000e+00
# Epoch 26/100
# 24/24 [==============================] - 252s 10s/step - loss: 4.3575 - ICAE_decoder_loss: 0.0392 - ICAE_classifier_loss: 0.6229 - ICAE_decoder_mae: 0.1703 - ICAE_classifier_accuracy: 0.6510 - ICAE_classifier_precision: 0.6510 - ICAE_classifier_recall: 0.6510 - val_loss: 3.9091 - val_ICAE_decoder_loss: 0.0000e+00 - val_ICAE_classifier_loss: 0.0000e+00 - val_ICAE_decoder_mae: 0.0000e+00 - val_ICAE_classifier_accuracy: 0.0000e+00 - val_ICAE_classifier_precision: 0.0000e+00 - val_ICAE_classifier_recall: 0.0000e+00
# Epoch 27/100
# 24/24 [==============================] - 283s 12s/step - loss: 4.1331 - ICAE_decoder_loss: 0.0388 - ICAE_classifier_loss: 0.6175 - ICAE_decoder_mae: 0.1697 - ICAE_classifier_accuracy: 0.6602 - ICAE_classifier_precision: 0.6602 - ICAE_classifier_recall: 0.6602 - val_loss: 3.6940 - val_ICAE_decoder_loss: 0.0000e+00 - val_ICAE_classifier_loss: 0.0000e+00 - val_ICAE_decoder_mae: 0.0000e+00 - val_ICAE_classifier_accuracy: 0.0000e+00 - val_ICAE_classifier_precision: 0.0000e+00 - val_ICAE_classifier_recall: 0.0000e+00
# Epoch 28/100
# 24/24 [==============================] - 272s 11s/step - loss: 3.9266 - ICAE_decoder_loss: 0.0385 - ICAE_classifier_loss: 0.6224 - ICAE_decoder_mae: 0.1690 - ICAE_classifier_accuracy: 0.6576 - ICAE_classifier_precision: 0.6576 - ICAE_classifier_recall: 0.6576 - val_loss: 3.4918 - val_ICAE_decoder_loss: 0.0000e+00 - val_ICAE_classifier_loss: 0.0000e+00 - val_ICAE_decoder_mae: 0.0000e+00 - val_ICAE_classifier_accuracy: 0.0000e+00 - val_ICAE_classifier_precision: 0.0000e+00 - val_ICAE_classifier_recall: 0.0000e+00
# Epoch 29/100
# 24/24 [==============================] - 259s 11s/step - loss: 3.7258 - ICAE_decoder_loss: 0.0380 - ICAE_classifier_loss: 0.6138 - ICAE_decoder_mae: 0.1678 - ICAE_classifier_accuracy: 0.6628 - ICAE_classifier_precision: 0.6628 - ICAE_classifier_recall: 0.6628 - val_loss: 3.3020 - val_ICAE_decoder_loss: 0.0000e+00 - val_ICAE_classifier_loss: 0.0000e+00 - val_ICAE_decoder_mae: 0.0000e+00 - val_ICAE_classifier_accuracy: 0.0000e+00 - val_ICAE_classifier_precision: 0.0000e+00 - val_ICAE_classifier_recall: 0.0000e+00
# Epoch 30/100
# 24/24 [==============================] - 256s 11s/step - loss: 3.5438 - ICAE_decoder_loss: 0.0377 - ICAE_classifier_loss: 0.6180 - ICAE_decoder_mae: 0.1673 - ICAE_classifier_accuracy: 0.6589 - ICAE_classifier_precision: 0.6589 - ICAE_classifier_recall: 0.6589 - val_loss: 3.1243 - val_ICAE_decoder_loss: 0.0000e+00 - val_ICAE_classifier_loss: 0.0000e+00 - val_ICAE_decoder_mae: 0.0000e+00 - val_ICAE_classifier_accuracy: 0.0000e+00 - val_ICAE_classifier_precision: 0.0000e+00 - val_ICAE_classifier_recall: 0.0000e+00
# Epoch 31/100
# 24/24 [==============================] - 277s 12s/step - loss: 3.3707 - ICAE_decoder_loss: 0.0373 - ICAE_classifier_loss: 0.6158 - ICAE_decoder_mae: 0.1665 - ICAE_classifier_accuracy: 0.6589 - ICAE_classifier_precision: 0.6589 - ICAE_classifier_recall: 0.6589 - val_loss: 2.9590 - val_ICAE_decoder_loss: 0.0000e+00 - val_ICAE_classifier_loss: 0.0000e+00 - val_ICAE_decoder_mae: 0.0000e+00 - val_ICAE_classifier_accuracy: 0.0000e+00 - val_ICAE_classifier_precision: 0.0000e+00 - val_ICAE_classifier_recall: 0.0000e+00
# Epoch 32/100
# 24/24 [==============================] - 263s 11s/step - loss: 3.2080 - ICAE_decoder_loss: 0.0369 - ICAE_classifier_loss: 0.6103 - ICAE_decoder_mae: 0.1656 - ICAE_classifier_accuracy: 0.6732 - ICAE_classifier_precision: 0.6732 - ICAE_classifier_recall: 0.6732 - val_loss: 2.8056 - val_ICAE_decoder_loss: 0.0000e+00 - val_ICAE_classifier_loss: 0.0000e+00 - val_ICAE_decoder_mae: 0.0000e+00 - val_ICAE_classifier_accuracy: 0.0000e+00 - val_ICAE_classifier_precision: 0.0000e+00 - val_ICAE_classifier_recall: 0.0000e+00
# Epoch 33/100
# 24/24 [==============================] - 258s 11s/step - loss: 3.0603 - ICAE_decoder_loss: 0.0366 - ICAE_classifier_loss: 0.6102 - ICAE_decoder_mae: 0.1651 - ICAE_classifier_accuracy: 0.6745 - ICAE_classifier_precision: 0.6745 - ICAE_classifier_recall: 0.6745 - val_loss: 2.6642 - val_ICAE_decoder_loss: 0.0000e+00 - val_ICAE_classifier_loss: 0.0000e+00 - val_ICAE_decoder_mae: 0.0000e+00 - val_ICAE_classifier_accuracy: 0.0000e+00 - val_ICAE_classifier_precision: 0.0000e+00 - val_ICAE_classifier_recall: 0.0000e+00
# Epoch 34/100
# 24/24 [==============================] - 259s 11s/step - loss: 2.9233 - ICAE_decoder_loss: 0.0364 - ICAE_classifier_loss: 0.6074 - ICAE_decoder_mae: 0.1647 - ICAE_classifier_accuracy: 0.6953 - ICAE_classifier_precision: 0.6953 - ICAE_classifier_recall: 0.6953 - val_loss: 2.5348 - val_ICAE_decoder_loss: 0.0000e+00 - val_ICAE_classifier_loss: 0.0000e+00 - val_ICAE_decoder_mae: 0.0000e+00 - val_ICAE_classifier_accuracy: 0.0000e+00 - val_ICAE_classifier_precision: 0.0000e+00 - val_ICAE_classifier_recall: 0.0000e+00
# Epoch 35/100
# 24/24 [==============================] - 262s 11s/step - loss: 2.7972 - ICAE_decoder_loss: 0.0362 - ICAE_classifier_loss: 0.6032 - ICAE_decoder_mae: 0.1642 - ICAE_classifier_accuracy: 0.6810 - ICAE_classifier_precision: 0.6810 - ICAE_classifier_recall: 0.6810 - val_loss: 2.4170 - val_ICAE_decoder_loss: 0.0000e+00 - val_ICAE_classifier_loss: 0.0000e+00 - val_ICAE_decoder_mae: 0.0000e+00 - val_ICAE_classifier_accuracy: 0.0000e+00 - val_ICAE_classifier_precision: 0.0000e+00 - val_ICAE_classifier_recall: 0.0000e+00
# Epoch 36/100
# 24/24 [==============================] - 277s 12s/step - loss: 2.6882 - ICAE_decoder_loss: 0.0360 - ICAE_classifier_loss: 0.6098 - ICAE_decoder_mae: 0.1639 - ICAE_classifier_accuracy: 0.6706 - ICAE_classifier_precision: 0.6706 - ICAE_classifier_recall: 0.6706 - val_loss: 2.3111 - val_ICAE_decoder_loss: 0.0000e+00 - val_ICAE_classifier_loss: 0.0000e+00 - val_ICAE_decoder_mae: 0.0000e+00 - val_ICAE_classifier_accuracy: 0.0000e+00 - val_ICAE_classifier_precision: 0.0000e+00 - val_ICAE_classifier_recall: 0.0000e+00
# Epoch 37/100
# 24/24 [==============================] - 252s 11s/step - loss: 2.5836 - ICAE_decoder_loss: 0.0357 - ICAE_classifier_loss: 0.6010 - ICAE_decoder_mae: 0.1631 - ICAE_classifier_accuracy: 0.6810 - ICAE_classifier_precision: 0.6810 - ICAE_classifier_recall: 0.6810 - val_loss: 2.2174 - val_ICAE_decoder_loss: 0.0000e+00 - val_ICAE_classifier_loss: 0.0000e+00 - val_ICAE_decoder_mae: 0.0000e+00 - val_ICAE_classifier_accuracy: 0.0000e+00 - val_ICAE_classifier_precision: 0.0000e+00 - val_ICAE_classifier_recall: 0.0000e+00
# Epoch 38/100
# 24/24 [==============================] - 256s 11s/step - loss: 2.4919 - ICAE_decoder_loss: 0.0355 - ICAE_classifier_loss: 0.5934 - ICAE_decoder_mae: 0.1627 - ICAE_classifier_accuracy: 0.6914 - ICAE_classifier_precision: 0.6914 - ICAE_classifier_recall: 0.6914 - val_loss: 2.1357 - val_ICAE_decoder_loss: 0.0000e+00 - val_ICAE_classifier_loss: 0.0000e+00 - val_ICAE_decoder_mae: 0.0000e+00 - val_ICAE_classifier_accuracy: 0.0000e+00 - val_ICAE_classifier_precision: 0.0000e+00 - val_ICAE_classifier_recall: 0.0000e+00
# Epoch 39/100
# 24/24 [==============================] - 272s 11s/step - loss: 2.4152 - ICAE_decoder_loss: 0.0354 - ICAE_classifier_loss: 0.5923 - ICAE_decoder_mae: 0.1626 - ICAE_classifier_accuracy: 0.7031 - ICAE_classifier_precision: 0.7031 - ICAE_classifier_recall: 0.7031 - val_loss: 2.0661 - val_ICAE_decoder_loss: 0.0000e+00 - val_ICAE_classifier_loss: 0.0000e+00 - val_ICAE_decoder_mae: 0.0000e+00 - val_ICAE_classifier_accuracy: 0.0000e+00 - val_ICAE_classifier_precision: 0.0000e+00 - val_ICAE_classifier_recall: 0.0000e+00
# Epoch 40/100
# 24/24 [==============================] - 252s 10s/step - loss: 2.3557 - ICAE_decoder_loss: 0.0350 - ICAE_classifier_loss: 0.6014 - ICAE_decoder_mae: 0.1616 - ICAE_classifier_accuracy: 0.6862 - ICAE_classifier_precision: 0.6862 - ICAE_classifier_recall: 0.6862 - val_loss: 2.0083 - val_ICAE_decoder_loss: 0.0000e+00 - val_ICAE_classifier_loss: 0.0000e+00 - val_ICAE_decoder_mae: 0.0000e+00 - val_ICAE_classifier_accuracy: 0.0000e+00 - val_ICAE_classifier_precision: 0.0000e+00 - val_ICAE_classifier_recall: 0.0000e+00
# Epoch 41/100
# 24/24 [==============================] - 254s 11s/step - loss: 2.2945 - ICAE_decoder_loss: 0.0347 - ICAE_classifier_loss: 0.5885 - ICAE_decoder_mae: 0.1611 - ICAE_classifier_accuracy: 0.7122 - ICAE_classifier_precision: 0.7122 - ICAE_classifier_recall: 0.7122 - val_loss: 1.9554 - val_ICAE_decoder_loss: 0.0000e+00 - val_ICAE_classifier_loss: 0.0000e+00 - val_ICAE_decoder_mae: 0.0000e+00 - val_ICAE_classifier_accuracy: 0.0000e+00 - val_ICAE_classifier_precision: 0.0000e+00 - val_ICAE_classifier_recall: 0.0000e+00
# Epoch 42/100
# 24/24 [==============================] - 255s 11s/step - loss: 2.2437 - ICAE_decoder_loss: 0.0346 - ICAE_classifier_loss: 0.5920 - ICAE_decoder_mae: 0.1609 - ICAE_classifier_accuracy: 0.6732 - ICAE_classifier_precision: 0.6732 - ICAE_classifier_recall: 0.6732 - val_loss: 1.9033 - val_ICAE_decoder_loss: 0.0000e+00 - val_ICAE_classifier_loss: 0.0000e+00 - val_ICAE_decoder_mae: 0.0000e+00 - val_ICAE_classifier_accuracy: 0.0000e+00 - val_ICAE_classifier_precision: 0.0000e+00 - val_ICAE_classifier_recall: 0.0000e+00
# Epoch 43/100
# 24/24 [==============================] - 257s 11s/step - loss: 2.1873 - ICAE_decoder_loss: 0.0344 - ICAE_classifier_loss: 0.5826 - ICAE_decoder_mae: 0.1605 - ICAE_classifier_accuracy: 0.7070 - ICAE_classifier_precision: 0.7070 - ICAE_classifier_recall: 0.7070 - val_loss: 1.8523 - val_ICAE_decoder_loss: 0.0000e+00 - val_ICAE_classifier_loss: 0.0000e+00 - val_ICAE_decoder_mae: 0.0000e+00 - val_ICAE_classifier_accuracy: 0.0000e+00 - val_ICAE_classifier_precision: 0.0000e+00 - val_ICAE_classifier_recall: 0.0000e+00
# Epoch 44/100
# 24/24 [==============================] - 253s 11s/step - loss: 2.1366 - ICAE_decoder_loss: 0.0343 - ICAE_classifier_loss: 0.5823 - ICAE_decoder_mae: 0.1602 - ICAE_classifier_accuracy: 0.6992 - ICAE_classifier_precision: 0.6992 - ICAE_classifier_recall: 0.6992 - val_loss: 1.8021 - val_ICAE_decoder_loss: 0.0000e+00 - val_ICAE_classifier_loss: 0.0000e+00 - val_ICAE_decoder_mae: 0.0000e+00 - val_ICAE_classifier_accuracy: 0.0000e+00 - val_ICAE_classifier_precision: 0.0000e+00 - val_ICAE_classifier_recall: 0.0000e+00
# Epoch 45/100
# 24/24 [==============================] - 270s 11s/step - loss: 2.0826 - ICAE_decoder_loss: 0.0341 - ICAE_classifier_loss: 0.5741 - ICAE_decoder_mae: 0.1597 - ICAE_classifier_accuracy: 0.7174 - ICAE_classifier_precision: 0.7174 - ICAE_classifier_recall: 0.7174 - val_loss: 1.7526 - val_ICAE_decoder_loss: 0.0000e+00 - val_ICAE_classifier_loss: 0.0000e+00 - val_ICAE_decoder_mae: 0.0000e+00 - val_ICAE_classifier_accuracy: 0.0000e+00 - val_ICAE_classifier_precision: 0.0000e+00 - val_ICAE_classifier_recall: 0.0000e+00
# Epoch 46/100
# 24/24 [==============================] - 262s 11s/step - loss: 2.0316 - ICAE_decoder_loss: 0.0338 - ICAE_classifier_loss: 0.5706 - ICAE_decoder_mae: 0.1591 - ICAE_classifier_accuracy: 0.6940 - ICAE_classifier_precision: 0.6940 - ICAE_classifier_recall: 0.6940 - val_loss: 1.7040 - val_ICAE_decoder_loss: 0.0000e+00 - val_ICAE_classifier_loss: 0.0000e+00 - val_ICAE_decoder_mae: 0.0000e+00 - val_ICAE_classifier_accuracy: 0.0000e+00 - val_ICAE_classifier_precision: 0.0000e+00 - val_ICAE_classifier_recall: 0.0000e+00
# Epoch 47/100
# 24/24 [==============================] - 259s 11s/step - loss: 1.9860 - ICAE_decoder_loss: 0.0336 - ICAE_classifier_loss: 0.5763 - ICAE_decoder_mae: 0.1589 - ICAE_classifier_accuracy: 0.7018 - ICAE_classifier_precision: 0.7018 - ICAE_classifier_recall: 0.7018 - val_loss: 1.6561 - val_ICAE_decoder_loss: 0.0000e+00 - val_ICAE_classifier_loss: 0.0000e+00 - val_ICAE_decoder_mae: 0.0000e+00 - val_ICAE_classifier_accuracy: 0.0000e+00 - val_ICAE_classifier_precision: 0.0000e+00 - val_ICAE_classifier_recall: 0.0000e+00
# Epoch 48/100
# 24/24 [==============================] - 262s 11s/step - loss: 1.9355 - ICAE_decoder_loss: 0.0334 - ICAE_classifier_loss: 0.5705 - ICAE_decoder_mae: 0.1584 - ICAE_classifier_accuracy: 0.7109 - ICAE_classifier_precision: 0.7109 - ICAE_classifier_recall: 0.7109 - val_loss: 1.6089 - val_ICAE_decoder_loss: 0.0000e+00 - val_ICAE_classifier_loss: 0.0000e+00 - val_ICAE_decoder_mae: 0.0000e+00 - val_ICAE_classifier_accuracy: 0.0000e+00 - val_ICAE_classifier_precision: 0.0000e+00 - val_ICAE_classifier_recall: 0.0000e+00
# Epoch 49/100
# 24/24 [==============================] - 263s 11s/step - loss: 1.8924 - ICAE_decoder_loss: 0.0333 - ICAE_classifier_loss: 0.5782 - ICAE_decoder_mae: 0.1580 - ICAE_classifier_accuracy: 0.7109 - ICAE_classifier_precision: 0.7109 - ICAE_classifier_recall: 0.7109 - val_loss: 1.5625 - val_ICAE_decoder_loss: 0.0000e+00 - val_ICAE_classifier_loss: 0.0000e+00 - val_ICAE_decoder_mae: 0.0000e+00 - val_ICAE_classifier_accuracy: 0.0000e+00 - val_ICAE_classifier_precision: 0.0000e+00 - val_ICAE_classifier_recall: 0.0000e+00
# Epoch 50/100
# 24/24 [==============================] - 262s 11s/step - loss: 1.8427 - ICAE_decoder_loss: 0.0331 - ICAE_classifier_loss: 0.5704 - ICAE_decoder_mae: 0.1577 - ICAE_classifier_accuracy: 0.6914 - ICAE_classifier_precision: 0.6914 - ICAE_classifier_recall: 0.6914 - val_loss: 1.5171 - val_ICAE_decoder_loss: 0.0000e+00 - val_ICAE_classifier_loss: 0.0000e+00 - val_ICAE_decoder_mae: 0.0000e+00 - val_ICAE_classifier_accuracy: 0.0000e+00 - val_ICAE_classifier_precision: 0.0000e+00 - val_ICAE_classifier_recall: 0.0000e+00
# Epoch 51/100
# 24/24 [==============================] - 258s 11s/step - loss: 1.7945 - ICAE_decoder_loss: 0.0330 - ICAE_classifier_loss: 0.5644 - ICAE_decoder_mae: 0.1575 - ICAE_classifier_accuracy: 0.7357 - ICAE_classifier_precision: 0.7357 - ICAE_classifier_recall: 0.7357 - val_loss: 1.4726 - val_ICAE_decoder_loss: 0.0000e+00 - val_ICAE_classifier_loss: 0.0000e+00 - val_ICAE_decoder_mae: 0.0000e+00 - val_ICAE_classifier_accuracy: 0.0000e+00 - val_ICAE_classifier_precision: 0.0000e+00 - val_ICAE_classifier_recall: 0.0000e+00
# Epoch 52/100
# 24/24 [==============================] - 262s 11s/step - loss: 1.7472 - ICAE_decoder_loss: 0.0328 - ICAE_classifier_loss: 0.5579 - ICAE_decoder_mae: 0.1571 - ICAE_classifier_accuracy: 0.7201 - ICAE_classifier_precision: 0.7201 - ICAE_classifier_recall: 0.7201 - val_loss: 1.4292 - val_ICAE_decoder_loss: 0.0000e+00 - val_ICAE_classifier_loss: 0.0000e+00 - val_ICAE_decoder_mae: 0.0000e+00 - val_ICAE_classifier_accuracy: 0.0000e+00 - val_ICAE_classifier_precision: 0.0000e+00 - val_ICAE_classifier_recall: 0.0000e+00
# Epoch 53/100
# 24/24 [==============================] - 256s 11s/step - loss: 1.7064 - ICAE_decoder_loss: 0.0327 - ICAE_classifier_loss: 0.5628 - ICAE_decoder_mae: 0.1569 - ICAE_classifier_accuracy: 0.7188 - ICAE_classifier_precision: 0.7188 - ICAE_classifier_recall: 0.7188 - val_loss: 1.3864 - val_ICAE_decoder_loss: 0.0000e+00 - val_ICAE_classifier_loss: 0.0000e+00 - val_ICAE_decoder_mae: 0.0000e+00 - val_ICAE_classifier_accuracy: 0.0000e+00 - val_ICAE_classifier_precision: 0.0000e+00 - val_ICAE_classifier_recall: 0.0000e+00
# Epoch 54/100
# 24/24 [==============================] - 266s 11s/step - loss: 1.6614 - ICAE_decoder_loss: 0.0326 - ICAE_classifier_loss: 0.5576 - ICAE_decoder_mae: 0.1567 - ICAE_classifier_accuracy: 0.7148 - ICAE_classifier_precision: 0.7148 - ICAE_classifier_recall: 0.7148 - val_loss: 1.3444 - val_ICAE_decoder_loss: 0.0000e+00 - val_ICAE_classifier_loss: 0.0000e+00 - val_ICAE_decoder_mae: 0.0000e+00 - val_ICAE_classifier_accuracy: 0.0000e+00 - val_ICAE_classifier_precision: 0.0000e+00 - val_ICAE_classifier_recall: 0.0000e+00
# Epoch 55/100
# 24/24 [==============================] - 260s 11s/step - loss: 1.6190 - ICAE_decoder_loss: 0.0327 - ICAE_classifier_loss: 0.5559 - ICAE_decoder_mae: 0.1569 - ICAE_classifier_accuracy: 0.7174 - ICAE_classifier_precision: 0.7174 - ICAE_classifier_recall: 0.7174 - val_loss: 1.3033 - val_ICAE_decoder_loss: 0.0000e+00 - val_ICAE_classifier_loss: 0.0000e+00 - val_ICAE_decoder_mae: 0.0000e+00 - val_ICAE_classifier_accuracy: 0.0000e+00 - val_ICAE_classifier_precision: 0.0000e+00 - val_ICAE_classifier_recall: 0.0000e+00
# Epoch 56/100
# 24/24 [==============================] - 256s 11s/step - loss: 1.5771 - ICAE_decoder_loss: 0.0326 - ICAE_classifier_loss: 0.5539 - ICAE_decoder_mae: 0.1567 - ICAE_classifier_accuracy: 0.7227 - ICAE_classifier_precision: 0.7227 - ICAE_classifier_recall: 0.7227 - val_loss: 1.2626 - val_ICAE_decoder_loss: 0.0000e+00 - val_ICAE_classifier_loss: 0.0000e+00 - val_ICAE_decoder_mae: 0.0000e+00 - val_ICAE_classifier_accuracy: 0.0000e+00 - val_ICAE_classifier_precision: 0.0000e+00 - val_ICAE_classifier_recall: 0.0000e+00
# Epoch 57/100
# 24/24 [==============================] - 254s 11s/step - loss: 1.5385 - ICAE_decoder_loss: 0.0326 - ICAE_classifier_loss: 0.5573 - ICAE_decoder_mae: 0.1568 - ICAE_classifier_accuracy: 0.7188 - ICAE_classifier_precision: 0.7188 - ICAE_classifier_recall: 0.7188 - val_loss: 1.2227 - val_ICAE_decoder_loss: 0.0000e+00 - val_ICAE_classifier_loss: 0.0000e+00 - val_ICAE_decoder_mae: 0.0000e+00 - val_ICAE_classifier_accuracy: 0.0000e+00 - val_ICAE_classifier_precision: 0.0000e+00 - val_ICAE_classifier_recall: 0.0000e+00
# Epoch 58/100
# 24/24 [==============================] - 253s 11s/step - loss: 1.5000 - ICAE_decoder_loss: 0.0327 - ICAE_classifier_loss: 0.5596 - ICAE_decoder_mae: 0.1571 - ICAE_classifier_accuracy: 0.7018 - ICAE_classifier_precision: 0.7018 - ICAE_classifier_recall: 0.7018 - val_loss: 1.1835 - val_ICAE_decoder_loss: 0.0000e+00 - val_ICAE_classifier_loss: 0.0000e+00 - val_ICAE_decoder_mae: 0.0000e+00 - val_ICAE_classifier_accuracy: 0.0000e+00 - val_ICAE_classifier_precision: 0.0000e+00 - val_ICAE_classifier_recall: 0.0000e+00
# Epoch 59/100
# 24/24 [==============================] - 252s 11s/step - loss: 1.4545 - ICAE_decoder_loss: 0.0326 - ICAE_classifier_loss: 0.5462 - ICAE_decoder_mae: 0.1571 - ICAE_classifier_accuracy: 0.7279 - ICAE_classifier_precision: 0.7279 - ICAE_classifier_recall: 0.7279 - val_loss: 1.1452 - val_ICAE_decoder_loss: 0.0000e+00 - val_ICAE_classifier_loss: 0.0000e+00 - val_ICAE_decoder_mae: 0.0000e+00 - val_ICAE_classifier_accuracy: 0.0000e+00 - val_ICAE_classifier_precision: 0.0000e+00 - val_ICAE_classifier_recall: 0.0000e+00
# Epoch 60/100
# 24/24 [==============================] - 256s 11s/step - loss: 1.4167 - ICAE_decoder_loss: 0.0326 - ICAE_classifier_loss: 0.5464 - ICAE_decoder_mae: 0.1570 - ICAE_classifier_accuracy: 0.7227 - ICAE_classifier_precision: 0.7227 - ICAE_classifier_recall: 0.7227 - val_loss: 1.1077 - val_ICAE_decoder_loss: 0.0000e+00 - val_ICAE_classifier_loss: 0.0000e+00 - val_ICAE_decoder_mae: 0.0000e+00 - val_ICAE_classifier_accuracy: 0.0000e+00 - val_ICAE_classifier_precision: 0.0000e+00 - val_ICAE_classifier_recall: 0.0000e+00
# Epoch 61/100
# 24/24 [==============================] - 251s 10s/step - loss: 1.3814 - ICAE_decoder_loss: 0.0325 - ICAE_classifier_loss: 0.5502 - ICAE_decoder_mae: 0.1568 - ICAE_classifier_accuracy: 0.7161 - ICAE_classifier_precision: 0.7161 - ICAE_classifier_recall: 0.7161 - val_loss: 1.0709 - val_ICAE_decoder_loss: 0.0000e+00 - val_ICAE_classifier_loss: 0.0000e+00 - val_ICAE_decoder_mae: 0.0000e+00 - val_ICAE_classifier_accuracy: 0.0000e+00 - val_ICAE_classifier_precision: 0.0000e+00 - val_ICAE_classifier_recall: 0.0000e+00
# Epoch 62/100
# 24/24 [==============================] - 250s 10s/step - loss: 1.3400 - ICAE_decoder_loss: 0.0323 - ICAE_classifier_loss: 0.5400 - ICAE_decoder_mae: 0.1564 - ICAE_classifier_accuracy: 0.7188 - ICAE_classifier_precision: 0.7188 - ICAE_classifier_recall: 0.7188 - val_loss: 1.0351 - val_ICAE_decoder_loss: 0.0000e+00 - val_ICAE_classifier_loss: 0.0000e+00 - val_ICAE_decoder_mae: 0.0000e+00 - val_ICAE_classifier_accuracy: 0.0000e+00 - val_ICAE_classifier_precision: 0.0000e+00 - val_ICAE_classifier_recall: 0.0000e+00
# Epoch 63/100
# 24/24 [==============================] - 253s 11s/step - loss: 1.3068 - ICAE_decoder_loss: 0.0322 - ICAE_classifier_loss: 0.5449 - ICAE_decoder_mae: 0.1563 - ICAE_classifier_accuracy: 0.7109 - ICAE_classifier_precision: 0.7109 - ICAE_classifier_recall: 0.7109 - val_loss: 1.0000 - val_ICAE_decoder_loss: 0.0000e+00 - val_ICAE_classifier_loss: 0.0000e+00 - val_ICAE_decoder_mae: 0.0000e+00 - val_ICAE_classifier_accuracy: 0.0000e+00 - val_ICAE_classifier_precision: 0.0000e+00 - val_ICAE_classifier_recall: 0.0000e+00
# Epoch 64/100
# 24/24 [==============================] - 264s 11s/step - loss: 1.2698 - ICAE_decoder_loss: 0.0321 - ICAE_classifier_loss: 0.5404 - ICAE_decoder_mae: 0.1560 - ICAE_classifier_accuracy: 0.7292 - ICAE_classifier_precision: 0.7292 - ICAE_classifier_recall: 0.7292 - val_loss: 0.9657 - val_ICAE_decoder_loss: 0.0000e+00 - val_ICAE_classifier_loss: 0.0000e+00 - val_ICAE_decoder_mae: 0.0000e+00 - val_ICAE_classifier_accuracy: 0.0000e+00 - val_ICAE_classifier_precision: 0.0000e+00 - val_ICAE_classifier_recall: 0.0000e+00
# Epoch 65/100
# 24/24 [==============================] - 321s 13s/step - loss: 1.2388 - ICAE_decoder_loss: 0.0321 - ICAE_classifier_loss: 0.5465 - ICAE_decoder_mae: 0.1561 - ICAE_classifier_accuracy: 0.7201 - ICAE_classifier_precision: 0.7201 - ICAE_classifier_recall: 0.7201 - val_loss: 0.9321 - val_ICAE_decoder_loss: 0.0000e+00 - val_ICAE_classifier_loss: 0.0000e+00 - val_ICAE_decoder_mae: 0.0000e+00 - val_ICAE_classifier_accuracy: 0.0000e+00 - val_ICAE_classifier_precision: 0.0000e+00 - val_ICAE_classifier_recall: 0.0000e+00
# Epoch 66/100
# 24/24 [==============================] - 262s 11s/step - loss: 1.1956 - ICAE_decoder_loss: 0.0319 - ICAE_classifier_loss: 0.5266 - ICAE_decoder_mae: 0.1557 - ICAE_classifier_accuracy: 0.7461 - ICAE_classifier_precision: 0.7461 - ICAE_classifier_recall: 0.7461 - val_loss: 0.8990 - val_ICAE_decoder_loss: 0.0000e+00 - val_ICAE_classifier_loss: 0.0000e+00 - val_ICAE_decoder_mae: 0.0000e+00 - val_ICAE_classifier_accuracy: 0.0000e+00 - val_ICAE_classifier_precision: 0.0000e+00 - val_ICAE_classifier_recall: 0.0000e+00
# Epoch 67/100
# 24/24 [==============================] - 254s 11s/step - loss: 1.1667 - ICAE_decoder_loss: 0.0320 - ICAE_classifier_loss: 0.5337 - ICAE_decoder_mae: 0.1560 - ICAE_classifier_accuracy: 0.7318 - ICAE_classifier_precision: 0.7318 - ICAE_classifier_recall: 0.7318 - val_loss: 0.8671 - val_ICAE_decoder_loss: 0.0000e+00 - val_ICAE_classifier_loss: 0.0000e+00 - val_ICAE_decoder_mae: 0.0000e+00 - val_ICAE_classifier_accuracy: 0.0000e+00 - val_ICAE_classifier_precision: 0.0000e+00 - val_ICAE_classifier_recall: 0.0000e+00
# Epoch 68/100
# 24/24 [==============================] - 250s 10s/step - loss: 1.1337 - ICAE_decoder_loss: 0.0319 - ICAE_classifier_loss: 0.5313 - ICAE_decoder_mae: 0.1558 - ICAE_classifier_accuracy: 0.7253 - ICAE_classifier_precision: 0.7253 - ICAE_classifier_recall: 0.7253 - val_loss: 0.8358 - val_ICAE_decoder_loss: 0.0000e+00 - val_ICAE_classifier_loss: 0.0000e+00 - val_ICAE_decoder_mae: 0.0000e+00 - val_ICAE_classifier_accuracy: 0.0000e+00 - val_ICAE_classifier_precision: 0.0000e+00 - val_ICAE_classifier_recall: 0.0000e+00
# Epoch 69/100
# 24/24 [==============================] - 252s 10s/step - loss: 1.1038 - ICAE_decoder_loss: 0.0320 - ICAE_classifier_loss: 0.5335 - ICAE_decoder_mae: 0.1560 - ICAE_classifier_accuracy: 0.7305 - ICAE_classifier_precision: 0.7305 - ICAE_classifier_recall: 0.7305 - val_loss: 0.8051 - val_ICAE_decoder_loss: 0.0000e+00 - val_ICAE_classifier_loss: 0.0000e+00 - val_ICAE_decoder_mae: 0.0000e+00 - val_ICAE_classifier_accuracy: 0.0000e+00 - val_ICAE_classifier_precision: 0.0000e+00 - val_ICAE_classifier_recall: 0.0000e+00
# Epoch 70/100
# 24/24 [==============================] - 255s 11s/step - loss: 1.0702 - ICAE_decoder_loss: 0.0319 - ICAE_classifier_loss: 0.5266 - ICAE_decoder_mae: 0.1559 - ICAE_classifier_accuracy: 0.7461 - ICAE_classifier_precision: 0.7461 - ICAE_classifier_recall: 0.7461 - val_loss: 0.7754 - val_ICAE_decoder_loss: 0.0000e+00 - val_ICAE_classifier_loss: 0.0000e+00 - val_ICAE_decoder_mae: 0.0000e+00 - val_ICAE_classifier_accuracy: 0.0000e+00 - val_ICAE_classifier_precision: 0.0000e+00 - val_ICAE_classifier_recall: 0.0000e+00
# Epoch 71/100
# 24/24 [==============================] - 255s 11s/step - loss: 1.0413 - ICAE_decoder_loss: 0.0320 - ICAE_classifier_loss: 0.5275 - ICAE_decoder_mae: 0.1562 - ICAE_classifier_accuracy: 0.7383 - ICAE_classifier_precision: 0.7383 - ICAE_classifier_recall: 0.7383 - val_loss: 0.7466 - val_ICAE_decoder_loss: 0.0000e+00 - val_ICAE_classifier_loss: 0.0000e+00 - val_ICAE_decoder_mae: 0.0000e+00 - val_ICAE_classifier_accuracy: 0.0000e+00 - val_ICAE_classifier_precision: 0.0000e+00 - val_ICAE_classifier_recall: 0.0000e+00
# Epoch 72/100
# 24/24 [==============================] - 259s 11s/step - loss: 1.0108 - ICAE_decoder_loss: 0.0319 - ICAE_classifier_loss: 0.5236 - ICAE_decoder_mae: 0.1562 - ICAE_classifier_accuracy: 0.7435 - ICAE_classifier_precision: 0.7435 - ICAE_classifier_recall: 0.7435 - val_loss: 0.7183 - val_ICAE_decoder_loss: 0.0000e+00 - val_ICAE_classifier_loss: 0.0000e+00 - val_ICAE_decoder_mae: 0.0000e+00 - val_ICAE_classifier_accuracy: 0.0000e+00 - val_ICAE_classifier_precision: 0.0000e+00 - val_ICAE_classifier_recall: 0.0000e+00
# Epoch 73/100
# 24/24 [==============================] - 255s 11s/step - loss: 0.9856 - ICAE_decoder_loss: 0.0319 - ICAE_classifier_loss: 0.5289 - ICAE_decoder_mae: 0.1561 - ICAE_classifier_accuracy: 0.7383 - ICAE_classifier_precision: 0.7383 - ICAE_classifier_recall: 0.7383 - val_loss: 0.6908 - val_ICAE_decoder_loss: 0.0000e+00 - val_ICAE_classifier_loss: 0.0000e+00 - val_ICAE_decoder_mae: 0.0000e+00 - val_ICAE_classifier_accuracy: 0.0000e+00 - val_ICAE_classifier_precision: 0.0000e+00 - val_ICAE_classifier_recall: 0.0000e+00
# Epoch 74/100
# 24/24 [==============================] - 260s 11s/step - loss: 0.9584 - ICAE_decoder_loss: 0.0319 - ICAE_classifier_loss: 0.5291 - ICAE_decoder_mae: 0.1562 - ICAE_classifier_accuracy: 0.7435 - ICAE_classifier_precision: 0.7435 - ICAE_classifier_recall: 0.7435 - val_loss: 0.6642 - val_ICAE_decoder_loss: 0.0000e+00 - val_ICAE_classifier_loss: 0.0000e+00 - val_ICAE_decoder_mae: 0.0000e+00 - val_ICAE_classifier_accuracy: 0.0000e+00 - val_ICAE_classifier_precision: 0.0000e+00 - val_ICAE_classifier_recall: 0.0000e+00
# Epoch 75/100
# 24/24 [==============================] - 253s 11s/step - loss: 0.9334 - ICAE_decoder_loss: 0.0321 - ICAE_classifier_loss: 0.5324 - ICAE_decoder_mae: 0.1566 - ICAE_classifier_accuracy: 0.7292 - ICAE_classifier_precision: 0.7292 - ICAE_classifier_recall: 0.7292 - val_loss: 0.6374 - val_ICAE_decoder_loss: 0.0000e+00 - val_ICAE_classifier_loss: 0.0000e+00 - val_ICAE_decoder_mae: 0.0000e+00 - val_ICAE_classifier_accuracy: 0.0000e+00 - val_ICAE_classifier_precision: 0.0000e+00 - val_ICAE_classifier_recall: 0.0000e+00
# Epoch 76/100
# 24/24 [==============================] - 265s 11s/step - loss: 0.9050 - ICAE_decoder_loss: 0.0322 - ICAE_classifier_loss: 0.5276 - ICAE_decoder_mae: 0.1570 - ICAE_classifier_accuracy: 0.7253 - ICAE_classifier_precision: 0.7253 - ICAE_classifier_recall: 0.7253 - val_loss: 0.6116 - val_ICAE_decoder_loss: 0.0000e+00 - val_ICAE_classifier_loss: 0.0000e+00 - val_ICAE_decoder_mae: 0.0000e+00 - val_ICAE_classifier_accuracy: 0.0000e+00 - val_ICAE_classifier_precision: 0.0000e+00 - val_ICAE_classifier_recall: 0.0000e+00
# Epoch 77/100
# 24/24 [==============================] - 249s 10s/step - loss: 0.8737 - ICAE_decoder_loss: 0.0321 - ICAE_classifier_loss: 0.5160 - ICAE_decoder_mae: 0.1569 - ICAE_classifier_accuracy: 0.7487 - ICAE_classifier_precision: 0.7487 - ICAE_classifier_recall: 0.7487 - val_loss: 0.5865 - val_ICAE_decoder_loss: 0.0000e+00 - val_ICAE_classifier_loss: 0.0000e+00 - val_ICAE_decoder_mae: 0.0000e+00 - val_ICAE_classifier_accuracy: 0.0000e+00 - val_ICAE_classifier_precision: 0.0000e+00 - val_ICAE_classifier_recall: 0.0000e+00
# Epoch 78/100
# 24/24 [==============================] - 264s 11s/step - loss: 0.8563 - ICAE_decoder_loss: 0.0321 - ICAE_classifier_loss: 0.5307 - ICAE_decoder_mae: 0.1570 - ICAE_classifier_accuracy: 0.7448 - ICAE_classifier_precision: 0.7448 - ICAE_classifier_recall: 0.7448 - val_loss: 0.5619 - val_ICAE_decoder_loss: 0.0000e+00 - val_ICAE_classifier_loss: 0.0000e+00 - val_ICAE_decoder_mae: 0.0000e+00 - val_ICAE_classifier_accuracy: 0.0000e+00 - val_ICAE_classifier_precision: 0.0000e+00 - val_ICAE_classifier_recall: 0.0000e+00
# Epoch 79/100
# 24/24 [==============================] - 255s 11s/step - loss: 0.8294 - ICAE_decoder_loss: 0.0323 - ICAE_classifier_loss: 0.5254 - ICAE_decoder_mae: 0.1574 - ICAE_classifier_accuracy: 0.7266 - ICAE_classifier_precision: 0.7266 - ICAE_classifier_recall: 0.7266 - val_loss: 0.5381 - val_ICAE_decoder_loss: 0.0000e+00 - val_ICAE_classifier_loss: 0.0000e+00 - val_ICAE_decoder_mae: 0.0000e+00 - val_ICAE_classifier_accuracy: 0.0000e+00 - val_ICAE_classifier_precision: 0.0000e+00 - val_ICAE_classifier_recall: 0.0000e+00
# Epoch 80/100
# 24/24 [==============================] - 259s 11s/step - loss: 0.7953 - ICAE_decoder_loss: 0.0323 - ICAE_classifier_loss: 0.5038 - ICAE_decoder_mae: 0.1575 - ICAE_classifier_accuracy: 0.7565 - ICAE_classifier_precision: 0.7565 - ICAE_classifier_recall: 0.7565 - val_loss: 0.5154 - val_ICAE_decoder_loss: 0.0000e+00 - val_ICAE_classifier_loss: 0.0000e+00 - val_ICAE_decoder_mae: 0.0000e+00 - val_ICAE_classifier_accuracy: 0.0000e+00 - val_ICAE_classifier_precision: 0.0000e+00 - val_ICAE_classifier_recall: 0.0000e+00
# Epoch 81/100
# 24/24 [==============================] - 250s 10s/step - loss: 0.7823 - ICAE_decoder_loss: 0.0322 - ICAE_classifier_loss: 0.5228 - ICAE_decoder_mae: 0.1574 - ICAE_classifier_accuracy: 0.7474 - ICAE_classifier_precision: 0.7474 - ICAE_classifier_recall: 0.7474 - val_loss: 0.4930 - val_ICAE_decoder_loss: 0.0000e+00 - val_ICAE_classifier_loss: 0.0000e+00 - val_ICAE_decoder_mae: 0.0000e+00 - val_ICAE_classifier_accuracy: 0.0000e+00 - val_ICAE_classifier_precision: 0.0000e+00 - val_ICAE_classifier_recall: 0.0000e+00
# Epoch 82/100
# 24/24 [==============================] - 262s 11s/step - loss: 0.7619 - ICAE_decoder_loss: 0.0325 - ICAE_classifier_loss: 0.5262 - ICAE_decoder_mae: 0.1580 - ICAE_classifier_accuracy: 0.7370 - ICAE_classifier_precision: 0.7370 - ICAE_classifier_recall: 0.7370 - val_loss: 0.4712 - val_ICAE_decoder_loss: 0.0000e+00 - val_ICAE_classifier_loss: 0.0000e+00 - val_ICAE_decoder_mae: 0.0000e+00 - val_ICAE_classifier_accuracy: 0.0000e+00 - val_ICAE_classifier_precision: 0.0000e+00 - val_ICAE_classifier_recall: 0.0000e+00
# Epoch 83/100
# 24/24 [==============================] - 261s 11s/step - loss: 0.7334 - ICAE_decoder_loss: 0.0325 - ICAE_classifier_loss: 0.5125 - ICAE_decoder_mae: 0.1582 - ICAE_classifier_accuracy: 0.7552 - ICAE_classifier_precision: 0.7552 - ICAE_classifier_recall: 0.7552 - val_loss: 0.4499 - val_ICAE_decoder_loss: 0.0000e+00 - val_ICAE_classifier_loss: 0.0000e+00 - val_ICAE_decoder_mae: 0.0000e+00 - val_ICAE_classifier_accuracy: 0.0000e+00 - val_ICAE_classifier_precision: 0.0000e+00 - val_ICAE_classifier_recall: 0.0000e+00
# Epoch 84/100
# 24/24 [==============================] - 261s 11s/step - loss: 0.7127 - ICAE_decoder_loss: 0.0325 - ICAE_classifier_loss: 0.5131 - ICAE_decoder_mae: 0.1582 - ICAE_classifier_accuracy: 0.7409 - ICAE_classifier_precision: 0.7409 - ICAE_classifier_recall: 0.7409 - val_loss: 0.4291 - val_ICAE_decoder_loss: 0.0000e+00 - val_ICAE_classifier_loss: 0.0000e+00 - val_ICAE_decoder_mae: 0.0000e+00 - val_ICAE_classifier_accuracy: 0.0000e+00 - val_ICAE_classifier_precision: 0.0000e+00 - val_ICAE_classifier_recall: 0.0000e+00
# Epoch 85/100
# 24/24 [==============================] - 253s 11s/step - loss: 0.6923 - ICAE_decoder_loss: 0.0326 - ICAE_classifier_loss: 0.5131 - ICAE_decoder_mae: 0.1583 - ICAE_classifier_accuracy: 0.7591 - ICAE_classifier_precision: 0.7591 - ICAE_classifier_recall: 0.7591 - val_loss: 0.4092 - val_ICAE_decoder_loss: 0.0000e+00 - val_ICAE_classifier_loss: 0.0000e+00 - val_ICAE_decoder_mae: 0.0000e+00 - val_ICAE_classifier_accuracy: 0.0000e+00 - val_ICAE_classifier_precision: 0.0000e+00 - val_ICAE_classifier_recall: 0.0000e+00
# Epoch 86/100
# 24/24 [==============================] - 257s 11s/step - loss: 0.6738 - ICAE_decoder_loss: 0.0326 - ICAE_classifier_loss: 0.5158 - ICAE_decoder_mae: 0.1585 - ICAE_classifier_accuracy: 0.7461 - ICAE_classifier_precision: 0.7461 - ICAE_classifier_recall: 0.7461 - val_loss: 0.3894 - val_ICAE_decoder_loss: 0.0000e+00 - val_ICAE_classifier_loss: 0.0000e+00 - val_ICAE_decoder_mae: 0.0000e+00 - val_ICAE_classifier_accuracy: 0.0000e+00 - val_ICAE_classifier_precision: 0.0000e+00 - val_ICAE_classifier_recall: 0.0000e+00
# Epoch 87/100
# 24/24 [==============================] - 249s 10s/step - loss: 0.6486 - ICAE_decoder_loss: 0.0327 - ICAE_classifier_loss: 0.5040 - ICAE_decoder_mae: 0.1588 - ICAE_classifier_accuracy: 0.7578 - ICAE_classifier_precision: 0.7578 - ICAE_classifier_recall: 0.7578 - val_loss: 0.3704 - val_ICAE_decoder_loss: 0.0000e+00 - val_ICAE_classifier_loss: 0.0000e+00 - val_ICAE_decoder_mae: 0.0000e+00 - val_ICAE_classifier_accuracy: 0.0000e+00 - val_ICAE_classifier_precision: 0.0000e+00 - val_ICAE_classifier_recall: 0.0000e+00
# Epoch 88/100
# 24/24 [==============================] - 269s 11s/step - loss: 0.6342 - ICAE_decoder_loss: 0.0328 - ICAE_classifier_loss: 0.5122 - ICAE_decoder_mae: 0.1590 - ICAE_classifier_accuracy: 0.7500 - ICAE_classifier_precision: 0.7500 - ICAE_classifier_recall: 0.7500 - val_loss: 0.3525 - val_ICAE_decoder_loss: 0.0000e+00 - val_ICAE_classifier_loss: 0.0000e+00 - val_ICAE_decoder_mae: 0.0000e+00 - val_ICAE_classifier_accuracy: 0.0000e+00 - val_ICAE_classifier_precision: 0.0000e+00 - val_ICAE_classifier_recall: 0.0000e+00
# Epoch 89/100
# 24/24 [==============================] - 258s 11s/step - loss: 0.6124 - ICAE_decoder_loss: 0.0328 - ICAE_classifier_loss: 0.5043 - ICAE_decoder_mae: 0.1592 - ICAE_classifier_accuracy: 0.7669 - ICAE_classifier_precision: 0.7669 - ICAE_classifier_recall: 0.7669 - val_loss: 0.3346 - val_ICAE_decoder_loss: 0.0000e+00 - val_ICAE_classifier_loss: 0.0000e+00 - val_ICAE_decoder_mae: 0.0000e+00 - val_ICAE_classifier_accuracy: 0.0000e+00 - val_ICAE_classifier_precision: 0.0000e+00 - val_ICAE_classifier_recall: 0.0000e+00
# Epoch 90/100
# 24/24 [==============================] - 249s 10s/step - loss: 0.5999 - ICAE_decoder_loss: 0.0329 - ICAE_classifier_loss: 0.5141 - ICAE_decoder_mae: 0.1594 - ICAE_classifier_accuracy: 0.7500 - ICAE_classifier_precision: 0.7500 - ICAE_classifier_recall: 0.7500 - val_loss: 0.3176 - val_ICAE_decoder_loss: 0.0000e+00 - val_ICAE_classifier_loss: 0.0000e+00 - val_ICAE_decoder_mae: 0.0000e+00 - val_ICAE_classifier_accuracy: 0.0000e+00 - val_ICAE_classifier_precision: 0.0000e+00 - val_ICAE_classifier_recall: 0.0000e+00
# Epoch 91/100
# 24/24 [==============================] - 254s 11s/step - loss: 0.5807 - ICAE_decoder_loss: 0.0329 - ICAE_classifier_loss: 0.5085 - ICAE_decoder_mae: 0.1595 - ICAE_classifier_accuracy: 0.7591 - ICAE_classifier_precision: 0.7591 - ICAE_classifier_recall: 0.7591 - val_loss: 0.3017 - val_ICAE_decoder_loss: 0.0000e+00 - val_ICAE_classifier_loss: 0.0000e+00 - val_ICAE_decoder_mae: 0.0000e+00 - val_ICAE_classifier_accuracy: 0.0000e+00 - val_ICAE_classifier_precision: 0.0000e+00 - val_ICAE_classifier_recall: 0.0000e+00
# Epoch 92/100
# 24/24 [==============================] - 260s 11s/step - loss: 0.5678 - ICAE_decoder_loss: 0.0330 - ICAE_classifier_loss: 0.5143 - ICAE_decoder_mae: 0.1596 - ICAE_classifier_accuracy: 0.7422 - ICAE_classifier_precision: 0.7422 - ICAE_classifier_recall: 0.7422 - val_loss: 0.2861 - val_ICAE_decoder_loss: 0.0000e+00 - val_ICAE_classifier_loss: 0.0000e+00 - val_ICAE_decoder_mae: 0.0000e+00 - val_ICAE_classifier_accuracy: 0.0000e+00 - val_ICAE_classifier_precision: 0.0000e+00 - val_ICAE_classifier_recall: 0.0000e+00
# Epoch 93/100
# 24/24 [==============================] - 249s 10s/step - loss: 0.5440 - ICAE_decoder_loss: 0.0330 - ICAE_classifier_loss: 0.4973 - ICAE_decoder_mae: 0.1598 - ICAE_classifier_accuracy: 0.7539 - ICAE_classifier_precision: 0.7539 - ICAE_classifier_recall: 0.7539 - val_loss: 0.2713 - val_ICAE_decoder_loss: 0.0000e+00 - val_ICAE_classifier_loss: 0.0000e+00 - val_ICAE_decoder_mae: 0.0000e+00 - val_ICAE_classifier_accuracy: 0.0000e+00 - val_ICAE_classifier_precision: 0.0000e+00 - val_ICAE_classifier_recall: 0.0000e+00
# Epoch 94/100
# 24/24 [==============================] - 245s 10s/step - loss: 0.5317 - ICAE_decoder_loss: 0.0329 - ICAE_classifier_loss: 0.5017 - ICAE_decoder_mae: 0.1595 - ICAE_classifier_accuracy: 0.7565 - ICAE_classifier_precision: 0.7565 - ICAE_classifier_recall: 0.7565 - val_loss: 0.2569 - val_ICAE_decoder_loss: 0.0000e+00 - val_ICAE_classifier_loss: 0.0000e+00 - val_ICAE_decoder_mae: 0.0000e+00 - val_ICAE_classifier_accuracy: 0.0000e+00 - val_ICAE_classifier_precision: 0.0000e+00 - val_ICAE_classifier_recall: 0.0000e+00
# Epoch 95/100
# 24/24 [==============================] - 256s 11s/step - loss: 0.5199 - ICAE_decoder_loss: 0.0331 - ICAE_classifier_loss: 0.5057 - ICAE_decoder_mae: 0.1599 - ICAE_classifier_accuracy: 0.7578 - ICAE_classifier_precision: 0.7578 - ICAE_classifier_recall: 0.7578 - val_loss: 0.2436 - val_ICAE_decoder_loss: 0.0000e+00 - val_ICAE_classifier_loss: 0.0000e+00 - val_ICAE_decoder_mae: 0.0000e+00 - val_ICAE_classifier_accuracy: 0.0000e+00 - val_ICAE_classifier_precision: 0.0000e+00 - val_ICAE_classifier_recall: 0.0000e+00
# Epoch 96/100
# 24/24 [==============================] - 256s 11s/step - loss: 0.5058 - ICAE_decoder_loss: 0.0331 - ICAE_classifier_loss: 0.5035 - ICAE_decoder_mae: 0.1600 - ICAE_classifier_accuracy: 0.7500 - ICAE_classifier_precision: 0.7500 - ICAE_classifier_recall: 0.7500 - val_loss: 0.2308 - val_ICAE_decoder_loss: 0.0000e+00 - val_ICAE_classifier_loss: 0.0000e+00 - val_ICAE_decoder_mae: 0.0000e+00 - val_ICAE_classifier_accuracy: 0.0000e+00 - val_ICAE_classifier_precision: 0.0000e+00 - val_ICAE_classifier_recall: 0.0000e+00
# Epoch 97/100
# 24/24 [==============================] - 257s 11s/step - loss: 0.4981 - ICAE_decoder_loss: 0.0331 - ICAE_classifier_loss: 0.5132 - ICAE_decoder_mae: 0.1602 - ICAE_classifier_accuracy: 0.7448 - ICAE_classifier_precision: 0.7448 - ICAE_classifier_recall: 0.7448 - val_loss: 0.2185 - val_ICAE_decoder_loss: 0.0000e+00 - val_ICAE_classifier_loss: 0.0000e+00 - val_ICAE_decoder_mae: 0.0000e+00 - val_ICAE_classifier_accuracy: 0.0000e+00 - val_ICAE_classifier_precision: 0.0000e+00 - val_ICAE_classifier_recall: 0.0000e+00
# Epoch 98/100
# 24/24 [==============================] - 247s 10s/step - loss: 0.4811 - ICAE_decoder_loss: 0.0333 - ICAE_classifier_loss: 0.5035 - ICAE_decoder_mae: 0.1604 - ICAE_classifier_accuracy: 0.7552 - ICAE_classifier_precision: 0.7552 - ICAE_classifier_recall: 0.7552 - val_loss: 0.2070 - val_ICAE_decoder_loss: 0.0000e+00 - val_ICAE_classifier_loss: 0.0000e+00 - val_ICAE_decoder_mae: 0.0000e+00 - val_ICAE_classifier_accuracy: 0.0000e+00 - val_ICAE_classifier_precision: 0.0000e+00 - val_ICAE_classifier_recall: 0.0000e+00
# Epoch 99/100
# 24/24 [==============================] - 247s 10s/step - loss: 0.4710 - ICAE_decoder_loss: 0.0333 - ICAE_classifier_loss: 0.5056 - ICAE_decoder_mae: 0.1606 - ICAE_classifier_accuracy: 0.7513 - ICAE_classifier_precision: 0.7513 - ICAE_classifier_recall: 0.7513 - val_loss: 0.1958 - val_ICAE_decoder_loss: 0.0000e+00 - val_ICAE_classifier_loss: 0.0000e+00 - val_ICAE_decoder_mae: 0.0000e+00 - val_ICAE_classifier_accuracy: 0.0000e+00 - val_ICAE_classifier_precision: 0.0000e+00 - val_ICAE_classifier_recall: 0.0000e+00
# Epoch 100/100
# 24/24 [==============================] - 246s 10s/step - loss: 0.4528 - ICAE_decoder_loss: 0.0333 - ICAE_classifier_loss: 0.4902 - ICAE_decoder_mae: 0.1607 - ICAE_classifier_accuracy: 0.7643 - ICAE_classifier_precision: 0.7643 - ICAE_classifier_recall: 0.7643 - val_loss: 0.1856 - val_ICAE_decoder_loss: 0.0000e+00 - val_ICAE_classifier_loss: 0.0000e+00 - val_ICAE_decoder_mae: 0.0000e+00 - val_ICAE_classifier_accuracy: 0.0000e+00 - val_ICAE_classifier_precision: 0.0000e+00 - val_ICAE_classifier_recall: 0.0000e+00
# Time taken: 446.93 minutes

# %% [markdown]
# #### Initial Results

# %%
print('Time taken:', duration, 'minutes')
# Out:
# Time taken: 446.93 minutes

# %%
test_generator = MyDataGenerator(test_list, processed_dir, batch_size=14, 
                                 augment=False, to_fit=False)

# %%
ae_pred = ICAE_autoencoder.predict(test_generator)

# %%
np.sum(np.round(ae_pred[1]),axis=0)
# Out:
# array([17., 81.], dtype=float32)

# %%
train_loss = history_ICAE.history['loss']
val_loss = history_ICAE.history['val_loss']
epochs = range(100)
plt.figure()
plt.plot(epochs, train_loss, 'b', label='Training loss')
plt.plot(epochs, val_loss, 'r', label='Validation loss')
plt.title('Training and validation loss')
plt.legend()
plt.show()

# %% [markdown]
# #### Further Analysis

# %%
import os

# %%
# %cd /content/drive/My Drive/AD_MRI/outputs_AC
# Out:
# /content/drive/.shortcut-targets-by-id/1oU0ruELKPJf457X2y4uyGIpFkyyxaQyv/AD_MRI/outputs_AC

# %%
# %pwd
# Out:
# '/content/drive/.shortcut-targets-by-id/1oU0ruELKPJf457X2y4uyGIpFkyyxaQyv/AD_MRI/outputs_AC'

# %%
% ls 'ICAE_experimentation_AC_1205.100-0.19.h5' # file seems to be corrupted. Reverting to epoch 99 file.
# Out:
# ICAE_experimentation_AC_1205.100-0.19.h5

# %%
ICAE_autoencoder.load_weights('ICAE_experimentation_AC_1205.99-0.20.h5')

# %%
start_time = time.time()

history_ICAE = ICAE_autoencoder.fit(train_generator, epochs=1, 
                                    validation_data=val_generator, 
                                    shuffle=True, use_multiprocessing=False, 
                                    callbacks=my_callbacks)
# given the warning, if this hangs, try default use_multiprocessing=False

duration = round((time.time() - start_time) / 60, 2)

print('Time taken:', duration, 'minutes')
# Out:
# 24/24 [==============================] - 1003s 42s/step - loss: 0.4598 - ICAE_decoder_loss: 0.0333 - ICAE_classifier_loss: 0.5043 - ICAE_decoder_mae: 0.1606 - ICAE_classifier_accuracy: 0.7604 - ICAE_classifier_precision: 0.7604 - ICAE_classifier_recall: 0.7604 - val_loss: 0.1856 - val_ICAE_decoder_loss: 0.0000e+00 - val_ICAE_classifier_loss: 0.0000e+00 - val_ICAE_decoder_mae: 0.0000e+00 - val_ICAE_classifier_accuracy: 0.0000e+00 - val_ICAE_classifier_precision: 0.0000e+00 - val_ICAE_classifier_recall: 0.0000e+00
# Time taken: 18.22 minutes

# %%
from sklearn.metrics import classification_report, accuracy_score, roc_auc_score

test_generator = MyDataGenerator(test_list, processed_dir, batch_size=14, 
                                 augment=False, to_fit=False)

ae_pred = ICAE_autoencoder.predict(test_generator)

# %%
print("acc: ", accuracy_score(labels_to_categorical(val_label), np.round(ae_pred[1])))
print(classification_report(labels_to_categorical(val_label), np.round(ae_pred[1])))
# Out:
# acc:  0.5612244897959183
#               precision    recall  f1-score   support
#
#            0       0.32      0.20      0.25        35
#            1       0.63      0.76      0.69        63
#
#    micro avg       0.56      0.56      0.56        98
#    macro avg       0.47      0.48      0.47        98
# weighted avg       0.52      0.56      0.53        98
#  samples avg       0.56      0.56      0.56        98

# %%
print("AUC", roc_auc_score(labels_to_categorical(test_label), ae_pred[1]))
# Out:
# AUC 0.5488351254480286

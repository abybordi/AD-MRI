# %%
# %matplotlib inline 
from matplotlib import pyplot as plt
import numpy as np
import pandas as pd
import pickle
import warnings
import tensorflow as tf
import random
import scipy
import cv2
from tensorflow.keras.utils import Sequence
from tensorflow.keras.utils import to_categorical
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.utils import class_weight
from tensorflow import keras
from tensorflow.keras import backend as K
from tensorflow.keras.callbacks import TensorBoard
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import Dense, Conv3D, MaxPool3D, Dropout, \
        Flatten, Conv3DTranspose, UpSampling3D, Reshape, Input, concatenate
from tensorflow.keras.regularizers import l1_l2
from google.colab import drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
import tensorflow as tf
print('Tensorflow version:', tf.__version__)
# Out:
# Tensorflow version: 2.2.0

# %% [markdown]
# #### Create Train/Test Subset

# %%
# %cd /content/drive/My Drive/AD_MRI

# Load list of records
with open('AD_MRI_Master', 'rb') as f:
    master_list = pickle.load(f)
    
master_sheet = pd.DataFrame.from_dict(master_list, orient='index')
display(master_sheet.head())
print()

# Split: 80% train, 10% validation, 10% test
train_list, val_list, train_label, val_label = \
        train_test_split(master_sheet.subject.values, 
                         master_sheet.diagnosis.values, 
                         random_state = 1337, 
                         test_size=0.10)
        
train_list,test_list,train_label,test_label = \
        train_test_split(train_list, 
                         train_label, 
                         random_state = 0, 
                         test_size=0.10)

# Check for ratios of AD to NC to be consistent among sets
AD_count = 0
for lab in train_label:
    if lab == 'AD':
        AD_count +=1
print('train_ratio AD: ', round(AD_count/len(train_label), 3))

AD_count = 0
for lab in val_label:
    if lab == 'AD':
        AD_count +=1
print('val_ratio AD: ', round(AD_count/len(val_label), 3))

AD_count = 0
for lab in test_label:
    if lab == 'AD':
        AD_count +=1
print('test_ratio AD: ', round(AD_count/len(test_label), 3))

print('\nNumber of records\ntrain:', len(train_list), 
      '\nvalidation:', len(val_list), '\ntest:', len(test_list))
# Out:
# /content/drive/.shortcut-targets-by-id/1oU0ruELKPJf457X2y4uyGIpFkyyxaQyv/AD_MRI
#            subject   age diagnosis            scan_ID
# OAS30001  OAS30001  65.0        CN  OAS30001_MR_d0129
# OAS30002  OAS30002  68.0        CN  OAS30002_MR_d0371
# OAS30003  OAS30003  60.0        CN  OAS30003_MR_d0558
# OAS30004  OAS30004  58.0        CN  OAS30004_MR_d1101
# OAS30005  OAS30005  48.0        CN  OAS30005_MR_d0143
# train_ratio AD:  0.367
# val_ratio AD:  0.367
# test_ratio AD:  0.371
#
# Number of records
# train: 793
# validation: 98
# test: 89

# %% [markdown]
# #### Create Generator

# %%
processed_dir = '/content/drive/My Drive/AD_MRI/PROCESSED/'

# custom data generator.
import random
import scipy
import numpy as np
import cv2
from tensorflow.keras.utils import Sequence
from tensorflow.keras.utils import to_categorical
from sklearn.preprocessing import LabelEncoder
import random

import scipy


def labels_to_categorical(labels):
    le = LabelEncoder()
    le.fit(["CN", "AD"])
    num_lab=to_categorical(le.transform(labels),num_classes=2)
    return num_lab

def my_minmax(z):
    return (z-np.min(z))/(np.max(z)-np.min(z))

# Custom data generator
class MyDataGenerator(Sequence):
    """Generates data for Keras Sequence based data generator. 
    Suitable for building data generator for training and prediction.
    """
    def __init__(self, list_IDs, processed_dir, augment=False, 
                 to_fit=True, batch_size=32, dim=(120, 160, 120, 1),
                 n_classes=2, shuffle=True, ventricles_only=True, 
                 slice_start=50, slice_end=66, sample_weight=None):
        """Initialization
        :param list_IDs: list of all 'label' PATHS
        :param processed_dir: path to directory of processed images
        :param augment
        :param to_fit: True to return X and y, False to return X only
        :param batch_size: batch size at each iteration
        :param dim: tuple indicating image dimension
        :param n_classes: number of output masks
        :param shuffle: True to shuffle label indexes after every epoch
        :param ventricles_only: reduce dimensions to relevant slice
        """
        self.list_IDs = list_IDs
        self.processed_dir = processed_dir
        self.augment = augment
        self.to_fit = to_fit
        self.batch_size = batch_size
        self.dim = dim
        self.n_classes = n_classes
        self.shuffle = shuffle
        self.ventricles_only = ventricles_only
        self.on_epoch_end()
        self.slice_start = slice_start
        self.slice_end = slice_end
        if self.ventricles_only == False:
            self.slice_size = 120
        else:
            self.slice_size = slice_end - slice_start
        self.sample_weight = sample_weight
        # sample_weight needs to be provided if to_fit=True


    def __len__(self):
        """Denotes the number of batches per epoch
        :return: number of batches per epoch
        """
        return int(np.floor(len(self.list_IDs) / self.batch_size))


    def __getitem__(self, index):
        """Generate one batch of data
        :param index: index of the batch
        :return: X and y when fitting. X only when predicting
        """
        # Generate indexes of the batch
        indexes = self.indexes[index 
                               * self.batch_size:(index + 1) 
                               * self.batch_size]

        # Find list of IDs
        list_IDs_temp = [self.list_IDs[k] for k in indexes]
        
        # Generate data
        X, y = self._load_data(list_IDs_temp)
        X = my_minmax(np.float32(X))
        if self.ventricles_only == True:
          X = X[:, :, :, self.slice_start:self.slice_end, :]
          w_temp = np.asarray([self.sample_weight[k] for k in indexes])
        if self.to_fit:
            y = {'CAE_classifier': y, 'CAE_decoder': X}
            w = {'CAE_classifier': w_temp,
                 'CAE_decoder':np.ones(np.shape(X))}
            return X, y, w
        else:
            return X


    def on_epoch_end(self):
        """Updates indexes after each epoch
        """
        self.indexes = np.arange(len(self.list_IDs))
        if self.shuffle == True:
            np.random.shuffle(self.indexes)


    def _load_data(self, list_IDs_temp):
        """Generates data containing batch_size images
        :param list_IDs_temp: list of label ids to load
        :return: batch of images
        """
        # Initialization
        X = np.empty((self.batch_size, *self.dim))
        y = np.empty((self.batch_size, self.n_classes), dtype=int)
        
        # Generate data
        for i, ID in enumerate(list_IDs_temp):
            
            # start X
            with open(self.processed_dir+ID+'_data','rb') as f:
                data = pickle.load(f)
                
            # third dimension = 120, error using self.slice_size for value 16
            x_reshape= np.reshape(data['image'], (120, 160, 120, 1))
            if self.augment == True:
                x_reshape = scipy.ndimage.rotate(x_reshape, 
                                axes=random.choice([(0, 1), (0, 2), (1, 2)]), 
                                angle=random.choice([360-15, 15,0]), 
                                reshape=False)
            X[i,] = x_reshape
            
            #start y
            y[i,] = labels_to_categorical([data['diagnosis']])

        return X, y

# %%
print(labels_to_categorical(["CN"]))

balancing_weights = class_weight.compute_sample_weight('balanced',train_label)
print(balancing_weights[0],train_label[0])
print(balancing_weights[1],train_label[1])


# usage:
processed_dir = '/content/drive/My Drive/AD_MRI/PROCESSED/'
mdg = MyDataGenerator(test_list, processed_dir, to_fit=True, augment=True, 
                      sample_weight=balancing_weights,batch_size=2)

#X, pred, weights = mdg.__getitem__(0) #without .__getitem__ obviously
# Out:
# [[0. 1.]]
# 1.3625429553264605 AD
# 0.7898406374501992 CN

# %% [markdown]
# #### Building CAE Encoder

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import backend as K
from tensorflow.keras.callbacks import TensorBoard
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import Dense, Conv3D, MaxPool3D, Dropout, \
    Flatten, Conv3DTranspose, UpSampling3D, Reshape
from tensorflow.keras.layers import Input

# %%
dropout_rate = 0.5
input_img = Input(shape=(120, 160, 16, 1), name='Input')
print('\ninput shape:', input_img.shape)

x = Conv3D(10, (3, 3, 3), activation='relu', padding='same', 
           name='Convolution_1')(input_img)
x = MaxPool3D((2, 2, 2), name='MaxPooling_1')(x)
x = Dropout(dropout_rate, name='DropOut_1')(x)

x = Conv3D(10, (3, 3, 3), activation='relu', padding='same', 
           name='Convolution_2')(x)
x = MaxPool3D((2, 2, 2), name='MaxPooling_2')(x)
x = Dropout(dropout_rate, name='DropOut_2')(x)

x = Conv3D(10, (3, 3, 3), activation='relu', padding='same', 
           name='Convolution_3')(x)
x = MaxPool3D((2, 2, 2), name='MaxPooling_3')(x)
x = Dropout(dropout_rate, name='DropOut_3')(x)

encoded = x
encoded_shape = K.int_shape(encoded)
print('output shape:', encoded_shape, '\n')

CAE_encoder = Model(input_img, encoded, name='CAE_encoder')
CAE_encoder.summary()
# Out:
# input shape: (None, 120, 160, 16, 1)
# output shape: (None, 15, 20, 2, 10)
#
# Model: "CAE_encoder"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# Input (InputLayer)           [(None, 120, 160, 16, 1)] 0
# _________________________________________________________________
# Convolution_1 (Conv3D)       (None, 120, 160, 16, 10)  280
# _________________________________________________________________
# MaxPooling_1 (MaxPooling3D)  (None, 60, 80, 8, 10)     0
# _________________________________________________________________
# DropOut_1 (Dropout)          (None, 60, 80, 8, 10)     0
# _________________________________________________________________
# Convolution_2 (Conv3D)       (None, 60, 80, 8, 10)     2710
# _________________________________________________________________
# MaxPooling_2 (MaxPooling3D)  (None, 30, 40, 4, 10)     0
# _________________________________________________________________
# DropOut_2 (Dropout)          (None, 30, 40, 4, 10)     0
# _________________________________________________________________
# Convolution_3 (Conv3D)       (None, 30, 40, 4, 10)     2710
# _________________________________________________________________
# MaxPooling_3 (MaxPooling3D)  (None, 15, 20, 2, 10)     0
# _________________________________________________________________
# DropOut_3 (Dropout)          (None, 15, 20, 2, 10)     0
# =================================================================
# Total params: 5,700
# Trainable params: 5,700
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# #### Building CAE Decoder

# %%
encoded_shape
# Out:
# (None, 15, 20, 2, 10)

# %%
encoded_input = Input(shape=(encoded_shape[1],encoded_shape[2], 
                             encoded_shape[3], encoded_shape[4],), 
                      name='Encoded')

print('\ninput shape:', encoded_input.shape)
x = encoded_input

x = Conv3DTranspose(10, (3, 3, 3), activation='relu', padding='same', 
                    name='Convolution_3')(x)
x = UpSampling3D((2, 2, 2), name='UpSampling_3')(x)
x = Dropout(dropout_rate, name='DropOut_3')(x)

x = Conv3DTranspose(10, (3, 3, 3), activation='relu', padding='same', 
                    name='Convolution_2')(x)
x = UpSampling3D((2, 2, 2), name='UpSampling_2')(x)
x = Dropout(dropout_rate, name='DropOut_2')(x)

x = Conv3DTranspose(10, (3, 3, 3), activation='relu', padding='same', 
                    name='Convolution_1')(x)
x = UpSampling3D((2, 2, 2), name='UpSampling_1')(x)
x = Dropout(dropout_rate, name='DropOut_1')(x)

decoded = Conv3DTranspose(1, (3, 3, 3), activation='sigmoid', padding='same', 
                          name='Output')(x)

print('output shape:', K.int_shape(decoded), '\n')

CAE_decoder = Model(encoded_input, decoded, name='CAE_decoder')
CAE_decoder.summary()
# Out:
# input shape: (None, 15, 20, 2, 10)
# output shape: (None, 120, 160, 16, 1)
#
# Model: "CAE_decoder"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# Encoded (InputLayer)         [(None, 15, 20, 2, 10)]   0
# _________________________________________________________________
# Convolution_3 (Conv3DTranspo (None, 15, 20, 2, 10)     2710
# _________________________________________________________________
# UpSampling_3 (UpSampling3D)  (None, 30, 40, 4, 10)     0
# _________________________________________________________________
# DropOut_3 (Dropout)          (None, 30, 40, 4, 10)     0
# _________________________________________________________________
# Convolution_2 (Conv3DTranspo (None, 30, 40, 4, 10)     2710
# _________________________________________________________________
# UpSampling_2 (UpSampling3D)  (None, 60, 80, 8, 10)     0
# _________________________________________________________________
# DropOut_2 (Dropout)          (None, 60, 80, 8, 10)     0
# _________________________________________________________________
# Convolution_1 (Conv3DTranspo (None, 60, 80, 8, 10)     2710
# _________________________________________________________________
# UpSampling_1 (UpSampling3D)  (None, 120, 160, 16, 10)  0
# _________________________________________________________________
# DropOut_1 (Dropout)          (None, 120, 160, 16, 10)  0
# _________________________________________________________________
# Output (Conv3DTranspose)     (None, 120, 160, 16, 1)   271
# =================================================================
# Total params: 8,401
# Trainable params: 8,401
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# #### Building CAE Classifier

# %%
# CAE Classifier

encoded_input = Input(shape=(encoded_shape[1], encoded_shape[2], 
                             encoded_shape[3], encoded_shape[4],), 
                      name='Encoded')

y = encoded_input

y = Flatten(name='Flatten')(y)
y = Dense(1024, activation='selu', name='SELU_1')(y)
y = Dense(64, activation='selu', name='SELU_2')(y)
y = Dense(2, activation='softmax', name='Prediction')(y)

CAE_pred = y

CAE_classifier = Model(encoded_input, CAE_pred, name='CAE_classifier')
CAE_classifier.summary()
# Out:
# Model: "CAE_classifier"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# Encoded (InputLayer)         [(None, 15, 20, 2, 10)]   0
# _________________________________________________________________
# Flatten (Flatten)            (None, 6000)              0
# _________________________________________________________________
# SELU_1 (Dense)               (None, 1024)              6145024
# _________________________________________________________________
# SELU_2 (Dense)               (None, 64)                65600
# _________________________________________________________________
# Prediction (Dense)           (None, 2)                 130
# =================================================================
# Total params: 6,210,754
# Trainable params: 6,210,754
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# #### Building CAE Autoencoder

# %%
CAE_autoencoder = Model(inputs=input_img, 
                         outputs=[CAE_decoder(CAE_encoder(input_img)), 
                                  CAE_classifier(CAE_encoder(input_img))],
                   name='CAE_autoencoder')
CAE_autoencoder.summary()
# Out:
# Model: "CAE_autoencoder"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# Input (InputLayer)              [(None, 120, 160, 16 0
# __________________________________________________________________________________________________
# CAE_encoder (Model)             (None, 15, 20, 2, 10 5700        Input[0][0]
#                                                                  Input[0][0]
# __________________________________________________________________________________________________
# CAE_decoder (Model)             (None, 120, 160, 16, 8401        CAE_encoder[1][0]
# __________________________________________________________________________________________________
# CAE_classifier (Model)          (None, 2)            6210754     CAE_encoder[2][0]
# ==================================================================================================
# Total params: 6,224,855
# Trainable params: 6,224,855
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %% [markdown]
# #### Building ICAE Encoder

# %%
def inception_module(input, filter_operation):
    """
    filter_operation is a list of inception operations for:
        1x1x1 kernel, 
        1x1x1 then 3x3x3 kernels, 
        1x1x1 then 3x3x3 then 3x3x3 kernels, 
        and 3x3x3 maxpooling then 1x1x1 kernels, 
            respectively.
    """
    
    # According to Nature paper (Oh et. al.), l1 and l2 values of 10e-4 
    # performed the best from experimentation with 0.01, 0.001, 0.0001, 0.00001 
    # values.
    l1_value = 10e-4 #10e-4
    l2_value = 10e-4 #10e-4

    # Branch A
    branch_1x1x1 = Conv3D(filter_operation[0], kernel_size=(1, 1, 1), 
                          activation='relu', padding='same', 
                          kernel_regularizer=l1_l2(l1_value, l2_value), 
                          name='Branch_A_1x1x1')(input)

    # Branch B
    branch_3x3x3_initial = Conv3D(filter_operation[1], kernel_size=(1, 1, 1), 
                                  activation='relu', padding='same', 
                                  kernel_regularizer=l1_l2(l1_value, l2_value), 
                                  name='Branch_B_1x1x1')(input)
    branch_3x3x3 = Conv3D(filter_operation[1], kernel_size=(3, 3, 3), 
                          activation='relu', padding='same', 
                          kernel_regularizer=l1_l2(l1_value, l2_value), 
                          name='Branch_B_3x3x3')(branch_3x3x3_initial)

    # Branch C
    branch_double_3x3x3_initial = Conv3D(filter_operation[2], 
                                         kernel_size=(1, 1, 1), 
                                         activation='relu', padding='same', 
                                         kernel_regularizer=l1_l2(l1_value, 
                                                                  l2_value), 
                                         name='Branch_C_1x1x1')(input)
    branch_double_3x3x3_middle = Conv3D(filter_operation[2], 
                                        kernel_size=(3, 3, 3), 
                                        activation='relu', padding='same', 
                                        kernel_regularizer=l1_l2(l1_value, 
                                                                 l2_value), 
                                        name='Branch_C_1st_3x3x3')\
                                        (branch_double_3x3x3_initial)
    branch_double_3x3x3 = Conv3D(filter_operation[2], kernel_size=(3, 3, 3), 
                                 activation='relu', padding='same', 
                                 kernel_regularizer=l1_l2(l1_value, l2_value), 
                                 name='Branch_C_2nd_3x3x3')\
                                 (branch_double_3x3x3_middle)

    # Branch D
    branch_maxpool_3x3x3_initial = MaxPool3D(pool_size=(3, 3, 3), 
                                             strides=(1, 1, 1), padding='same', 
                                             name='Branch_D_3x3x3_maxpool')\
                                             (input)
    branch_maxpool_3x3x3 = Conv3D(filter_operation[3], kernel_size=(1, 1, 1), 
                                  activation='relu', padding='same', 
                                  kernel_regularizer=l1_l2(l1_value, l2_value), 
                                  name='Branch_D_1x1x1')\
                                  (branch_maxpool_3x3x3_initial)
    
    # Merge branches
    modules = [branch_1x1x1, branch_3x3x3, branch_double_3x3x3, 
               branch_maxpool_3x3x3]
    merged_module = concatenate(modules, name='Inception_Merged')
    
    return merged_module

# %%
filter_operations = [10, 10, 10, 10]
dropout = 0.0

input_img = Input(shape= (120, 160, 16, 1), name='Input')
print('\ninput shape:', input_img.shape)

x = Conv3D(10, (3, 3, 3), activation='relu', padding='same', 
           name='Convolution_1')(input_img)
x = MaxPool3D((2, 2, 2), name='MaxPooling_1')(x)
x = Dropout(dropout, name='DropOut_1')(x)

x = Conv3D(10, (3, 3, 3), activation='relu', padding='same', 
           name='Convolution_2')(x)
x = MaxPool3D((2, 2, 2), name='MaxPooling_2')(x)
x = Dropout(dropout, name='DropOut_2')(x)

x = inception_module(x, filter_operations)
x = MaxPool3D((2, 2, 2), name='Inception_MaxPooling')(x)
x = Dropout(dropout, name='DropOut_3')(x)

encoded = x
encoded_shape = K.int_shape(encoded)
print('output shape:', encoded_shape, '\n')

ICAE_encoder = Model(input_img, encoded, name='ICAE_encoder')
ICAE_encoder.summary(positions=[.35, .64, .71, 1.]) 
# `positions` adjusts print settings to minimize truncation
# Out:
# input shape: (None, 120, 160, 16, 1)
# output shape: (None, 15, 20, 2, 40)
#
# Model: "ICAE_encoder"
# __________________________________________________________________________________________________
# Layer (type)                      Output Shape                Param  Connected to
# ==================================================================================================
# Input (InputLayer)                [(None, 120, 160, 16, 1)]   0
# __________________________________________________________________________________________________
# Convolution_1 (Conv3D)            (None, 120, 160, 16, 10)    280    Input[0][0]
# __________________________________________________________________________________________________
# MaxPooling_1 (MaxPooling3D)       (None, 60, 80, 8, 10)       0      Convolution_1[0][0]
# __________________________________________________________________________________________________
# DropOut_1 (Dropout)               (None, 60, 80, 8, 10)       0      MaxPooling_1[0][0]
# __________________________________________________________________________________________________
# Convolution_2 (Conv3D)            (None, 60, 80, 8, 10)       2710   DropOut_1[0][0]
# __________________________________________________________________________________________________
# MaxPooling_2 (MaxPooling3D)       (None, 30, 40, 4, 10)       0      Convolution_2[0][0]
# __________________________________________________________________________________________________
# DropOut_2 (Dropout)               (None, 30, 40, 4, 10)       0      MaxPooling_2[0][0]
# __________________________________________________________________________________________________
# Branch_C_1x1x1 (Conv3D)           (None, 30, 40, 4, 10)       110    DropOut_2[0][0]
# __________________________________________________________________________________________________
# Branch_B_1x1x1 (Conv3D)           (None, 30, 40, 4, 10)       110    DropOut_2[0][0]
# __________________________________________________________________________________________________
# Branch_C_1st_3x3x3 (Conv3D)       (None, 30, 40, 4, 10)       2710   Branch_C_1x1x1[0][0]
# __________________________________________________________________________________________________
# Branch_D_3x3x3_maxpool (MaxPoolin (None, 30, 40, 4, 10)       0      DropOut_2[0][0]
# __________________________________________________________________________________________________
# Branch_A_1x1x1 (Conv3D)           (None, 30, 40, 4, 10)       110    DropOut_2[0][0]
# __________________________________________________________________________________________________
# Branch_B_3x3x3 (Conv3D)           (None, 30, 40, 4, 10)       2710   Branch_B_1x1x1[0][0]
# __________________________________________________________________________________________________
# Branch_C_2nd_3x3x3 (Conv3D)       (None, 30, 40, 4, 10)       2710   Branch_C_1st_3x3x3[0][0]
# __________________________________________________________________________________________________
# Branch_D_1x1x1 (Conv3D)           (None, 30, 40, 4, 10)       110    Branch_D_3x3x3_maxpool[0][0]
# __________________________________________________________________________________________________
# Inception_Merged (Concatenate)    (None, 30, 40, 4, 40)       0      Branch_A_1x1x1[0][0]
#                                                                      Branch_B_3x3x3[0][0]
#                                                                      Branch_C_2nd_3x3x3[0][0]
#                                                                      Branch_D_1x1x1[0][0]
# __________________________________________________________________________________________________
# Inception_MaxPooling (MaxPooling3 (None, 15, 20, 2, 40)       0      Inception_Merged[0][0]
# __________________________________________________________________________________________________
# DropOut_3 (Dropout)               (None, 15, 20, 2, 40)       0      Inception_MaxPooling[0][0]
# ==================================================================================================
# Total params: 11,560
# Trainable params: 11,560
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %% [markdown]
# #### Building ICAE Decoder

# %%
encoded_input= Input(shape=(encoded_shape[1],encoded_shape[2], 
                            encoded_shape[3], encoded_shape[4],), 
                     name='Encoded')
print('\ninput shape:', encoded_input.shape)

combined_dim = sum(filter_operations) 
# `filter_operations` taken from ICAE encoder

x = encoded_input

x = inception_module(x, filter_operations)
x = UpSampling3D((2, 2, 2), name='Inception_Upsampling')(x)
x = Dropout(dropout, name='DropOut_3')(x)

x = Conv3DTranspose(10, (3, 3, 3), activation='relu', padding='same', 
                    name='Convolution_2')(x)
x = UpSampling3D((2, 2, 2), name='Upsampling_2')(x)
x = Dropout(dropout, name='DropOut_2')(x)

x = Conv3DTranspose(10, (3, 3, 3), activation='relu', padding='same', 
                    name='Convolution_1')(x)
x = UpSampling3D((2, 2, 2), name='Upsampling_1')(x)
x = Dropout(dropout, name='DropOut_1')(x)

decoded = Conv3DTranspose(1, (3, 3, 3), activation='sigmoid', padding='same', 
                          name='Output')(x)

print('output shape:', K.int_shape(decoded), '\n')

ICAE_decoder = Model(encoded_input, decoded, name='ICAE_decoder')
ICAE_decoder.summary(positions=[.35, .64, .71, 1.])
# Out:
# input shape: (None, 15, 20, 2, 40)
# output shape: (None, 120, 160, 16, 1)
#
# Model: "ICAE_decoder"
# __________________________________________________________________________________________________
# Layer (type)                      Output Shape                Param  Connected to
# ==================================================================================================
# Encoded (InputLayer)              [(None, 15, 20, 2, 40)]     0
# __________________________________________________________________________________________________
# Branch_C_1x1x1 (Conv3D)           (None, 15, 20, 2, 10)       410    Encoded[0][0]
# __________________________________________________________________________________________________
# Branch_B_1x1x1 (Conv3D)           (None, 15, 20, 2, 10)       410    Encoded[0][0]
# __________________________________________________________________________________________________
# Branch_C_1st_3x3x3 (Conv3D)       (None, 15, 20, 2, 10)       2710   Branch_C_1x1x1[0][0]
# __________________________________________________________________________________________________
# Branch_D_3x3x3_maxpool (MaxPoolin (None, 15, 20, 2, 40)       0      Encoded[0][0]
# __________________________________________________________________________________________________
# Branch_A_1x1x1 (Conv3D)           (None, 15, 20, 2, 10)       410    Encoded[0][0]
# __________________________________________________________________________________________________
# Branch_B_3x3x3 (Conv3D)           (None, 15, 20, 2, 10)       2710   Branch_B_1x1x1[0][0]
# __________________________________________________________________________________________________
# Branch_C_2nd_3x3x3 (Conv3D)       (None, 15, 20, 2, 10)       2710   Branch_C_1st_3x3x3[0][0]
# __________________________________________________________________________________________________
# Branch_D_1x1x1 (Conv3D)           (None, 15, 20, 2, 10)       410    Branch_D_3x3x3_maxpool[0][0]
# __________________________________________________________________________________________________
# Inception_Merged (Concatenate)    (None, 15, 20, 2, 40)       0      Branch_A_1x1x1[0][0]
#                                                                      Branch_B_3x3x3[0][0]
#                                                                      Branch_C_2nd_3x3x3[0][0]
#                                                                      Branch_D_1x1x1[0][0]
# __________________________________________________________________________________________________
# Inception_Upsampling (UpSampling3 (None, 30, 40, 4, 40)       0      Inception_Merged[0][0]
# __________________________________________________________________________________________________
# DropOut_3 (Dropout)               (None, 30, 40, 4, 40)       0      Inception_Upsampling[0][0]
# __________________________________________________________________________________________________
# Convolution_2 (Conv3DTranspose)   (None, 30, 40, 4, 10)       10810  DropOut_3[0][0]
# __________________________________________________________________________________________________
# Upsampling_2 (UpSampling3D)       (None, 60, 80, 8, 10)       0      Convolution_2[0][0]
# __________________________________________________________________________________________________
# DropOut_2 (Dropout)               (None, 60, 80, 8, 10)       0      Upsampling_2[0][0]
# __________________________________________________________________________________________________
# Convolution_1 (Conv3DTranspose)   (None, 60, 80, 8, 10)       2710   DropOut_2[0][0]
# __________________________________________________________________________________________________
# Upsampling_1 (UpSampling3D)       (None, 120, 160, 16, 10)    0      Convolution_1[0][0]
# __________________________________________________________________________________________________
# DropOut_1 (Dropout)               (None, 120, 160, 16, 10)    0      Upsampling_1[0][0]
# __________________________________________________________________________________________________
# Output (Conv3DTranspose)          (None, 120, 160, 16, 1)     271    DropOut_1[0][0]
# ==================================================================================================
# Total params: 23,561
# Trainable params: 23,561
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %% [markdown]
# #### Building ICAE Classifier

# %%
# ICAE Classifier

encoded_input = Input(shape=(encoded_shape[1], encoded_shape[2], 
                             encoded_shape[3], encoded_shape[4],), 
                      name='Encoded')

y = encoded_input

# y = Conv3D(10, (1, 1, 1), padding='same', name='Linear')(y)
y = Flatten(name='Flatten')(y)
y = Dense(256, activation='selu', name='SELU_1')(y) #32
y = Dense(128, activation='selu', name='SELU_2')(y) #16
y = Dense(2, activation='sigmoid', name='Prediction')(y) #softmax

ICAE_pred = y

ICAE_classifier = Model(encoded_input, ICAE_pred, name='ICAE_classifier')
ICAE_classifier.summary()
# Out:
# Model: "ICAE_classifier"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# Encoded (InputLayer)         [(None, 15, 20, 2, 40)]   0
# _________________________________________________________________
# Flatten (Flatten)            (None, 24000)             0
# _________________________________________________________________
# SELU_1 (Dense)               (None, 256)               6144256
# _________________________________________________________________
# SELU_2 (Dense)               (None, 128)               32896
# _________________________________________________________________
# Prediction (Dense)           (None, 2)                 258
# =================================================================
# Total params: 6,177,410
# Trainable params: 6,177,410
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# #### Building ICAE Autoencoder

# %%
ICAE_autoencoder = Model(inputs=input_img, 
                         outputs=[ICAE_decoder(ICAE_encoder(input_img)), 
                                  ICAE_classifier(ICAE_encoder(input_img))],
                   name='ICAE_autoencoder')
ICAE_autoencoder.summary(positions=[.35, .64, .71, 1.])
# Out:
# Model: "ICAE_autoencoder"
# __________________________________________________________________________________________________
# Layer (type)                      Output Shape                Param  Connected to
# ==================================================================================================
# Input (InputLayer)                [(None, 120, 160, 16, 1)]   0
# __________________________________________________________________________________________________
# ICAE_encoder (Model)              (None, 15, 20, 2, 40)       11560  Input[0][0]
#                                                                      Input[0][0]
# __________________________________________________________________________________________________
# ICAE_decoder (Model)              (None, 120, 160, 16, 1)     23561  ICAE_encoder[1][0]
# __________________________________________________________________________________________________
# ICAE_classifier (Model)           (None, 2)                   617741 ICAE_encoder[2][0]
# ==================================================================================================
# Total params: 6,212,531
# Trainable params: 6,212,531
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %% [markdown]
# #### Building Classifier Branch

# %%
losses = {"CAE_decoder":'binary_crossentropy','CAE_classifier':'categorical_crossentropy'}
metrics= {'CAE_decoder':'mae', 'CAE_classifier':[ \
                                            'acc',
                                            tf.keras.metrics.Precision(), 
                                            tf.keras.metrics.Recall(),
                                            tf.keras.metrics.FalseNegatives(), 
                                            tf.keras.metrics.FalsePositives()]}
loss_weights={"CAE_decoder":0.5,'CAE_classifier':0.5}

initial_learning_rate = 0.1
lr_schedule = tf.keras.optimizers.schedules.ExponentialDecay(\
    initial_learning_rate,
    decay_steps=100000,
    decay_rate=0.90,
    staircase=True)

CAE_autoencoder.compile(optimizer='adam', 
                         loss=losses,
                         loss_weights = loss_weights,
                         metrics=metrics)

my_callbacks = [
    tf.keras.callbacks.EarlyStopping(patience=10),
    tf.keras.callbacks.ModelCheckpoint(filepath='outputs_AC/CAE_50do_AC_0523p.{epoch:02d}-{val_loss:.2f}.h5'),
    tf.keras.callbacks.TensorBoard(log_dir='./logs_AC'),
]

# %%
balancing_weights = class_weight.compute_sample_weight('balanced',train_label)
balancing_weights_test = class_weight.compute_sample_weight('balanced',test_label)

# %%
train_generator = MyDataGenerator(train_list, processed_dir, to_fit=True, 
                                  augment=True, batch_size=32,sample_weight=balancing_weights)
test_generator = MyDataGenerator(test_list, processed_dir, batch_size=32,sample_weight=balancing_weights_test)

# %%
history_CAE_50do=CAE_autoencoder.fit_generator(generator=train_generator,epochs=50,
                                       validation_data=test_generator,shuffle=True,
                                       callbacks = my_callbacks)
# Out:
# WARNING:tensorflow:From <ipython-input-18-82a774d887ce>:3: Model.fit_generator (from tensorflow.python.keras.engine.training) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use Model.fit, which supports generators.
# Epoch 1/50
# 24/24 [==============================] - 706s 29s/step - loss: 1.1745 - CAE_decoder_loss: 0.6578 - CAE_classifier_loss: 1.6912 - CAE_decoder_mae: 0.1893 - CAE_classifier_acc: 0.4635 - CAE_classifier_precision: 0.4635 - CAE_classifier_recall: 0.4635 - CAE_classifier_false_negatives: 412.0000 - CAE_classifier_false_positives: 412.0000 - val_loss: 0.6352 - val_CAE_decoder_loss: 0.5896 - val_CAE_classifier_loss: 0.6809 - val_CAE_decoder_mae: 0.2107 - val_CAE_classifier_acc: 0.3281 - val_CAE_classifier_precision: 0.3281 - val_CAE_classifier_recall: 0.3281 - val_CAE_classifier_false_negatives: 43.0000 - val_CAE_classifier_false_positives: 43.0000
# Epoch 2/50
# 24/24 [==============================] - 446s 19s/step - loss: 0.6635 - CAE_decoder_loss: 0.6148 - CAE_classifier_loss: 0.7123 - CAE_decoder_mae: 0.1455 - CAE_classifier_acc: 0.5078 - CAE_classifier_precision: 0.5078 - CAE_classifier_recall: 0.5078 - CAE_classifier_false_negatives: 378.0000 - CAE_classifier_false_positives: 378.0000 - val_loss: 0.6219 - val_CAE_decoder_loss: 0.5440 - val_CAE_classifier_loss: 0.6999 - val_CAE_decoder_mae: 0.1795 - val_CAE_classifier_acc: 0.3906 - val_CAE_classifier_precision: 0.3906 - val_CAE_classifier_recall: 0.3906 - val_CAE_classifier_false_negatives: 39.0000 - val_CAE_classifier_false_positives: 39.0000
# Epoch 3/50
# 24/24 [==============================] - 435s 18s/step - loss: 0.6525 - CAE_decoder_loss: 0.6086 - CAE_classifier_loss: 0.6964 - CAE_decoder_mae: 0.1367 - CAE_classifier_acc: 0.4297 - CAE_classifier_precision: 0.4297 - CAE_classifier_recall: 0.4297 - CAE_classifier_false_negatives: 438.0000 - CAE_classifier_false_positives: 438.0000 - val_loss: 0.6167 - val_CAE_decoder_loss: 0.5364 - val_CAE_classifier_loss: 0.6971 - val_CAE_decoder_mae: 0.1738 - val_CAE_classifier_acc: 0.6250 - val_CAE_classifier_precision: 0.6250 - val_CAE_classifier_recall: 0.6250 - val_CAE_classifier_false_negatives: 24.0000 - val_CAE_classifier_false_positives: 24.0000
# Epoch 4/50
# 24/24 [==============================] - 440s 18s/step - loss: 0.6474 - CAE_decoder_loss: 0.6019 - CAE_classifier_loss: 0.6930 - CAE_decoder_mae: 0.1338 - CAE_classifier_acc: 0.5286 - CAE_classifier_precision: 0.5286 - CAE_classifier_recall: 0.5286 - CAE_classifier_false_negatives: 362.0000 - CAE_classifier_false_positives: 362.0000 - val_loss: 0.6073 - val_CAE_decoder_loss: 0.5347 - val_CAE_classifier_loss: 0.6799 - val_CAE_decoder_mae: 0.1724 - val_CAE_classifier_acc: 0.3281 - val_CAE_classifier_precision: 0.3281 - val_CAE_classifier_recall: 0.3281 - val_CAE_classifier_false_negatives: 43.0000 - val_CAE_classifier_false_positives: 43.0000
# Epoch 5/50
# 24/24 [==============================] - 436s 18s/step - loss: 0.6459 - CAE_decoder_loss: 0.5989 - CAE_classifier_loss: 0.6930 - CAE_decoder_mae: 0.1348 - CAE_classifier_acc: 0.4609 - CAE_classifier_precision: 0.4609 - CAE_classifier_recall: 0.4609 - CAE_classifier_false_negatives: 414.0000 - CAE_classifier_false_positives: 414.0000 - val_loss: 0.6034 - val_CAE_decoder_loss: 0.5330 - val_CAE_classifier_loss: 0.6738 - val_CAE_decoder_mae: 0.1714 - val_CAE_classifier_acc: 0.6719 - val_CAE_classifier_precision: 0.6719 - val_CAE_classifier_recall: 0.6719 - val_CAE_classifier_false_negatives: 21.0000 - val_CAE_classifier_false_positives: 21.0000
# Epoch 6/50
# 24/24 [==============================] - 437s 18s/step - loss: 0.6500 - CAE_decoder_loss: 0.5971 - CAE_classifier_loss: 0.7029 - CAE_decoder_mae: 0.1304 - CAE_classifier_acc: 0.5104 - CAE_classifier_precision: 0.5104 - CAE_classifier_recall: 0.5104 - CAE_classifier_false_negatives: 376.0000 - CAE_classifier_false_positives: 376.0000 - val_loss: 0.6229 - val_CAE_decoder_loss: 0.5261 - val_CAE_classifier_loss: 0.7197 - val_CAE_decoder_mae: 0.1662 - val_CAE_classifier_acc: 0.5781 - val_CAE_classifier_precision: 0.5781 - val_CAE_classifier_recall: 0.5781 - val_CAE_classifier_false_negatives: 27.0000 - val_CAE_classifier_false_positives: 27.0000
# Epoch 7/50
# 24/24 [==============================] - 431s 18s/step - loss: 0.6418 - CAE_decoder_loss: 0.5880 - CAE_classifier_loss: 0.6955 - CAE_decoder_mae: 0.1259 - CAE_classifier_acc: 0.5026 - CAE_classifier_precision: 0.5026 - CAE_classifier_recall: 0.5026 - CAE_classifier_false_negatives: 382.0000 - CAE_classifier_false_positives: 382.0000 - val_loss: 0.5986 - val_CAE_decoder_loss: 0.5211 - val_CAE_classifier_loss: 0.6762 - val_CAE_decoder_mae: 0.1615 - val_CAE_classifier_acc: 0.3125 - val_CAE_classifier_precision: 0.3125 - val_CAE_classifier_recall: 0.3125 - val_CAE_classifier_false_negatives: 44.0000 - val_CAE_classifier_false_positives: 44.0000
# Epoch 8/50
# 24/24 [==============================] - 430s 18s/step - loss: 0.6425 - CAE_decoder_loss: 0.5888 - CAE_classifier_loss: 0.6961 - CAE_decoder_mae: 0.1209 - CAE_classifier_acc: 0.5378 - CAE_classifier_precision: 0.5378 - CAE_classifier_recall: 0.5378 - CAE_classifier_false_negatives: 355.0000 - CAE_classifier_false_positives: 355.0000 - val_loss: 0.6173 - val_CAE_decoder_loss: 0.5307 - val_CAE_classifier_loss: 0.7039 - val_CAE_decoder_mae: 0.1679 - val_CAE_classifier_acc: 0.4062 - val_CAE_classifier_precision: 0.4062 - val_CAE_classifier_recall: 0.4062 - val_CAE_classifier_false_negatives: 38.0000 - val_CAE_classifier_false_positives: 38.0000
# Epoch 9/50
# 24/24 [==============================] - 425s 18s/step - loss: 0.6410 - CAE_decoder_loss: 0.5834 - CAE_classifier_loss: 0.6985 - CAE_decoder_mae: 0.1189 - CAE_classifier_acc: 0.4583 - CAE_classifier_precision: 0.4583 - CAE_classifier_recall: 0.4583 - CAE_classifier_false_negatives: 416.0000 - CAE_classifier_false_positives: 416.0000 - val_loss: 0.6054 - val_CAE_decoder_loss: 0.5143 - val_CAE_classifier_loss: 0.6965 - val_CAE_decoder_mae: 0.1556 - val_CAE_classifier_acc: 0.6250 - val_CAE_classifier_precision: 0.6250 - val_CAE_classifier_recall: 0.6250 - val_CAE_classifier_false_negatives: 24.0000 - val_CAE_classifier_false_positives: 24.0000
# Epoch 10/50
# 24/24 [==============================] - 429s 18s/step - loss: 0.6388 - CAE_decoder_loss: 0.5845 - CAE_classifier_loss: 0.6931 - CAE_decoder_mae: 0.1156 - CAE_classifier_acc: 0.5013 - CAE_classifier_precision: 0.5013 - CAE_classifier_recall: 0.5013 - CAE_classifier_false_negatives: 383.0000 - CAE_classifier_false_positives: 383.0000 - val_loss: 0.6054 - val_CAE_decoder_loss: 0.5160 - val_CAE_classifier_loss: 0.6948 - val_CAE_decoder_mae: 0.1561 - val_CAE_classifier_acc: 0.6250 - val_CAE_classifier_precision: 0.6250 - val_CAE_classifier_recall: 0.6250 - val_CAE_classifier_false_negatives: 24.0000 - val_CAE_classifier_false_positives: 24.0000
# Epoch 11/50
# 24/24 [==============================] - 423s 18s/step - loss: 0.6372 - CAE_decoder_loss: 0.5827 - CAE_classifier_loss: 0.6917 - CAE_decoder_mae: 0.1111 - CAE_classifier_acc: 0.5130 - CAE_classifier_precision: 0.5130 - CAE_classifier_recall: 0.5130 - CAE_classifier_false_negatives: 374.0000 - CAE_classifier_false_positives: 374.0000 - val_loss: 0.5981 - val_CAE_decoder_loss: 0.5139 - val_CAE_classifier_loss: 0.6823 - val_CAE_decoder_mae: 0.1526 - val_CAE_classifier_acc: 0.3281 - val_CAE_classifier_precision: 0.3281 - val_CAE_classifier_recall: 0.3281 - val_CAE_classifier_false_negatives: 43.0000 - val_CAE_classifier_false_positives: 43.0000
# Epoch 12/50
# 24/24 [==============================] - 417s 17s/step - loss: 0.6386 - CAE_decoder_loss: 0.5838 - CAE_classifier_loss: 0.6934 - CAE_decoder_mae: 0.1106 - CAE_classifier_acc: 0.5508 - CAE_classifier_precision: 0.5508 - CAE_classifier_recall: 0.5508 - CAE_classifier_false_negatives: 345.0000 - CAE_classifier_false_positives: 345.0000 - val_loss: 0.6063 - val_CAE_decoder_loss: 0.5122 - val_CAE_classifier_loss: 0.7004 - val_CAE_decoder_mae: 0.1540 - val_CAE_classifier_acc: 0.3906 - val_CAE_classifier_precision: 0.3906 - val_CAE_classifier_recall: 0.3906 - val_CAE_classifier_false_negatives: 39.0000 - val_CAE_classifier_false_positives: 39.0000
# Epoch 13/50
# 24/24 [==============================] - 433s 18s/step - loss: 0.6352 - CAE_decoder_loss: 0.5797 - CAE_classifier_loss: 0.6907 - CAE_decoder_mae: 0.1109 - CAE_classifier_acc: 0.5026 - CAE_classifier_precision: 0.5026 - CAE_classifier_recall: 0.5026 - CAE_classifier_false_negatives: 382.0000 - CAE_classifier_false_positives: 382.0000 - val_loss: 0.6101 - val_CAE_decoder_loss: 0.5161 - val_CAE_classifier_loss: 0.7042 - val_CAE_decoder_mae: 0.1574 - val_CAE_classifier_acc: 0.4062 - val_CAE_classifier_precision: 0.4062 - val_CAE_classifier_recall: 0.4062 - val_CAE_classifier_false_negatives: 38.0000 - val_CAE_classifier_false_positives: 38.0000
# Epoch 14/50
# 24/24 [==============================] - 427s 18s/step - loss: 0.6391 - CAE_decoder_loss: 0.5890 - CAE_classifier_loss: 0.6892 - CAE_decoder_mae: 0.1081 - CAE_classifier_acc: 0.5104 - CAE_classifier_precision: 0.5104 - CAE_classifier_recall: 0.5104 - CAE_classifier_false_negatives: 376.0000 - CAE_classifier_false_positives: 376.0000 - val_loss: 0.6092 - val_CAE_decoder_loss: 0.5095 - val_CAE_classifier_loss: 0.7088 - val_CAE_decoder_mae: 0.1523 - val_CAE_classifier_acc: 0.4375 - val_CAE_classifier_precision: 0.4375 - val_CAE_classifier_recall: 0.4375 - val_CAE_classifier_false_negatives: 36.0000 - val_CAE_classifier_false_positives: 36.0000
# Epoch 15/50
# 24/24 [==============================] - 424s 18s/step - loss: 0.6331 - CAE_decoder_loss: 0.5825 - CAE_classifier_loss: 0.6836 - CAE_decoder_mae: 0.1079 - CAE_classifier_acc: 0.5651 - CAE_classifier_precision: 0.5651 - CAE_classifier_recall: 0.5651 - CAE_classifier_false_negatives: 334.0000 - CAE_classifier_false_positives: 334.0000 - val_loss: 0.6103 - val_CAE_decoder_loss: 0.5135 - val_CAE_classifier_loss: 0.7071 - val_CAE_decoder_mae: 0.1541 - val_CAE_classifier_acc: 0.4219 - val_CAE_classifier_precision: 0.4219 - val_CAE_classifier_recall: 0.4219 - val_CAE_classifier_false_negatives: 37.0000 - val_CAE_classifier_false_positives: 37.0000
# Epoch 16/50
# 24/24 [==============================] - 427s 18s/step - loss: 0.6354 - CAE_decoder_loss: 0.5791 - CAE_classifier_loss: 0.6917 - CAE_decoder_mae: 0.1097 - CAE_classifier_acc: 0.5391 - CAE_classifier_precision: 0.5391 - CAE_classifier_recall: 0.5391 - CAE_classifier_false_negatives: 354.0000 - CAE_classifier_false_positives: 354.0000 - val_loss: 0.6026 - val_CAE_decoder_loss: 0.5015 - val_CAE_classifier_loss: 0.7037 - val_CAE_decoder_mae: 0.1436 - val_CAE_classifier_acc: 0.3750 - val_CAE_classifier_precision: 0.3750 - val_CAE_classifier_recall: 0.3750 - val_CAE_classifier_false_negatives: 40.0000 - val_CAE_classifier_false_positives: 40.0000
# Epoch 17/50
# 24/24 [==============================] - 436s 18s/step - loss: 0.6286 - CAE_decoder_loss: 0.5828 - CAE_classifier_loss: 0.6745 - CAE_decoder_mae: 0.1053 - CAE_classifier_acc: 0.6029 - CAE_classifier_precision: 0.6029 - CAE_classifier_recall: 0.6029 - CAE_classifier_false_negatives: 305.0000 - CAE_classifier_false_positives: 305.0000 - val_loss: 0.6123 - val_CAE_decoder_loss: 0.4931 - val_CAE_classifier_loss: 0.7316 - val_CAE_decoder_mae: 0.1403 - val_CAE_classifier_acc: 0.3906 - val_CAE_classifier_precision: 0.3906 - val_CAE_classifier_recall: 0.3906 - val_CAE_classifier_false_negatives: 39.0000 - val_CAE_classifier_false_positives: 39.0000
# Epoch 18/50
# 24/24 [==============================] - 434s 18s/step - loss: 0.6392 - CAE_decoder_loss: 0.5894 - CAE_classifier_loss: 0.6890 - CAE_decoder_mae: 0.1069 - CAE_classifier_acc: 0.5312 - CAE_classifier_precision: 0.5312 - CAE_classifier_recall: 0.5312 - CAE_classifier_false_negatives: 360.0000 - CAE_classifier_false_positives: 360.0000 - val_loss: 0.6107 - val_CAE_decoder_loss: 0.5131 - val_CAE_classifier_loss: 0.7084 - val_CAE_decoder_mae: 0.1536 - val_CAE_classifier_acc: 0.3906 - val_CAE_classifier_precision: 0.3906 - val_CAE_classifier_recall: 0.3906 - val_CAE_classifier_false_negatives: 39.0000 - val_CAE_classifier_false_positives: 39.0000
# Epoch 19/50
# 24/24 [==============================] - 432s 18s/step - loss: 0.6231 - CAE_decoder_loss: 0.5744 - CAE_classifier_loss: 0.6718 - CAE_decoder_mae: 0.0967 - CAE_classifier_acc: 0.5846 - CAE_classifier_precision: 0.5846 - CAE_classifier_recall: 0.5846 - CAE_classifier_false_negatives: 319.0000 - CAE_classifier_false_positives: 319.0000 - val_loss: 0.6154 - val_CAE_decoder_loss: 0.4946 - val_CAE_classifier_loss: 0.7363 - val_CAE_decoder_mae: 0.1404 - val_CAE_classifier_acc: 0.3281 - val_CAE_classifier_precision: 0.3281 - val_CAE_classifier_recall: 0.3281 - val_CAE_classifier_false_negatives: 43.0000 - val_CAE_classifier_false_positives: 43.0000
# Epoch 20/50
# 24/24 [==============================] - 426s 18s/step - loss: 0.6234 - CAE_decoder_loss: 0.5743 - CAE_classifier_loss: 0.6726 - CAE_decoder_mae: 0.0909 - CAE_classifier_acc: 0.5911 - CAE_classifier_precision: 0.5911 - CAE_classifier_recall: 0.5911 - CAE_classifier_false_negatives: 314.0000 - CAE_classifier_false_positives: 314.0000 - val_loss: 0.6177 - val_CAE_decoder_loss: 0.5034 - val_CAE_classifier_loss: 0.7319 - val_CAE_decoder_mae: 0.1478 - val_CAE_classifier_acc: 0.4219 - val_CAE_classifier_precision: 0.4219 - val_CAE_classifier_recall: 0.4219 - val_CAE_classifier_false_negatives: 37.0000 - val_CAE_classifier_false_positives: 37.0000
# Epoch 21/50
# 24/24 [==============================] - 440s 18s/step - loss: 0.6311 - CAE_decoder_loss: 0.5804 - CAE_classifier_loss: 0.6818 - CAE_decoder_mae: 0.0916 - CAE_classifier_acc: 0.5339 - CAE_classifier_precision: 0.5339 - CAE_classifier_recall: 0.5339 - CAE_classifier_false_negatives: 358.0000 - CAE_classifier_false_positives: 358.0000 - val_loss: 0.6022 - val_CAE_decoder_loss: 0.4983 - val_CAE_classifier_loss: 0.7062 - val_CAE_decoder_mae: 0.1450 - val_CAE_classifier_acc: 0.4062 - val_CAE_classifier_precision: 0.4062 - val_CAE_classifier_recall: 0.4062 - val_CAE_classifier_false_negatives: 38.0000 - val_CAE_classifier_false_positives: 38.0000

# %%
CAE_autoencoder.save('CAE_autoencoder_50do_5-23.h5')
with open('outputs_AC/trainHistoryDict', 'wb') as file_pi:
        pickle.dump(history_CAE_50do.history, file_pi)
plt.plot(history_CAE_50do.history['loss'])
plt.plot(history_CAE_50do.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# %%
history_CAE_50do.history.keys()
# Out:
# dict_keys(['loss', 'CAE_decoder_loss', 'CAE_classifier_loss', 'CAE_decoder_mae', 'CAE_classifier_acc', 'CAE_classifier_precision', 'CAE_classifier_recall', 'CAE_classifier_false_negatives', 'CAE_classifier_false_positives', 'val_loss', 'val_CAE_decoder_loss', 'val_CAE_classifier_loss', 'val_CAE_decoder_mae', 'val_CAE_classifier_acc', 'val_CAE_classifier_precision', 'val_CAE_classifier_recall', 'val_CAE_classifier_false_negatives', 'val_CAE_classifier_false_positives'])

# %%
plt.plot(history_CAE_50do.history['CAE_classifier_acc'])
plt.plot(history_CAE_50do.history['val_CAE_classifier_acc'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# %%
plt.plot(history_CAE_50do.history['CAE_classifier_precision'])
plt.plot(history_CAE_50do.history['val_CAE_classifier_precision'])
plt.title('model precision')
plt.ylabel('precision')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# %%
balancing_weights_val = class_weight.compute_sample_weight('balanced',val_label)
val_generator = MyDataGenerator(val_list, processed_dir,to_fit=False, batch_size=2,sample_weight=balancing_weights_val)
pred = CAE_autoencoder.predict_generator(val_generator)
# Out:
# WARNING:tensorflow:From <ipython-input-26-47d1002de5c7>:3: Model.predict_generator (from tensorflow.python.keras.engine.training) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use Model.predict, which supports generators.

# %%
from sklearn.metrics import classification_report,accuracy_score
print("acc: ",accuracy_score(labels_to_categorical(val_label),np.round(pred[1])))
print(classification_report(labels_to_categorical(val_label),np.round(pred[1])))
# Out:
# acc:  0.3673469387755102
#               precision    recall  f1-score   support
#
#            0       0.37      1.00      0.54        36
#            1       0.00      0.00      0.00        62
#
#    micro avg       0.37      0.37      0.37        98
#    macro avg       0.18      0.50      0.27        98
# weighted avg       0.13      0.37      0.20        98
#  samples avg       0.37      0.37      0.37        98

# %%
with open('outputs_AC/trainHistoryDict', 'rb') as file_pi:
  test = pickle.load(file_pi)

# %%
test['loss'][-10:]
# Out:
# [0.6386252045631409,
#  0.6351831555366516,
#  0.6390635967254639,
#  0.633076548576355,
#  0.6353790760040283,
#  0.628606915473938,
#  0.6391943097114563,
#  0.6230961680412292,
#  0.6234054565429688,
#  0.6311361193656921]

# %%
plt.imshow(pred[0][2][:,:,15,0])
plt.show()
plt.imshow(pred[0][2][:,:,0,0])

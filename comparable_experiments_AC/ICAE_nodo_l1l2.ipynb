# %%
# %matplotlib inline 
from matplotlib import pyplot as plt
import numpy as np
import pandas as pd
import pickle
import warnings
import tensorflow as tf
import random
import scipy
import cv2
from tensorflow.keras.utils import Sequence
from tensorflow.keras.utils import to_categorical
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.utils import class_weight
from tensorflow import keras
from tensorflow.keras import backend as K
from tensorflow.keras.callbacks import TensorBoard
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import Dense, Conv3D, MaxPool3D, Dropout, \
        Flatten, Conv3DTranspose, UpSampling3D, Reshape, Input, concatenate
from tensorflow.keras.regularizers import l1_l2
from google.colab import drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
import tensorflow as tf
print('Tensorflow version:', tf.__version__)
# Out:
# Tensorflow version: 2.2.0

# %% [markdown]
# #### Create Train/Test Subset

# %%
# %cd /content/drive/My Drive/AD_MRI

# Load list of records
with open('AD_MRI_Master', 'rb') as f:
    master_list = pickle.load(f)
    
master_sheet = pd.DataFrame.from_dict(master_list, orient='index')
display(master_sheet.head())
print()

# Split: 80% train, 10% validation, 10% test
train_list, val_list, train_label, val_label = \
        train_test_split(master_sheet.subject.values, 
                         master_sheet.diagnosis.values, 
                         random_state = 1337, 
                         test_size=0.10)
        
train_list,test_list,train_label,test_label = \
        train_test_split(train_list, 
                         train_label, 
                         random_state = 0, 
                         test_size=0.10)

# Check for ratios of AD to NC to be consistent among sets
AD_count = 0
for lab in train_label:
    if lab == 'AD':
        AD_count +=1
print('train_ratio AD: ', round(AD_count/len(train_label), 3))

AD_count = 0
for lab in val_label:
    if lab == 'AD':
        AD_count +=1
print('val_ratio AD: ', round(AD_count/len(val_label), 3))

AD_count = 0
for lab in test_label:
    if lab == 'AD':
        AD_count +=1
print('test_ratio AD: ', round(AD_count/len(test_label), 3))

print('\nNumber of records\ntrain:', len(train_list), 
      '\nvalidation:', len(val_list), '\ntest:', len(test_list))
# Out:
# /content/drive/.shortcut-targets-by-id/1oU0ruELKPJf457X2y4uyGIpFkyyxaQyv/AD_MRI
#            subject   age diagnosis            scan_ID
# OAS30001  OAS30001  65.0        CN  OAS30001_MR_d0129
# OAS30002  OAS30002  68.0        CN  OAS30002_MR_d0371
# OAS30003  OAS30003  60.0        CN  OAS30003_MR_d0558
# OAS30004  OAS30004  58.0        CN  OAS30004_MR_d1101
# OAS30005  OAS30005  48.0        CN  OAS30005_MR_d0143
# train_ratio AD:  0.367
# val_ratio AD:  0.367
# test_ratio AD:  0.371
#
# Number of records
# train: 793
# validation: 98
# test: 89

# %% [markdown]
# #### Create Generator

# %%
processed_dir = '/content/drive/My Drive/AD_MRI/PROCESSED/'

# custom data generator.
import random
import scipy
import numpy as np
import cv2
from tensorflow.keras.utils import Sequence
from tensorflow.keras.utils import to_categorical
from sklearn.preprocessing import LabelEncoder
import random

import scipy


def labels_to_categorical(labels):
    le = LabelEncoder()
    le.fit(["CN", "AD"])
    num_lab=to_categorical(le.transform(labels),num_classes=2)
    return num_lab

def my_minmax(z):
    return (z-np.min(z))/(np.max(z)-np.min(z))

# Custom data generator
class MyDataGenerator(Sequence):
    """Generates data for Keras Sequence based data generator. 
    Suitable for building data generator for training and prediction.
    """
    def __init__(self, list_IDs, processed_dir, augment=False, 
                 to_fit=True, batch_size=32, dim=(120, 160, 120, 1),
                 n_classes=2, shuffle=True, ventricles_only=True, 
                 slice_start=50, slice_end=66, sample_weight=None):
        """Initialization
        :param list_IDs: list of all 'label' PATHS
        :param processed_dir: path to directory of processed images
        :param augment
        :param to_fit: True to return X and y, False to return X only
        :param batch_size: batch size at each iteration
        :param dim: tuple indicating image dimension
        :param n_classes: number of output masks
        :param shuffle: True to shuffle label indexes after every epoch
        :param ventricles_only: reduce dimensions to relevant slice
        """
        self.list_IDs = list_IDs
        self.processed_dir = processed_dir
        self.augment = augment
        self.to_fit = to_fit
        self.batch_size = batch_size
        self.dim = dim
        self.n_classes = n_classes
        self.shuffle = shuffle
        self.ventricles_only = ventricles_only
        self.on_epoch_end()
        self.slice_start = slice_start
        self.slice_end = slice_end
        if self.ventricles_only == False:
            self.slice_size = 120
        else:
            self.slice_size = slice_end - slice_start
        self.sample_weight = sample_weight
        # sample_weight needs to be provided if to_fit=True


    def __len__(self):
        """Denotes the number of batches per epoch
        :return: number of batches per epoch
        """
        return int(np.floor(len(self.list_IDs) / self.batch_size))


    def __getitem__(self, index):
        """Generate one batch of data
        :param index: index of the batch
        :return: X and y when fitting. X only when predicting
        """
        # Generate indexes of the batch
        indexes = self.indexes[index 
                               * self.batch_size:(index + 1) 
                               * self.batch_size]

        # Find list of IDs
        list_IDs_temp = [self.list_IDs[k] for k in indexes]
        
        # Generate data
        X, y = self._load_data(list_IDs_temp)
        X = my_minmax(np.float32(X))
        if self.ventricles_only == True:
          X = X[:, :, :, self.slice_start:self.slice_end, :]
          w_temp = np.asarray([self.sample_weight[k] for k in indexes])
        if self.to_fit:
            y = {'ICAE_classifier': y, 'ICAE_decoder': X}
            w = {'ICAE_classifier': w_temp,
                 'ICAE_decoder':np.ones(np.shape(X))}
            return X, y, w
        else:
            return X


    def on_epoch_end(self):
        """Updates indexes after each epoch
        """
        self.indexes = np.arange(len(self.list_IDs))
        if self.shuffle == True:
            np.random.shuffle(self.indexes)


    def _load_data(self, list_IDs_temp):
        """Generates data containing batch_size images
        :param list_IDs_temp: list of label ids to load
        :return: batch of images
        """
        # Initialization
        X = np.empty((self.batch_size, *self.dim))
        y = np.empty((self.batch_size, self.n_classes), dtype=int)
        
        # Generate data
        for i, ID in enumerate(list_IDs_temp):
            
            # start X
            with open(self.processed_dir+ID+'_data','rb') as f:
                data = pickle.load(f)
                
            # third dimension = 120, error using self.slice_size for value 16
            x_reshape= np.reshape(data['image'], (120, 160, 120, 1))
            if self.augment == True:
                x_reshape = scipy.ndimage.rotate(x_reshape, 
                                axes=random.choice([(0, 1), (0, 2), (1, 2)]), 
                                angle=random.choice([360-15, 15,0]), 
                                reshape=False)
            X[i,] = x_reshape
            
            #start y
            y[i,] = labels_to_categorical([data['diagnosis']])

        return X, y

# %%
print(labels_to_categorical(["CN"]))

balancing_weights = class_weight.compute_sample_weight('balanced',train_label)
print(balancing_weights[0],train_label[0])
print(balancing_weights[1],train_label[1])


# usage:
processed_dir = '/content/drive/My Drive/AD_MRI/PROCESSED/'
mdg = MyDataGenerator(test_list, processed_dir, to_fit=True, augment=True, 
                      sample_weight=balancing_weights,batch_size=2)

#X, pred, weights = mdg.__getitem__(0) #without .__getitem__ obviously
# Out:
# [[0. 1.]]
# 1.3625429553264605 AD
# 0.7898406374501992 CN

# %% [markdown]
# #### Building CAE Encoder

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import backend as K
from tensorflow.keras.callbacks import TensorBoard
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import Dense, Conv3D, MaxPool3D, Dropout, \
    Flatten, Conv3DTranspose, UpSampling3D, Reshape
from tensorflow.keras.layers import Input

# %%
dropout_rate = 0.0
input_img = Input(shape=(120, 160, 16, 1), name='Input')
print('\ninput shape:', input_img.shape)

x = Conv3D(10, (3, 3, 3), activation='relu', padding='same', 
           name='Convolution_1')(input_img)
x = MaxPool3D((2, 2, 2), name='MaxPooling_1')(x)
x = Dropout(dropout_rate, name='DropOut_1')(x)

x = Conv3D(10, (3, 3, 3), activation='relu', padding='same', 
           name='Convolution_2')(x)
x = MaxPool3D((2, 2, 2), name='MaxPooling_2')(x)
x = Dropout(dropout_rate, name='DropOut_2')(x)

x = Conv3D(10, (3, 3, 3), activation='relu', padding='same', 
           name='Convolution_3')(x)
x = MaxPool3D((2, 2, 2), name='MaxPooling_3')(x)
x = Dropout(dropout_rate, name='DropOut_3')(x)

encoded = x
encoded_shape = K.int_shape(encoded)
print('output shape:', encoded_shape, '\n')

CAE_encoder = Model(input_img, encoded, name='CAE_encoder')
CAE_encoder.summary()
# Out:
# input shape: (None, 120, 160, 16, 1)
# output shape: (None, 15, 20, 2, 10)
#
# Model: "CAE_encoder"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# Input (InputLayer)           [(None, 120, 160, 16, 1)] 0
# _________________________________________________________________
# Convolution_1 (Conv3D)       (None, 120, 160, 16, 10)  280
# _________________________________________________________________
# MaxPooling_1 (MaxPooling3D)  (None, 60, 80, 8, 10)     0
# _________________________________________________________________
# DropOut_1 (Dropout)          (None, 60, 80, 8, 10)     0
# _________________________________________________________________
# Convolution_2 (Conv3D)       (None, 60, 80, 8, 10)     2710
# _________________________________________________________________
# MaxPooling_2 (MaxPooling3D)  (None, 30, 40, 4, 10)     0
# _________________________________________________________________
# DropOut_2 (Dropout)          (None, 30, 40, 4, 10)     0
# _________________________________________________________________
# Convolution_3 (Conv3D)       (None, 30, 40, 4, 10)     2710
# _________________________________________________________________
# MaxPooling_3 (MaxPooling3D)  (None, 15, 20, 2, 10)     0
# _________________________________________________________________
# DropOut_3 (Dropout)          (None, 15, 20, 2, 10)     0
# =================================================================
# Total params: 5,700
# Trainable params: 5,700
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# #### Building CAE Decoder

# %%
encoded_shape
# Out:
# (None, 15, 20, 2, 10)

# %%
encoded_input = Input(shape=(encoded_shape[1],encoded_shape[2], 
                             encoded_shape[3], encoded_shape[4],), 
                      name='Encoded')

print('\ninput shape:', encoded_input.shape)
x = encoded_input

x = Conv3DTranspose(10, (3, 3, 3), activation='relu', padding='same', 
                    name='Convolution_3')(x)
x = UpSampling3D((2, 2, 2), name='UpSampling_3')(x)
x = Dropout(dropout_rate, name='DropOut_3')(x)

x = Conv3DTranspose(10, (3, 3, 3), activation='relu', padding='same', 
                    name='Convolution_2')(x)
x = UpSampling3D((2, 2, 2), name='UpSampling_2')(x)
x = Dropout(dropout_rate, name='DropOut_2')(x)

x = Conv3DTranspose(10, (3, 3, 3), activation='relu', padding='same', 
                    name='Convolution_1')(x)
x = UpSampling3D((2, 2, 2), name='UpSampling_1')(x)
x = Dropout(dropout_rate, name='DropOut_1')(x)

decoded = Conv3DTranspose(1, (3, 3, 3), activation='sigmoid', padding='same', 
                          name='Output')(x)

print('output shape:', K.int_shape(decoded), '\n')

CAE_decoder = Model(encoded_input, decoded, name='CAE_decoder')
CAE_decoder.summary()
# Out:
# input shape: (None, 15, 20, 2, 10)
# output shape: (None, 120, 160, 16, 1)
#
# Model: "CAE_decoder"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# Encoded (InputLayer)         [(None, 15, 20, 2, 10)]   0
# _________________________________________________________________
# Convolution_3 (Conv3DTranspo (None, 15, 20, 2, 10)     2710
# _________________________________________________________________
# UpSampling_3 (UpSampling3D)  (None, 30, 40, 4, 10)     0
# _________________________________________________________________
# DropOut_3 (Dropout)          (None, 30, 40, 4, 10)     0
# _________________________________________________________________
# Convolution_2 (Conv3DTranspo (None, 30, 40, 4, 10)     2710
# _________________________________________________________________
# UpSampling_2 (UpSampling3D)  (None, 60, 80, 8, 10)     0
# _________________________________________________________________
# DropOut_2 (Dropout)          (None, 60, 80, 8, 10)     0
# _________________________________________________________________
# Convolution_1 (Conv3DTranspo (None, 60, 80, 8, 10)     2710
# _________________________________________________________________
# UpSampling_1 (UpSampling3D)  (None, 120, 160, 16, 10)  0
# _________________________________________________________________
# DropOut_1 (Dropout)          (None, 120, 160, 16, 10)  0
# _________________________________________________________________
# Output (Conv3DTranspose)     (None, 120, 160, 16, 1)   271
# =================================================================
# Total params: 8,401
# Trainable params: 8,401
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# #### Building CAE Classifier

# %%
# CAE Classifier

encoded_input = Input(shape=(encoded_shape[1], encoded_shape[2], 
                             encoded_shape[3], encoded_shape[4],), 
                      name='Encoded')

y = encoded_input

y = Flatten(name='Flatten')(y)
y = Dense(1024, activation='selu', name='SELU_1')(y)
y = Dense(64, activation='selu', name='SELU_2')(y)
y = Dense(2, activation='softmax', name='Prediction')(y)

CAE_pred = y

CAE_classifier = Model(encoded_input, CAE_pred, name='CAE_classifier')
CAE_classifier.summary()
# Out:
# Model: "CAE_classifier"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# Encoded (InputLayer)         [(None, 15, 20, 2, 10)]   0
# _________________________________________________________________
# Flatten (Flatten)            (None, 6000)              0
# _________________________________________________________________
# SELU_1 (Dense)               (None, 1024)              6145024
# _________________________________________________________________
# SELU_2 (Dense)               (None, 64)                65600
# _________________________________________________________________
# Prediction (Dense)           (None, 2)                 130
# =================================================================
# Total params: 6,210,754
# Trainable params: 6,210,754
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# #### Building CAE Autoencoder

# %%
CAE_autoencoder = Model(inputs=input_img, 
                         outputs=[CAE_decoder(CAE_encoder(input_img)), 
                                  CAE_classifier(CAE_encoder(input_img))],
                   name='CAE_autoencoder')
CAE_autoencoder.summary()
# Out:
# Model: "CAE_autoencoder"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# Input (InputLayer)              [(None, 120, 160, 16 0
# __________________________________________________________________________________________________
# CAE_encoder (Model)             (None, 15, 20, 2, 10 5700        Input[0][0]
#                                                                  Input[0][0]
# __________________________________________________________________________________________________
# CAE_decoder (Model)             (None, 120, 160, 16, 8401        CAE_encoder[1][0]
# __________________________________________________________________________________________________
# CAE_classifier (Model)          (None, 2)            6210754     CAE_encoder[2][0]
# ==================================================================================================
# Total params: 6,224,855
# Trainable params: 6,224,855
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %% [markdown]
# #### Building ICAE Encoder

# %%
def inception_module(input, filter_operation):
    """
    filter_operation is a list of inception operations for:
        1x1x1 kernel, 
        1x1x1 then 3x3x3 kernels, 
        1x1x1 then 3x3x3 then 3x3x3 kernels, 
        and 3x3x3 maxpooling then 1x1x1 kernels, 
            respectively.
    """
    
    # According to Nature paper (Oh et. al.), l1 and l2 values of 10e-4 
    # performed the best from experimentation with 0.01, 0.001, 0.0001, 0.00001 
    # values.
    l1_value = 10e-4 #10e-4
    l2_value = 10e-4 #10e-4

    # Branch A
    branch_1x1x1 = Conv3D(filter_operation[0], kernel_size=(1, 1, 1), 
                          activation='relu', padding='same', 
                          kernel_regularizer=l1_l2(l1_value, l2_value), 
                          name='Branch_A_1x1x1')(input)

    # Branch B
    branch_3x3x3_initial = Conv3D(filter_operation[1], kernel_size=(1, 1, 1), 
                                  activation='relu', padding='same', 
                                  kernel_regularizer=l1_l2(l1_value, l2_value), 
                                  name='Branch_B_1x1x1')(input)
    branch_3x3x3 = Conv3D(filter_operation[1], kernel_size=(3, 3, 3), 
                          activation='relu', padding='same', 
                          kernel_regularizer=l1_l2(l1_value, l2_value), 
                          name='Branch_B_3x3x3')(branch_3x3x3_initial)

    # Branch C
    branch_double_3x3x3_initial = Conv3D(filter_operation[2], 
                                         kernel_size=(1, 1, 1), 
                                         activation='relu', padding='same', 
                                         kernel_regularizer=l1_l2(l1_value, 
                                                                  l2_value), 
                                         name='Branch_C_1x1x1')(input)
    branch_double_3x3x3_middle = Conv3D(filter_operation[2], 
                                        kernel_size=(3, 3, 3), 
                                        activation='relu', padding='same', 
                                        kernel_regularizer=l1_l2(l1_value, 
                                                                 l2_value), 
                                        name='Branch_C_1st_3x3x3')\
                                        (branch_double_3x3x3_initial)
    branch_double_3x3x3 = Conv3D(filter_operation[2], kernel_size=(3, 3, 3), 
                                 activation='relu', padding='same', 
                                 kernel_regularizer=l1_l2(l1_value, l2_value), 
                                 name='Branch_C_2nd_3x3x3')\
                                 (branch_double_3x3x3_middle)

    # Branch D
    branch_maxpool_3x3x3_initial = MaxPool3D(pool_size=(3, 3, 3), 
                                             strides=(1, 1, 1), padding='same', 
                                             name='Branch_D_3x3x3_maxpool')\
                                             (input)
    branch_maxpool_3x3x3 = Conv3D(filter_operation[3], kernel_size=(1, 1, 1), 
                                  activation='relu', padding='same', 
                                  kernel_regularizer=l1_l2(l1_value, l2_value), 
                                  name='Branch_D_1x1x1')\
                                  (branch_maxpool_3x3x3_initial)
    
    # Merge branches
    modules = [branch_1x1x1, branch_3x3x3, branch_double_3x3x3, 
               branch_maxpool_3x3x3]
    merged_module = concatenate(modules, name='Inception_Merged')
    
    return merged_module

# %%
filter_operations = [10, 10, 10, 10]
dropout = 0.0

input_img = Input(shape= (120, 160, 16, 1), name='Input')
print('\ninput shape:', input_img.shape)

x = Conv3D(10, (3, 3, 3), activation='relu', padding='same', 
           name='Convolution_1')(input_img)
x = MaxPool3D((2, 2, 2), name='MaxPooling_1')(x)
x = Dropout(dropout, name='DropOut_1')(x)

x = Conv3D(10, (3, 3, 3), activation='relu', padding='same', 
           name='Convolution_2')(x)
x = MaxPool3D((2, 2, 2), name='MaxPooling_2')(x)
x = Dropout(dropout, name='DropOut_2')(x)

x = inception_module(x, filter_operations)
x = MaxPool3D((2, 2, 2), name='Inception_MaxPooling')(x)
x = Dropout(dropout, name='DropOut_3')(x)

encoded = x
encoded_shape = K.int_shape(encoded)
print('output shape:', encoded_shape, '\n')

ICAE_encoder = Model(input_img, encoded, name='ICAE_encoder')
ICAE_encoder.summary(positions=[.35, .64, .71, 1.]) 
# `positions` adjusts print settings to minimize truncation
# Out:
# input shape: (None, 120, 160, 16, 1)
# output shape: (None, 15, 20, 2, 40)
#
# Model: "ICAE_encoder"
# __________________________________________________________________________________________________
# Layer (type)                      Output Shape                Param  Connected to
# ==================================================================================================
# Input (InputLayer)                [(None, 120, 160, 16, 1)]   0
# __________________________________________________________________________________________________
# Convolution_1 (Conv3D)            (None, 120, 160, 16, 10)    280    Input[0][0]
# __________________________________________________________________________________________________
# MaxPooling_1 (MaxPooling3D)       (None, 60, 80, 8, 10)       0      Convolution_1[0][0]
# __________________________________________________________________________________________________
# DropOut_1 (Dropout)               (None, 60, 80, 8, 10)       0      MaxPooling_1[0][0]
# __________________________________________________________________________________________________
# Convolution_2 (Conv3D)            (None, 60, 80, 8, 10)       2710   DropOut_1[0][0]
# __________________________________________________________________________________________________
# MaxPooling_2 (MaxPooling3D)       (None, 30, 40, 4, 10)       0      Convolution_2[0][0]
# __________________________________________________________________________________________________
# DropOut_2 (Dropout)               (None, 30, 40, 4, 10)       0      MaxPooling_2[0][0]
# __________________________________________________________________________________________________
# Branch_C_1x1x1 (Conv3D)           (None, 30, 40, 4, 10)       110    DropOut_2[0][0]
# __________________________________________________________________________________________________
# Branch_B_1x1x1 (Conv3D)           (None, 30, 40, 4, 10)       110    DropOut_2[0][0]
# __________________________________________________________________________________________________
# Branch_C_1st_3x3x3 (Conv3D)       (None, 30, 40, 4, 10)       2710   Branch_C_1x1x1[0][0]
# __________________________________________________________________________________________________
# Branch_D_3x3x3_maxpool (MaxPoolin (None, 30, 40, 4, 10)       0      DropOut_2[0][0]
# __________________________________________________________________________________________________
# Branch_A_1x1x1 (Conv3D)           (None, 30, 40, 4, 10)       110    DropOut_2[0][0]
# __________________________________________________________________________________________________
# Branch_B_3x3x3 (Conv3D)           (None, 30, 40, 4, 10)       2710   Branch_B_1x1x1[0][0]
# __________________________________________________________________________________________________
# Branch_C_2nd_3x3x3 (Conv3D)       (None, 30, 40, 4, 10)       2710   Branch_C_1st_3x3x3[0][0]
# __________________________________________________________________________________________________
# Branch_D_1x1x1 (Conv3D)           (None, 30, 40, 4, 10)       110    Branch_D_3x3x3_maxpool[0][0]
# __________________________________________________________________________________________________
# Inception_Merged (Concatenate)    (None, 30, 40, 4, 40)       0      Branch_A_1x1x1[0][0]
#                                                                      Branch_B_3x3x3[0][0]
#                                                                      Branch_C_2nd_3x3x3[0][0]
#                                                                      Branch_D_1x1x1[0][0]
# __________________________________________________________________________________________________
# Inception_MaxPooling (MaxPooling3 (None, 15, 20, 2, 40)       0      Inception_Merged[0][0]
# __________________________________________________________________________________________________
# DropOut_3 (Dropout)               (None, 15, 20, 2, 40)       0      Inception_MaxPooling[0][0]
# ==================================================================================================
# Total params: 11,560
# Trainable params: 11,560
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %% [markdown]
# #### Building ICAE Decoder

# %%
encoded_input= Input(shape=(encoded_shape[1],encoded_shape[2], 
                            encoded_shape[3], encoded_shape[4],), 
                     name='Encoded')
print('\ninput shape:', encoded_input.shape)

combined_dim = sum(filter_operations) 
# `filter_operations` taken from ICAE encoder

x = encoded_input

x = inception_module(x, filter_operations)
x = UpSampling3D((2, 2, 2), name='Inception_Upsampling')(x)
x = Dropout(dropout, name='DropOut_3')(x)

x = Conv3DTranspose(10, (3, 3, 3), activation='relu', padding='same', 
                    name='Convolution_2')(x)
x = UpSampling3D((2, 2, 2), name='Upsampling_2')(x)
x = Dropout(dropout, name='DropOut_2')(x)

x = Conv3DTranspose(10, (3, 3, 3), activation='relu', padding='same', 
                    name='Convolution_1')(x)
x = UpSampling3D((2, 2, 2), name='Upsampling_1')(x)
x = Dropout(dropout, name='DropOut_1')(x)

decoded = Conv3DTranspose(1, (3, 3, 3), activation='sigmoid', padding='same', 
                          name='Output')(x)

print('output shape:', K.int_shape(decoded), '\n')

ICAE_decoder = Model(encoded_input, decoded, name='ICAE_decoder')
ICAE_decoder.summary(positions=[.35, .64, .71, 1.])
# Out:
# input shape: (None, 15, 20, 2, 40)
# output shape: (None, 120, 160, 16, 1)
#
# Model: "ICAE_decoder"
# __________________________________________________________________________________________________
# Layer (type)                      Output Shape                Param  Connected to
# ==================================================================================================
# Encoded (InputLayer)              [(None, 15, 20, 2, 40)]     0
# __________________________________________________________________________________________________
# Branch_C_1x1x1 (Conv3D)           (None, 15, 20, 2, 10)       410    Encoded[0][0]
# __________________________________________________________________________________________________
# Branch_B_1x1x1 (Conv3D)           (None, 15, 20, 2, 10)       410    Encoded[0][0]
# __________________________________________________________________________________________________
# Branch_C_1st_3x3x3 (Conv3D)       (None, 15, 20, 2, 10)       2710   Branch_C_1x1x1[0][0]
# __________________________________________________________________________________________________
# Branch_D_3x3x3_maxpool (MaxPoolin (None, 15, 20, 2, 40)       0      Encoded[0][0]
# __________________________________________________________________________________________________
# Branch_A_1x1x1 (Conv3D)           (None, 15, 20, 2, 10)       410    Encoded[0][0]
# __________________________________________________________________________________________________
# Branch_B_3x3x3 (Conv3D)           (None, 15, 20, 2, 10)       2710   Branch_B_1x1x1[0][0]
# __________________________________________________________________________________________________
# Branch_C_2nd_3x3x3 (Conv3D)       (None, 15, 20, 2, 10)       2710   Branch_C_1st_3x3x3[0][0]
# __________________________________________________________________________________________________
# Branch_D_1x1x1 (Conv3D)           (None, 15, 20, 2, 10)       410    Branch_D_3x3x3_maxpool[0][0]
# __________________________________________________________________________________________________
# Inception_Merged (Concatenate)    (None, 15, 20, 2, 40)       0      Branch_A_1x1x1[0][0]
#                                                                      Branch_B_3x3x3[0][0]
#                                                                      Branch_C_2nd_3x3x3[0][0]
#                                                                      Branch_D_1x1x1[0][0]
# __________________________________________________________________________________________________
# Inception_Upsampling (UpSampling3 (None, 30, 40, 4, 40)       0      Inception_Merged[0][0]
# __________________________________________________________________________________________________
# DropOut_3 (Dropout)               (None, 30, 40, 4, 40)       0      Inception_Upsampling[0][0]
# __________________________________________________________________________________________________
# Convolution_2 (Conv3DTranspose)   (None, 30, 40, 4, 10)       10810  DropOut_3[0][0]
# __________________________________________________________________________________________________
# Upsampling_2 (UpSampling3D)       (None, 60, 80, 8, 10)       0      Convolution_2[0][0]
# __________________________________________________________________________________________________
# DropOut_2 (Dropout)               (None, 60, 80, 8, 10)       0      Upsampling_2[0][0]
# __________________________________________________________________________________________________
# Convolution_1 (Conv3DTranspose)   (None, 60, 80, 8, 10)       2710   DropOut_2[0][0]
# __________________________________________________________________________________________________
# Upsampling_1 (UpSampling3D)       (None, 120, 160, 16, 10)    0      Convolution_1[0][0]
# __________________________________________________________________________________________________
# DropOut_1 (Dropout)               (None, 120, 160, 16, 10)    0      Upsampling_1[0][0]
# __________________________________________________________________________________________________
# Output (Conv3DTranspose)          (None, 120, 160, 16, 1)     271    DropOut_1[0][0]
# ==================================================================================================
# Total params: 23,561
# Trainable params: 23,561
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %% [markdown]
# #### Building ICAE Classifier

# %%
# ICAE Classifier

encoded_input = Input(shape=(encoded_shape[1], encoded_shape[2], 
                             encoded_shape[3], encoded_shape[4],), 
                      name='Encoded')

y = encoded_input

# y = Conv3D(10, (1, 1, 1), padding='same', name='Linear')(y)
y = Flatten(name='Flatten')(y)
y = Dense(256, activation='selu', name='SELU_1')(y) #32
y = Dense(128, activation='selu', name='SELU_2')(y) #16
y = Dense(2, activation='sigmoid', name='Prediction')(y) #softmax

ICAE_pred = y

ICAE_classifier = Model(encoded_input, ICAE_pred, name='ICAE_classifier')
ICAE_classifier.summary()
# Out:
# Model: "ICAE_classifier"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# Encoded (InputLayer)         [(None, 15, 20, 2, 40)]   0
# _________________________________________________________________
# Flatten (Flatten)            (None, 24000)             0
# _________________________________________________________________
# SELU_1 (Dense)               (None, 256)               6144256
# _________________________________________________________________
# SELU_2 (Dense)               (None, 128)               32896
# _________________________________________________________________
# Prediction (Dense)           (None, 2)                 258
# =================================================================
# Total params: 6,177,410
# Trainable params: 6,177,410
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# #### Building ICAE Autoencoder

# %%
ICAE_autoencoder = Model(inputs=input_img, 
                         outputs=[ICAE_decoder(ICAE_encoder(input_img)), 
                                  ICAE_classifier(ICAE_encoder(input_img))],
                   name='ICAE_autoencoder')
ICAE_autoencoder.summary(positions=[.35, .64, .71, 1.])
# Out:
# Model: "ICAE_autoencoder"
# __________________________________________________________________________________________________
# Layer (type)                      Output Shape                Param  Connected to
# ==================================================================================================
# Input (InputLayer)                [(None, 120, 160, 16, 1)]   0
# __________________________________________________________________________________________________
# ICAE_encoder (Model)              (None, 15, 20, 2, 40)       11560  Input[0][0]
#                                                                      Input[0][0]
# __________________________________________________________________________________________________
# ICAE_decoder (Model)              (None, 120, 160, 16, 1)     23561  ICAE_encoder[1][0]
# __________________________________________________________________________________________________
# ICAE_classifier (Model)           (None, 2)                   617741 ICAE_encoder[2][0]
# ==================================================================================================
# Total params: 6,212,531
# Trainable params: 6,212,531
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %% [markdown]
# #### Building Classifier Branch

# %%
losses = {"ICAE_decoder":'binary_crossentropy','ICAE_classifier':'categorical_crossentropy'}
metrics= {'ICAE_decoder':'mae', 'ICAE_classifier':[ \
                                            'acc',
                                            tf.keras.metrics.Precision(), 
                                            tf.keras.metrics.Recall(),
                                            tf.keras.metrics.FalseNegatives(), 
                                            tf.keras.metrics.FalsePositives()]}
loss_weights={"ICAE_decoder":0.5,'ICAE_classifier':0.5}

initial_learning_rate = 0.1
lr_schedule = tf.keras.optimizers.schedules.ExponentialDecay(\
    initial_learning_rate,
    decay_steps=100000,
    decay_rate=0.90,
    staircase=True)

ICAE_autoencoder.compile(optimizer='adam', 
                         loss=losses,
                         loss_weights = loss_weights,
                         metrics=metrics)

my_callbacks = [
    tf.keras.callbacks.EarlyStopping(patience=10),
    tf.keras.callbacks.ModelCheckpoint(filepath='outputs_AC/ICAE_experiment_nodo_AC_0522p.{epoch:02d}-{val_loss:.2f}.h5'),
    tf.keras.callbacks.TensorBoard(log_dir='./logs_AC'),
]

# %%
balancing_weights = class_weight.compute_sample_weight('balanced',train_label)
balancing_weights_test = class_weight.compute_sample_weight('balanced',test_label)

# %%
train_generator = MyDataGenerator(train_list, processed_dir, to_fit=True, 
                                  augment=True, batch_size=32,sample_weight=balancing_weights)
test_generator = MyDataGenerator(test_list, processed_dir, batch_size=32,sample_weight=balancing_weights_test)

# %%
history_ICAE_extra=ICAE_autoencoder.fit_generator(generator=train_generator,epochs=50,
                                       validation_data=test_generator,shuffle=True,
                                       callbacks = my_callbacks)
# Out:
# Epoch 1/50
# 24/24 [==============================] - 1121s 47s/step - loss: 1.9723 - ICAE_decoder_loss: 0.6245 - ICAE_classifier_loss: 0.8529 - ICAE_decoder_mae: 0.1575 - ICAE_classifier_acc: 0.5938 - ICAE_classifier_precision_1: 0.4946 - ICAE_classifier_recall_1: 0.9479 - ICAE_classifier_false_negatives_1: 40.0000 - ICAE_classifier_false_positives_1: 744.0000 - val_loss: 1.6551 - val_ICAE_decoder_loss: 0.5353 - val_ICAE_classifier_loss: 0.6880 - val_ICAE_decoder_mae: 0.1710 - val_ICAE_classifier_acc: 0.6406 - val_ICAE_classifier_precision_1: 0.5000 - val_ICAE_classifier_recall_1: 1.0000 - val_ICAE_classifier_false_negatives_1: 0.0000e+00 - val_ICAE_classifier_false_positives_1: 64.0000
# Epoch 2/50
# 24/24 [==============================] - 451s 19s/step - loss: 1.5362 - ICAE_decoder_loss: 0.5920 - ICAE_classifier_loss: 0.6928 - ICAE_decoder_mae: 0.1290 - ICAE_classifier_acc: 0.6341 - ICAE_classifier_precision_1: 0.5000 - ICAE_classifier_recall_1: 1.0000 - ICAE_classifier_false_negatives_1: 0.0000e+00 - ICAE_classifier_false_positives_1: 768.0000 - val_loss: 1.3342 - val_ICAE_decoder_loss: 0.5001 - val_ICAE_classifier_loss: 0.6768 - val_ICAE_decoder_mae: 0.1401 - val_ICAE_classifier_acc: 0.6719 - val_ICAE_classifier_precision_1: 0.5000 - val_ICAE_classifier_recall_1: 1.0000 - val_ICAE_classifier_false_negatives_1: 0.0000e+00 - val_ICAE_classifier_false_positives_1: 64.0000
# Epoch 3/50
# 24/24 [==============================] - 404s 17s/step - loss: 1.2669 - ICAE_decoder_loss: 0.5694 - ICAE_classifier_loss: 0.6932 - ICAE_decoder_mae: 0.0897 - ICAE_classifier_acc: 0.6328 - ICAE_classifier_precision_1: 0.5000 - ICAE_classifier_recall_1: 1.0000 - ICAE_classifier_false_negatives_1: 0.0000e+00 - ICAE_classifier_false_positives_1: 768.0000 - val_loss: 1.1152 - val_ICAE_decoder_loss: 0.4639 - val_ICAE_classifier_loss: 0.7068 - val_ICAE_decoder_mae: 0.0992 - val_ICAE_classifier_acc: 0.5938 - val_ICAE_classifier_precision_1: 0.5000 - val_ICAE_classifier_recall_1: 1.0000 - val_ICAE_classifier_false_negatives_1: 0.0000e+00 - val_ICAE_classifier_false_positives_1: 64.0000
# Epoch 4/50
# 24/24 [==============================] - 409s 17s/step - loss: 1.0894 - ICAE_decoder_loss: 0.5682 - ICAE_classifier_loss: 0.6948 - ICAE_decoder_mae: 0.0768 - ICAE_classifier_acc: 0.6289 - ICAE_classifier_precision_1: 0.5000 - ICAE_classifier_recall_1: 1.0000 - ICAE_classifier_false_negatives_1: 0.0000e+00 - ICAE_classifier_false_positives_1: 768.0000 - val_loss: 0.9740 - val_ICAE_decoder_loss: 0.4615 - val_ICAE_classifier_loss: 0.7008 - val_ICAE_decoder_mae: 0.0991 - val_ICAE_classifier_acc: 0.6094 - val_ICAE_classifier_precision_1: 0.5000 - val_ICAE_classifier_recall_1: 1.0000 - val_ICAE_classifier_false_negatives_1: 0.0000e+00 - val_ICAE_classifier_false_positives_1: 64.0000
# Epoch 5/50
# 24/24 [==============================] - 406s 17s/step - loss: 0.9833 - ICAE_decoder_loss: 0.5632 - ICAE_classifier_loss: 0.6922 - ICAE_decoder_mae: 0.0731 - ICAE_classifier_acc: 0.6354 - ICAE_classifier_precision_1: 0.5000 - ICAE_classifier_recall_1: 1.0000 - ICAE_classifier_false_negatives_1: 0.0000e+00 - ICAE_classifier_false_positives_1: 768.0000 - val_loss: 0.8974 - val_ICAE_decoder_loss: 0.4568 - val_ICAE_classifier_loss: 0.6948 - val_ICAE_decoder_mae: 0.0967 - val_ICAE_classifier_acc: 0.6250 - val_ICAE_classifier_precision_1: 0.5000 - val_ICAE_classifier_recall_1: 1.0000 - val_ICAE_classifier_false_negatives_1: 0.0000e+00 - val_ICAE_classifier_false_positives_1: 64.0000
# Epoch 6/50
# 24/24 [==============================] - 414s 17s/step - loss: 0.9235 - ICAE_decoder_loss: 0.5612 - ICAE_classifier_loss: 0.6938 - ICAE_decoder_mae: 0.0709 - ICAE_classifier_acc: 0.6315 - ICAE_classifier_precision_1: 0.5000 - ICAE_classifier_recall_1: 1.0000 - ICAE_classifier_false_negatives_1: 0.0000e+00 - ICAE_classifier_false_positives_1: 768.0000 - val_loss: 0.8327 - val_ICAE_decoder_loss: 0.4540 - val_ICAE_classifier_loss: 0.6708 - val_ICAE_decoder_mae: 0.0940 - val_ICAE_classifier_acc: 0.6875 - val_ICAE_classifier_precision_1: 0.5000 - val_ICAE_classifier_recall_1: 1.0000 - val_ICAE_classifier_false_negatives_1: 0.0000e+00 - val_ICAE_classifier_false_positives_1: 64.0000
# Epoch 7/50
# 24/24 [==============================] - 405s 17s/step - loss: 0.8750 - ICAE_decoder_loss: 0.5595 - ICAE_classifier_loss: 0.6917 - ICAE_decoder_mae: 0.0684 - ICAE_classifier_acc: 0.6367 - ICAE_classifier_precision_1: 0.5000 - ICAE_classifier_recall_1: 1.0000 - ICAE_classifier_false_negatives_1: 0.0000e+00 - ICAE_classifier_false_positives_1: 768.0000 - val_loss: 0.8003 - val_ICAE_decoder_loss: 0.4559 - val_ICAE_classifier_loss: 0.6888 - val_ICAE_decoder_mae: 0.0952 - val_ICAE_classifier_acc: 0.6406 - val_ICAE_classifier_precision_1: 0.5000 - val_ICAE_classifier_recall_1: 1.0000 - val_ICAE_classifier_false_negatives_1: 0.0000e+00 - val_ICAE_classifier_false_positives_1: 64.0000
# Epoch 8/50
# 24/24 [==============================] - 403s 17s/step - loss: 0.8345 - ICAE_decoder_loss: 0.5533 - ICAE_classifier_loss: 0.6953 - ICAE_decoder_mae: 0.0680 - ICAE_classifier_acc: 0.6276 - ICAE_classifier_precision_1: 0.5000 - ICAE_classifier_recall_1: 1.0000 - ICAE_classifier_false_negatives_1: 0.0000e+00 - ICAE_classifier_false_positives_1: 768.0000 - val_loss: 0.7677 - val_ICAE_decoder_loss: 0.4508 - val_ICAE_classifier_loss: 0.7008 - val_ICAE_decoder_mae: 0.0922 - val_ICAE_classifier_acc: 0.6094 - val_ICAE_classifier_precision_1: 0.5000 - val_ICAE_classifier_recall_1: 1.0000 - val_ICAE_classifier_false_negatives_1: 0.0000e+00 - val_ICAE_classifier_false_positives_1: 64.0000
# Epoch 9/50
# 24/24 [==============================] - 409s 17s/step - loss: 0.8005 - ICAE_decoder_loss: 0.5539 - ICAE_classifier_loss: 0.6932 - ICAE_decoder_mae: 0.0669 - ICAE_classifier_acc: 0.6328 - ICAE_classifier_precision_1: 0.5000 - ICAE_classifier_recall_1: 1.0000 - ICAE_classifier_false_negatives_1: 0.0000e+00 - ICAE_classifier_false_positives_1: 768.0000 - val_loss: 0.7316 - val_ICAE_decoder_loss: 0.4516 - val_ICAE_classifier_loss: 0.6888 - val_ICAE_decoder_mae: 0.0933 - val_ICAE_classifier_acc: 0.6406 - val_ICAE_classifier_precision_1: 0.5000 - val_ICAE_classifier_recall_1: 1.0000 - val_ICAE_classifier_false_negatives_1: 0.0000e+00 - val_ICAE_classifier_false_positives_1: 64.0000
# Epoch 10/50
# 24/24 [==============================] - 407s 17s/step - loss: 0.7748 - ICAE_decoder_loss: 0.5606 - ICAE_classifier_loss: 0.6917 - ICAE_decoder_mae: 0.0660 - ICAE_classifier_acc: 0.6367 - ICAE_classifier_precision_1: 0.5000 - ICAE_classifier_recall_1: 1.0000 - ICAE_classifier_false_negatives_1: 0.0000e+00 - ICAE_classifier_false_positives_1: 768.0000 - val_loss: 0.7098 - val_ICAE_decoder_loss: 0.4538 - val_ICAE_classifier_loss: 0.6948 - val_ICAE_decoder_mae: 0.0939 - val_ICAE_classifier_acc: 0.6250 - val_ICAE_classifier_precision_1: 0.5000 - val_ICAE_classifier_recall_1: 1.0000 - val_ICAE_classifier_false_negatives_1: 0.0000e+00 - val_ICAE_classifier_false_positives_1: 64.0000
# Epoch 11/50
# 24/24 [==============================] - 395s 16s/step - loss: 0.7533 - ICAE_decoder_loss: 0.5640 - ICAE_classifier_loss: 0.6932 - ICAE_decoder_mae: 0.0647 - ICAE_classifier_acc: 0.6328 - ICAE_classifier_precision_1: 0.5000 - ICAE_classifier_recall_1: 1.0000 - ICAE_classifier_false_negatives_1: 0.0000e+00 - ICAE_classifier_false_positives_1: 768.0000 - val_loss: 0.6874 - val_ICAE_decoder_loss: 0.4528 - val_ICAE_classifier_loss: 0.6948 - val_ICAE_decoder_mae: 0.0957 - val_ICAE_classifier_acc: 0.6250 - val_ICAE_classifier_precision_1: 0.5000 - val_ICAE_classifier_recall_1: 1.0000 - val_ICAE_classifier_false_negatives_1: 0.0000e+00 - val_ICAE_classifier_false_positives_1: 64.0000
# Epoch 12/50
# 24/24 [==============================] - 411s 17s/step - loss: 0.7327 - ICAE_decoder_loss: 0.5652 - ICAE_classifier_loss: 0.6912 - ICAE_decoder_mae: 0.0652 - ICAE_classifier_acc: 0.6380 - ICAE_classifier_precision_1: 0.5000 - ICAE_classifier_recall_1: 1.0000 - ICAE_classifier_false_negatives_1: 0.0000e+00 - ICAE_classifier_false_positives_1: 768.0000 - val_loss: 0.6674 - val_ICAE_decoder_loss: 0.4556 - val_ICAE_classifier_loss: 0.6888 - val_ICAE_decoder_mae: 0.0939 - val_ICAE_classifier_acc: 0.6406 - val_ICAE_classifier_precision_1: 0.5000 - val_ICAE_classifier_recall_1: 1.0000 - val_ICAE_classifier_false_negatives_1: 0.0000e+00 - val_ICAE_classifier_false_positives_1: 64.0000
# Epoch 13/50
# 24/24 [==============================] - 416s 17s/step - loss: 0.7123 - ICAE_decoder_loss: 0.5548 - ICAE_classifier_loss: 0.6943 - ICAE_decoder_mae: 0.0636 - ICAE_classifier_acc: 0.6302 - ICAE_classifier_precision_1: 0.5000 - ICAE_classifier_recall_1: 1.0000 - ICAE_classifier_false_negatives_1: 0.0000e+00 - ICAE_classifier_false_positives_1: 768.0000 - val_loss: 0.6530 - val_ICAE_decoder_loss: 0.4508 - val_ICAE_classifier_loss: 0.6948 - val_ICAE_decoder_mae: 0.0923 - val_ICAE_classifier_acc: 0.6250 - val_ICAE_classifier_precision_1: 0.5000 - val_ICAE_classifier_recall_1: 1.0000 - val_ICAE_classifier_false_negatives_1: 0.0000e+00 - val_ICAE_classifier_false_positives_1: 64.0000
# Epoch 14/50
# 24/24 [==============================] - 407s 17s/step - loss: 0.7017 - ICAE_decoder_loss: 0.5599 - ICAE_classifier_loss: 0.6953 - ICAE_decoder_mae: 0.0622 - ICAE_classifier_acc: 0.6276 - ICAE_classifier_precision_1: 0.5000 - ICAE_classifier_recall_1: 1.0000 - ICAE_classifier_false_negatives_1: 0.0000e+00 - ICAE_classifier_false_positives_1: 768.0000 - val_loss: 0.6391 - val_ICAE_decoder_loss: 0.4534 - val_ICAE_classifier_loss: 0.6888 - val_ICAE_decoder_mae: 0.0939 - val_ICAE_classifier_acc: 0.6406 - val_ICAE_classifier_precision_1: 0.5000 - val_ICAE_classifier_recall_1: 1.0000 - val_ICAE_classifier_false_negatives_1: 0.0000e+00 - val_ICAE_classifier_false_positives_1: 64.0000
# Epoch 15/50
# 24/24 [==============================] - 423s 18s/step - loss: 0.6906 - ICAE_decoder_loss: 0.5596 - ICAE_classifier_loss: 0.6948 - ICAE_decoder_mae: 0.0637 - ICAE_classifier_acc: 0.6289 - ICAE_classifier_precision_1: 0.5000 - ICAE_classifier_recall_1: 1.0000 - ICAE_classifier_false_negatives_1: 0.0000e+00 - ICAE_classifier_false_positives_1: 768.0000 - val_loss: 0.6258 - val_ICAE_decoder_loss: 0.4515 - val_ICAE_classifier_loss: 0.6828 - val_ICAE_decoder_mae: 0.0913 - val_ICAE_classifier_acc: 0.6562 - val_ICAE_classifier_precision_1: 0.5000 - val_ICAE_classifier_recall_1: 1.0000 - val_ICAE_classifier_false_negatives_1: 0.0000e+00 - val_ICAE_classifier_false_positives_1: 64.0000
# Epoch 16/50
# 24/24 [==============================] - 411s 17s/step - loss: 0.6776 - ICAE_decoder_loss: 0.5532 - ICAE_classifier_loss: 0.6917 - ICAE_decoder_mae: 0.0629 - ICAE_classifier_acc: 0.6367 - ICAE_classifier_precision_1: 0.5000 - ICAE_classifier_recall_1: 1.0000 - ICAE_classifier_false_negatives_1: 0.0000e+00 - ICAE_classifier_false_positives_1: 768.0000 - val_loss: 0.6190 - val_ICAE_decoder_loss: 0.4520 - val_ICAE_classifier_loss: 0.6828 - val_ICAE_decoder_mae: 0.0903 - val_ICAE_classifier_acc: 0.6562 - val_ICAE_classifier_precision_1: 0.5000 - val_ICAE_classifier_recall_1: 1.0000 - val_ICAE_classifier_false_negatives_1: 0.0000e+00 - val_ICAE_classifier_false_positives_1: 64.0000
# Epoch 17/50
# 24/24 [==============================] - 407s 17s/step - loss: 0.6760 - ICAE_decoder_loss: 0.5609 - ICAE_classifier_loss: 0.6932 - ICAE_decoder_mae: 0.0629 - ICAE_classifier_acc: 0.6328 - ICAE_classifier_precision_1: 0.5000 - ICAE_classifier_recall_1: 1.0000 - ICAE_classifier_false_negatives_1: 0.0000e+00 - ICAE_classifier_false_positives_1: 768.0000 - val_loss: 0.6248 - val_ICAE_decoder_loss: 0.4503 - val_ICAE_classifier_loss: 0.7068 - val_ICAE_decoder_mae: 0.0932 - val_ICAE_classifier_acc: 0.5938 - val_ICAE_classifier_precision_1: 0.5000 - val_ICAE_classifier_recall_1: 1.0000 - val_ICAE_classifier_false_negatives_1: 0.0000e+00 - val_ICAE_classifier_false_positives_1: 64.0000
# Epoch 18/50
# 24/24 [==============================] - 441s 18s/step - loss: 0.6716 - ICAE_decoder_loss: 0.5610 - ICAE_classifier_loss: 0.6943 - ICAE_decoder_mae: 0.0618 - ICAE_classifier_acc: 0.6302 - ICAE_classifier_precision_1: 0.5000 - ICAE_classifier_recall_1: 1.0000 - ICAE_classifier_false_negatives_1: 0.0000e+00 - ICAE_classifier_false_positives_1: 768.0000 - val_loss: 0.6219 - val_ICAE_decoder_loss: 0.4539 - val_ICAE_classifier_loss: 0.7068 - val_ICAE_decoder_mae: 0.0938 - val_ICAE_classifier_acc: 0.5938 - val_ICAE_classifier_precision_1: 0.5000 - val_ICAE_classifier_recall_1: 1.0000 - val_ICAE_classifier_false_negatives_1: 0.0000e+00 - val_ICAE_classifier_false_positives_1: 64.0000
# Epoch 19/50
# 24/24 [==============================] - 407s 17s/step - loss: 0.6620 - ICAE_decoder_loss: 0.5523 - ICAE_classifier_loss: 0.6927 - ICAE_decoder_mae: 0.0619 - ICAE_classifier_acc: 0.6341 - ICAE_classifier_precision_1: 0.5000 - ICAE_classifier_recall_1: 1.0000 - ICAE_classifier_false_negatives_1: 0.0000e+00 - ICAE_classifier_false_positives_1: 768.0000 - val_loss: 0.6176 - val_ICAE_decoder_loss: 0.4476 - val_ICAE_classifier_loss: 0.7128 - val_ICAE_decoder_mae: 0.0907 - val_ICAE_classifier_acc: 0.5781 - val_ICAE_classifier_precision_1: 0.5000 - val_ICAE_classifier_recall_1: 1.0000 - val_ICAE_classifier_false_negatives_1: 0.0000e+00 - val_ICAE_classifier_false_positives_1: 64.0000
# Epoch 20/50
# 24/24 [==============================] - 400s 17s/step - loss: 0.6610 - ICAE_decoder_loss: 0.5588 - ICAE_classifier_loss: 0.6922 - ICAE_decoder_mae: 0.0613 - ICAE_classifier_acc: 0.6354 - ICAE_classifier_precision_1: 0.5000 - ICAE_classifier_recall_1: 1.0000 - ICAE_classifier_false_negatives_1: 0.0000e+00 - ICAE_classifier_false_positives_1: 768.0000 - val_loss: 0.6051 - val_ICAE_decoder_loss: 0.4543 - val_ICAE_classifier_loss: 0.6888 - val_ICAE_decoder_mae: 0.0941 - val_ICAE_classifier_acc: 0.6406 - val_ICAE_classifier_precision_1: 0.5000 - val_ICAE_classifier_recall_1: 1.0000 - val_ICAE_classifier_false_negatives_1: 0.0000e+00 - val_ICAE_classifier_false_positives_1: 64.0000
# Epoch 21/50
# 24/24 [==============================] - 411s 17s/step - loss: 0.6596 - ICAE_decoder_loss: 0.5620 - ICAE_classifier_loss: 0.6932 - ICAE_decoder_mae: 0.0609 - ICAE_classifier_acc: 0.6328 - ICAE_classifier_precision_1: 0.5000 - ICAE_classifier_recall_1: 1.0000 - ICAE_classifier_false_negatives_1: 0.0000e+00 - ICAE_classifier_false_positives_1: 768.0000 - val_loss: 0.5954 - val_ICAE_decoder_loss: 0.4476 - val_ICAE_classifier_loss: 0.6828 - val_ICAE_decoder_mae: 0.0885 - val_ICAE_classifier_acc: 0.6562 - val_ICAE_classifier_precision_1: 0.5000 - val_ICAE_classifier_recall_1: 1.0000 - val_ICAE_classifier_false_negatives_1: 0.0000e+00 - val_ICAE_classifier_false_positives_1: 64.0000
# Epoch 22/50
# 24/24 [==============================] - 398s 17s/step - loss: 0.6541 - ICAE_decoder_loss: 0.5583 - ICAE_classifier_loss: 0.6922 - ICAE_decoder_mae: 0.0619 - ICAE_classifier_acc: 0.6354 - ICAE_classifier_precision_1: 0.5000 - ICAE_classifier_recall_1: 1.0000 - ICAE_classifier_false_negatives_1: 0.0000e+00 - ICAE_classifier_false_positives_1: 768.0000 - val_loss: 0.6004 - val_ICAE_decoder_loss: 0.4515 - val_ICAE_classifier_loss: 0.6948 - val_ICAE_decoder_mae: 0.0921 - val_ICAE_classifier_acc: 0.6250 - val_ICAE_classifier_precision_1: 0.5000 - val_ICAE_classifier_recall_1: 1.0000 - val_ICAE_classifier_false_negatives_1: 0.0000e+00 - val_ICAE_classifier_false_positives_1: 64.0000
# Epoch 23/50
# 24/24 [==============================] - 399s 17s/step - loss: 0.6518 - ICAE_decoder_loss: 0.5587 - ICAE_classifier_loss: 0.6927 - ICAE_decoder_mae: 0.0614 - ICAE_classifier_acc: 0.6341 - ICAE_classifier_precision_1: 0.5000 - ICAE_classifier_recall_1: 1.0000 - ICAE_classifier_false_negatives_1: 0.0000e+00 - ICAE_classifier_false_positives_1: 768.0000 - val_loss: 0.6076 - val_ICAE_decoder_loss: 0.4529 - val_ICAE_classifier_loss: 0.7128 - val_ICAE_decoder_mae: 0.0927 - val_ICAE_classifier_acc: 0.5781 - val_ICAE_classifier_precision_1: 0.5000 - val_ICAE_classifier_recall_1: 1.0000 - val_ICAE_classifier_false_negatives_1: 0.0000e+00 - val_ICAE_classifier_false_positives_1: 64.0000
# Epoch 24/50
# 24/24 [==============================] - 402s 17s/step - loss: 0.6482 - ICAE_decoder_loss: 0.5568 - ICAE_classifier_loss: 0.6922 - ICAE_decoder_mae: 0.0613 - ICAE_classifier_acc: 0.6354 - ICAE_classifier_precision_1: 0.5000 - ICAE_classifier_recall_1: 1.0000 - ICAE_classifier_false_negatives_1: 0.0000e+00 - ICAE_classifier_false_positives_1: 768.0000 - val_loss: 0.5931 - val_ICAE_decoder_loss: 0.4523 - val_ICAE_classifier_loss: 0.6888 - val_ICAE_decoder_mae: 0.0905 - val_ICAE_classifier_acc: 0.6406 - val_ICAE_classifier_precision_1: 0.5000 - val_ICAE_classifier_recall_1: 1.0000 - val_ICAE_classifier_false_negatives_1: 0.0000e+00 - val_ICAE_classifier_false_positives_1: 64.0000
# Epoch 25/50
# 24/24 [==============================] - 415s 17s/step - loss: 0.6440 - ICAE_decoder_loss: 0.5521 - ICAE_classifier_loss: 0.6927 - ICAE_decoder_mae: 0.0627 - ICAE_classifier_acc: 0.6341 - ICAE_classifier_precision_1: 0.5000 - ICAE_classifier_recall_1: 1.0000 - ICAE_classifier_false_negatives_1: 0.0000e+00 - ICAE_classifier_false_positives_1: 768.0000 - val_loss: 0.5923 - val_ICAE_decoder_loss: 0.4545 - val_ICAE_classifier_loss: 0.6888 - val_ICAE_decoder_mae: 0.0919 - val_ICAE_classifier_acc: 0.6406 - val_ICAE_classifier_precision_1: 0.5000 - val_ICAE_classifier_recall_1: 1.0000 - val_ICAE_classifier_false_negatives_1: 0.0000e+00 - val_ICAE_classifier_false_positives_1: 64.0000
# Epoch 26/50
# 24/24 [==============================] - 402s 17s/step - loss: 0.6472 - ICAE_decoder_loss: 0.5630 - ICAE_classifier_loss: 0.6917 - ICAE_decoder_mae: 0.0607 - ICAE_classifier_acc: 0.6367 - ICAE_classifier_precision_1: 0.5000 - ICAE_classifier_recall_1: 1.0000 - ICAE_classifier_false_negatives_1: 0.0000e+00 - ICAE_classifier_false_positives_1: 768.0000 - val_loss: 0.5938 - val_ICAE_decoder_loss: 0.4548 - val_ICAE_classifier_loss: 0.6948 - val_ICAE_decoder_mae: 0.0926 - val_ICAE_classifier_acc: 0.6250 - val_ICAE_classifier_precision_1: 0.5000 - val_ICAE_classifier_recall_1: 1.0000 - val_ICAE_classifier_false_negatives_1: 0.0000e+00 - val_ICAE_classifier_false_positives_1: 64.0000
# Epoch 27/50
# 24/24 [==============================] - 416s 17s/step - loss: 0.6415 - ICAE_decoder_loss: 0.5524 - ICAE_classifier_loss: 0.6938 - ICAE_decoder_mae: 0.0612 - ICAE_classifier_acc: 0.6315 - ICAE_classifier_precision_1: 0.5000 - ICAE_classifier_recall_1: 1.0000 - ICAE_classifier_false_negatives_1: 0.0000e+00 - ICAE_classifier_false_positives_1: 768.0000 - val_loss: 0.5971 - val_ICAE_decoder_loss: 0.4518 - val_ICAE_classifier_loss: 0.7068 - val_ICAE_decoder_mae: 0.0941 - val_ICAE_classifier_acc: 0.5938 - val_ICAE_classifier_precision_1: 0.5000 - val_ICAE_classifier_recall_1: 1.0000 - val_ICAE_classifier_false_negatives_1: 0.0000e+00 - val_ICAE_classifier_false_positives_1: 64.0000
# Epoch 28/50
# 24/24 [==============================] - 412s 17s/step - loss: 0.6432 - ICAE_decoder_loss: 0.5577 - ICAE_classifier_loss: 0.6943 - ICAE_decoder_mae: 0.0612 - ICAE_classifier_acc: 0.6302 - ICAE_classifier_precision_1: 0.5000 - ICAE_classifier_recall_1: 1.0000 - ICAE_classifier_false_negatives_1: 0.0000e+00 - ICAE_classifier_false_positives_1: 768.0000 - val_loss: 0.5856 - val_ICAE_decoder_loss: 0.4550 - val_ICAE_classifier_loss: 0.6828 - val_ICAE_decoder_mae: 0.0941 - val_ICAE_classifier_acc: 0.6562 - val_ICAE_classifier_precision_1: 0.5000 - val_ICAE_classifier_recall_1: 1.0000 - val_ICAE_classifier_false_negatives_1: 0.0000e+00 - val_ICAE_classifier_false_positives_1: 64.0000
# Epoch 29/50
# 24/24 [==============================] - 392s 16s/step - loss: 0.6386 - ICAE_decoder_loss: 0.5524 - ICAE_classifier_loss: 0.6922 - ICAE_decoder_mae: 0.0611 - ICAE_classifier_acc: 0.6354 - ICAE_classifier_precision_1: 0.5000 - ICAE_classifier_recall_1: 1.0000 - ICAE_classifier_false_negatives_1: 0.0000e+00 - ICAE_classifier_false_positives_1: 768.0000 - val_loss: 0.5916 - val_ICAE_decoder_loss: 0.4507 - val_ICAE_classifier_loss: 0.7008 - val_ICAE_decoder_mae: 0.0901 - val_ICAE_classifier_acc: 0.6094 - val_ICAE_classifier_precision_1: 0.5000 - val_ICAE_classifier_recall_1: 1.0000 - val_ICAE_classifier_false_negatives_1: 0.0000e+00 - val_ICAE_classifier_false_positives_1: 64.0000
# Epoch 30/50
# 24/24 [==============================] - 397s 17s/step - loss: 0.6401 - ICAE_decoder_loss: 0.5566 - ICAE_classifier_loss: 0.6927 - ICAE_decoder_mae: 0.0597 - ICAE_classifier_acc: 0.6341 - ICAE_classifier_precision_1: 0.5000 - ICAE_classifier_recall_1: 1.0000 - ICAE_classifier_false_negatives_1: 0.0000e+00 - ICAE_classifier_false_positives_1: 768.0000 - val_loss: 0.5900 - val_ICAE_decoder_loss: 0.4492 - val_ICAE_classifier_loss: 0.7008 - val_ICAE_decoder_mae: 0.0909 - val_ICAE_classifier_acc: 0.6094 - val_ICAE_classifier_precision_1: 0.5000 - val_ICAE_classifier_recall_1: 1.0000 - val_ICAE_classifier_false_negatives_1: 0.0000e+00 - val_ICAE_classifier_false_positives_1: 64.0000
# Epoch 31/50
# 24/24 [==============================] - 414s 17s/step - loss: 0.6411 - ICAE_decoder_loss: 0.5581 - ICAE_classifier_loss: 0.6948 - ICAE_decoder_mae: 0.0589 - ICAE_classifier_acc: 0.6289 - ICAE_classifier_precision_1: 0.5000 - ICAE_classifier_recall_1: 1.0000 - ICAE_classifier_false_negatives_1: 0.0000e+00 - ICAE_classifier_false_positives_1: 768.0000 - val_loss: 0.5863 - val_ICAE_decoder_loss: 0.4492 - val_ICAE_classifier_loss: 0.6948 - val_ICAE_decoder_mae: 0.0915 - val_ICAE_classifier_acc: 0.6250 - val_ICAE_classifier_precision_1: 0.5000 - val_ICAE_classifier_recall_1: 1.0000 - val_ICAE_classifier_false_negatives_1: 0.0000e+00 - val_ICAE_classifier_false_positives_1: 64.0000
# Epoch 32/50
# 24/24 [==============================] - 393s 16s/step - loss: 0.6403 - ICAE_decoder_loss: 0.5588 - ICAE_classifier_loss: 0.6938 - ICAE_decoder_mae: 0.0589 - ICAE_classifier_acc: 0.6315 - ICAE_classifier_precision_1: 0.5000 - ICAE_classifier_recall_1: 1.0000 - ICAE_classifier_false_negatives_1: 0.0000e+00 - ICAE_classifier_false_positives_1: 768.0000 - val_loss: 0.5789 - val_ICAE_decoder_loss: 0.4537 - val_ICAE_classifier_loss: 0.6768 - val_ICAE_decoder_mae: 0.0936 - val_ICAE_classifier_acc: 0.6719 - val_ICAE_classifier_precision_1: 0.5000 - val_ICAE_classifier_recall_1: 1.0000 - val_ICAE_classifier_false_negatives_1: 0.0000e+00 - val_ICAE_classifier_false_positives_1: 64.0000
# Epoch 33/50
# 24/24 [==============================] - 430s 18s/step - loss: 0.6396 - ICAE_decoder_loss: 0.5593 - ICAE_classifier_loss: 0.6932 - ICAE_decoder_mae: 0.0583 - ICAE_classifier_acc: 0.6328 - ICAE_classifier_precision_1: 0.5000 - ICAE_classifier_recall_1: 1.0000 - ICAE_classifier_false_negatives_1: 0.0000e+00 - ICAE_classifier_false_positives_1: 768.0000 - val_loss: 0.5958 - val_ICAE_decoder_loss: 0.4527 - val_ICAE_classifier_loss: 0.7128 - val_ICAE_decoder_mae: 0.0924 - val_ICAE_classifier_acc: 0.5781 - val_ICAE_classifier_precision_1: 0.5000 - val_ICAE_classifier_recall_1: 1.0000 - val_ICAE_classifier_false_negatives_1: 0.0000e+00 - val_ICAE_classifier_false_positives_1: 64.0000
# Epoch 34/50
# 24/24 [==============================] - 408s 17s/step - loss: 0.6360 - ICAE_decoder_loss: 0.5543 - ICAE_classifier_loss: 0.6922 - ICAE_decoder_mae: 0.0594 - ICAE_classifier_acc: 0.6354 - ICAE_classifier_precision_1: 0.5000 - ICAE_classifier_recall_1: 1.0000 - ICAE_classifier_false_negatives_1: 0.0000e+00 - ICAE_classifier_false_positives_1: 768.0000 - val_loss: 0.5864 - val_ICAE_decoder_loss: 0.4472 - val_ICAE_classifier_loss: 0.7008 - val_ICAE_decoder_mae: 0.0884 - val_ICAE_classifier_acc: 0.6094 - val_ICAE_classifier_precision_1: 0.5000 - val_ICAE_classifier_recall_1: 1.0000 - val_ICAE_classifier_false_negatives_1: 0.0000e+00 - val_ICAE_classifier_false_positives_1: 64.0000
# Epoch 35/50
# 24/24 [==============================] - 414s 17s/step - loss: 0.6390 - ICAE_decoder_loss: 0.5620 - ICAE_classifier_loss: 0.6917 - ICAE_decoder_mae: 0.0585 - ICAE_classifier_acc: 0.6367 - ICAE_classifier_precision_1: 0.5000 - ICAE_classifier_recall_1: 1.0000 - ICAE_classifier_false_negatives_1: 0.0000e+00 - ICAE_classifier_false_positives_1: 768.0000 - val_loss: 0.5812 - val_ICAE_decoder_loss: 0.4498 - val_ICAE_classifier_loss: 0.6888 - val_ICAE_decoder_mae: 0.0902 - val_ICAE_classifier_acc: 0.6406 - val_ICAE_classifier_precision_1: 0.5000 - val_ICAE_classifier_recall_1: 1.0000 - val_ICAE_classifier_false_negatives_1: 0.0000e+00 - val_ICAE_classifier_false_positives_1: 64.0000
# Epoch 36/50
# 24/24 [==============================] - 420s 18s/step - loss: 0.6378 - ICAE_decoder_loss: 0.5585 - ICAE_classifier_loss: 0.6938 - ICAE_decoder_mae: 0.0581 - ICAE_classifier_acc: 0.6315 - ICAE_classifier_precision_1: 0.5000 - ICAE_classifier_recall_1: 1.0000 - ICAE_classifier_false_negatives_1: 0.0000e+00 - ICAE_classifier_false_positives_1: 768.0000 - val_loss: 0.5803 - val_ICAE_decoder_loss: 0.4491 - val_ICAE_classifier_loss: 0.6888 - val_ICAE_decoder_mae: 0.0912 - val_ICAE_classifier_acc: 0.6406 - val_ICAE_classifier_precision_1: 0.5000 - val_ICAE_classifier_recall_1: 1.0000 - val_ICAE_classifier_false_negatives_1: 0.0000e+00 - val_ICAE_classifier_false_positives_1: 64.0000
# Epoch 37/50
# 24/24 [==============================] - 413s 17s/step - loss: 0.6369 - ICAE_decoder_loss: 0.5589 - ICAE_classifier_loss: 0.6927 - ICAE_decoder_mae: 0.0590 - ICAE_classifier_acc: 0.6341 - ICAE_classifier_precision_1: 0.5000 - ICAE_classifier_recall_1: 1.0000 - ICAE_classifier_false_negatives_1: 0.0000e+00 - ICAE_classifier_false_positives_1: 768.0000 - val_loss: 0.5750 - val_ICAE_decoder_loss: 0.4514 - val_ICAE_classifier_loss: 0.6768 - val_ICAE_decoder_mae: 0.0917 - val_ICAE_classifier_acc: 0.6719 - val_ICAE_classifier_precision_1: 0.5000 - val_ICAE_classifier_recall_1: 1.0000 - val_ICAE_classifier_false_negatives_1: 0.0000e+00 - val_ICAE_classifier_false_positives_1: 64.0000
# Epoch 38/50
# 24/24 [==============================] - 405s 17s/step - loss: 0.6374 - ICAE_decoder_loss: 0.5608 - ICAE_classifier_loss: 0.6927 - ICAE_decoder_mae: 0.0578 - ICAE_classifier_acc: 0.6341 - ICAE_classifier_precision_1: 0.5000 - ICAE_classifier_recall_1: 1.0000 - ICAE_classifier_false_negatives_1: 0.0000e+00 - ICAE_classifier_false_positives_1: 768.0000 - val_loss: 0.5799 - val_ICAE_decoder_loss: 0.4501 - val_ICAE_classifier_loss: 0.6888 - val_ICAE_decoder_mae: 0.0885 - val_ICAE_classifier_acc: 0.6406 - val_ICAE_classifier_precision_1: 0.5000 - val_ICAE_classifier_recall_1: 1.0000 - val_ICAE_classifier_false_negatives_1: 0.0000e+00 - val_ICAE_classifier_false_positives_1: 64.0000
# Epoch 39/50
# 24/24 [==============================] - 416s 17s/step - loss: 0.6368 - ICAE_decoder_loss: 0.5599 - ICAE_classifier_loss: 0.6932 - ICAE_decoder_mae: 0.0574 - ICAE_classifier_acc: 0.6328 - ICAE_classifier_precision_1: 0.5000 - ICAE_classifier_recall_1: 1.0000 - ICAE_classifier_false_negatives_1: 0.0000e+00 - ICAE_classifier_false_positives_1: 768.0000 - val_loss: 0.5742 - val_ICAE_decoder_loss: 0.4517 - val_ICAE_classifier_loss: 0.6768 - val_ICAE_decoder_mae: 0.0909 - val_ICAE_classifier_acc: 0.6719 - val_ICAE_classifier_precision_1: 0.5000 - val_ICAE_classifier_recall_1: 1.0000 - val_ICAE_classifier_false_negatives_1: 0.0000e+00 - val_ICAE_classifier_false_positives_1: 64.0000
# Epoch 40/50
# 24/24 [==============================] - 409s 17s/step - loss: 0.6303 - ICAE_decoder_loss: 0.5489 - ICAE_classifier_loss: 0.6922 - ICAE_decoder_mae: 0.0588 - ICAE_classifier_acc: 0.6354 - ICAE_classifier_precision_1: 0.5000 - ICAE_classifier_recall_1: 1.0000 - ICAE_classifier_false_negatives_1: 0.0000e+00 - ICAE_classifier_false_positives_1: 768.0000 - val_loss: 0.5793 - val_ICAE_decoder_loss: 0.4507 - val_ICAE_classifier_loss: 0.6888 - val_ICAE_decoder_mae: 0.0899 - val_ICAE_classifier_acc: 0.6406 - val_ICAE_classifier_precision_1: 0.5000 - val_ICAE_classifier_recall_1: 1.0000 - val_ICAE_classifier_false_negatives_1: 0.0000e+00 - val_ICAE_classifier_false_positives_1: 64.0000
# Epoch 41/50
# 24/24 [==============================] - 410s 17s/step - loss: 0.6347 - ICAE_decoder_loss: 0.5580 - ICAE_classifier_loss: 0.6927 - ICAE_decoder_mae: 0.0585 - ICAE_classifier_acc: 0.6341 - ICAE_classifier_precision_1: 0.5000 - ICAE_classifier_recall_1: 1.0000 - ICAE_classifier_false_negatives_1: 0.0000e+00 - ICAE_classifier_false_positives_1: 768.0000 - val_loss: 0.5878 - val_ICAE_decoder_loss: 0.4505 - val_ICAE_classifier_loss: 0.7068 - val_ICAE_decoder_mae: 0.0918 - val_ICAE_classifier_acc: 0.5938 - val_ICAE_classifier_precision_1: 0.5000 - val_ICAE_classifier_recall_1: 1.0000 - val_ICAE_classifier_false_negatives_1: 0.0000e+00 - val_ICAE_classifier_false_positives_1: 64.0000
# Epoch 42/50
# 24/24 [==============================] - 413s 17s/step - loss: 0.6338 - ICAE_decoder_loss: 0.5564 - ICAE_classifier_loss: 0.6932 - ICAE_decoder_mae: 0.0587 - ICAE_classifier_acc: 0.6328 - ICAE_classifier_precision_1: 0.5000 - ICAE_classifier_recall_1: 1.0000 - ICAE_classifier_false_negatives_1: 0.0000e+00 - ICAE_classifier_false_positives_1: 768.0000 - val_loss: 0.5729 - val_ICAE_decoder_loss: 0.4514 - val_ICAE_classifier_loss: 0.6768 - val_ICAE_decoder_mae: 0.0911 - val_ICAE_classifier_acc: 0.6719 - val_ICAE_classifier_precision_1: 0.5000 - val_ICAE_classifier_recall_1: 1.0000 - val_ICAE_classifier_false_negatives_1: 0.0000e+00 - val_ICAE_classifier_false_positives_1: 64.0000
# Epoch 43/50
# 24/24 [==============================] - 409s 17s/step - loss: 0.6330 - ICAE_decoder_loss: 0.5545 - ICAE_classifier_loss: 0.6943 - ICAE_decoder_mae: 0.0616 - ICAE_classifier_acc: 0.6302 - ICAE_classifier_precision_1: 0.5000 - ICAE_classifier_recall_1: 1.0000 - ICAE_classifier_false_negatives_1: 0.0000e+00 - ICAE_classifier_false_positives_1: 768.0000 - val_loss: 0.5730 - val_ICAE_decoder_loss: 0.4522 - val_ICAE_classifier_loss: 0.6768 - val_ICAE_decoder_mae: 0.0901 - val_ICAE_classifier_acc: 0.6719 - val_ICAE_classifier_precision_1: 0.5000 - val_ICAE_classifier_recall_1: 1.0000 - val_ICAE_classifier_false_negatives_1: 0.0000e+00 - val_ICAE_classifier_false_positives_1: 64.0000
# Epoch 44/50
# 24/24 [==============================] - 402s 17s/step - loss: 0.6341 - ICAE_decoder_loss: 0.5594 - ICAE_classifier_loss: 0.6922 - ICAE_decoder_mae: 0.0575 - ICAE_classifier_acc: 0.6354 - ICAE_classifier_precision_1: 0.5000 - ICAE_classifier_recall_1: 1.0000 - ICAE_classifier_false_negatives_1: 0.0000e+00 - ICAE_classifier_false_positives_1: 768.0000 - val_loss: 0.5780 - val_ICAE_decoder_loss: 0.4510 - val_ICAE_classifier_loss: 0.6888 - val_ICAE_decoder_mae: 0.0905 - val_ICAE_classifier_acc: 0.6406 - val_ICAE_classifier_precision_1: 0.5000 - val_ICAE_classifier_recall_1: 1.0000 - val_ICAE_classifier_false_negatives_1: 0.0000e+00 - val_ICAE_classifier_false_positives_1: 64.0000
# Epoch 45/50
# 24/24 [==============================] - 400s 17s/step - loss: 0.6327 - ICAE_decoder_loss: 0.5555 - ICAE_classifier_loss: 0.6937 - ICAE_decoder_mae: 0.0570 - ICAE_classifier_acc: 0.6315 - ICAE_classifier_precision_1: 0.5000 - ICAE_classifier_recall_1: 1.0000 - ICAE_classifier_false_negatives_1: 0.0000e+00 - ICAE_classifier_false_positives_1: 768.0000 - val_loss: 0.5814 - val_ICAE_decoder_loss: 0.4462 - val_ICAE_classifier_loss: 0.7008 - val_ICAE_decoder_mae: 0.0879 - val_ICAE_classifier_acc: 0.6094 - val_ICAE_classifier_precision_1: 0.5000 - val_ICAE_classifier_recall_1: 1.0000 - val_ICAE_classifier_false_negatives_1: 0.0000e+00 - val_ICAE_classifier_false_positives_1: 64.0000
# Epoch 46/50
# 24/24 [==============================] - 396s 17s/step - loss: 0.6343 - ICAE_decoder_loss: 0.5604 - ICAE_classifier_loss: 0.6927 - ICAE_decoder_mae: 0.0577 - ICAE_classifier_acc: 0.6341 - ICAE_classifier_precision_1: 0.5000 - ICAE_classifier_recall_1: 1.0000 - ICAE_classifier_false_negatives_1: 0.0000e+00 - ICAE_classifier_false_positives_1: 768.0000 - val_loss: 0.5778 - val_ICAE_decoder_loss: 0.4516 - val_ICAE_classifier_loss: 0.6888 - val_ICAE_decoder_mae: 0.0920 - val_ICAE_classifier_acc: 0.6406 - val_ICAE_classifier_precision_1: 0.5000 - val_ICAE_classifier_recall_1: 1.0000 - val_ICAE_classifier_false_negatives_1: 0.0000e+00 - val_ICAE_classifier_false_positives_1: 64.0000
# Epoch 47/50
# 24/24 [==============================] - 408s 17s/step - loss: 0.6273 - ICAE_decoder_loss: 0.5457 - ICAE_classifier_loss: 0.6939 - ICAE_decoder_mae: 0.0592 - ICAE_classifier_acc: 0.6302 - ICAE_classifier_precision_1: 0.5003 - ICAE_classifier_recall_1: 1.0000 - ICAE_classifier_false_negatives_1: 0.0000e+00 - ICAE_classifier_false_positives_1: 767.0000 - val_loss: 0.5889 - val_ICAE_decoder_loss: 0.4468 - val_ICAE_classifier_loss: 0.7162 - val_ICAE_decoder_mae: 0.0878 - val_ICAE_classifier_acc: 0.5781 - val_ICAE_classifier_precision_1: 0.5000 - val_ICAE_classifier_recall_1: 1.0000 - val_ICAE_classifier_false_negatives_1: 0.0000e+00 - val_ICAE_classifier_false_positives_1: 64.0000
# Epoch 48/50
# 24/24 [==============================] - 403s 17s/step - loss: 0.6301 - ICAE_decoder_loss: 0.5514 - ICAE_classifier_loss: 0.6939 - ICAE_decoder_mae: 0.0584 - ICAE_classifier_acc: 0.4453 - ICAE_classifier_precision_1: 0.5010 - ICAE_classifier_recall_1: 1.0000 - ICAE_classifier_false_negatives_1: 0.0000e+00 - ICAE_classifier_false_positives_1: 765.0000 - val_loss: 0.5731 - val_ICAE_decoder_loss: 0.4485 - val_ICAE_classifier_loss: 0.6828 - val_ICAE_decoder_mae: 0.0857 - val_ICAE_classifier_acc: 0.3438 - val_ICAE_classifier_precision_1: 0.5000 - val_ICAE_classifier_recall_1: 1.0000 - val_ICAE_classifier_false_negatives_1: 0.0000e+00 - val_ICAE_classifier_false_positives_1: 64.0000
# Epoch 49/50
# 24/24 [==============================] - 402s 17s/step - loss: 0.6318 - ICAE_decoder_loss: 0.5559 - ICAE_classifier_loss: 0.6932 - ICAE_decoder_mae: 0.0577 - ICAE_classifier_acc: 0.3672 - ICAE_classifier_precision_1: 0.5000 - ICAE_classifier_recall_1: 1.0000 - ICAE_classifier_false_negatives_1: 0.0000e+00 - ICAE_classifier_false_positives_1: 768.0000 - val_loss: 0.5814 - val_ICAE_decoder_loss: 0.4478 - val_ICAE_classifier_loss: 0.7008 - val_ICAE_decoder_mae: 0.0870 - val_ICAE_classifier_acc: 0.3906 - val_ICAE_classifier_precision_1: 0.5000 - val_ICAE_classifier_recall_1: 1.0000 - val_ICAE_classifier_false_negatives_1: 0.0000e+00 - val_ICAE_classifier_false_positives_1: 64.0000
# Epoch 50/50
# 24/24 [==============================] - 401s 17s/step - loss: 0.6302 - ICAE_decoder_loss: 0.5538 - ICAE_classifier_loss: 0.6927 - ICAE_decoder_mae: 0.0585 - ICAE_classifier_acc: 0.3659 - ICAE_classifier_precision_1: 0.5000 - ICAE_classifier_recall_1: 1.0000 - ICAE_classifier_false_negatives_1: 0.0000e+00 - ICAE_classifier_false_positives_1: 768.0000 - val_loss: 0.5864 - val_ICAE_decoder_loss: 0.4463 - val_ICAE_classifier_loss: 0.7128 - val_ICAE_decoder_mae: 0.0870 - val_ICAE_classifier_acc: 0.4219 - val_ICAE_classifier_precision_1: 0.5000 - val_ICAE_classifier_recall_1: 1.0000 - val_ICAE_classifier_false_negatives_1: 0.0000e+00 - val_ICAE_classifier_false_positives_1: 64.0000

# %%
ICAE_autoencoder.save('ICAE_autoencoder_nodo_5-22.h5')
with open('outputs_AC/trainHistoryDict', 'wb') as file_pi:
        pickle.dump(history_ICAE_extra.history, file_pi)
plt.plot(history_ICAE_extra.history['loss'])
plt.plot(history_ICAE_extra.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# %%
history_ICAE_extra.history.keys()
# Out:
# dict_keys(['loss', 'ICAE_decoder_loss', 'ICAE_classifier_loss', 'ICAE_decoder_mae', 'ICAE_classifier_acc', 'ICAE_classifier_precision_1', 'ICAE_classifier_recall_1', 'ICAE_classifier_false_negatives_1', 'ICAE_classifier_false_positives_1', 'val_loss', 'val_ICAE_decoder_loss', 'val_ICAE_classifier_loss', 'val_ICAE_decoder_mae', 'val_ICAE_classifier_acc', 'val_ICAE_classifier_precision_1', 'val_ICAE_classifier_recall_1', 'val_ICAE_classifier_false_negatives_1', 'val_ICAE_classifier_false_positives_1'])

# %%
plt.plot(history_ICAE_extra.history['ICAE_classifier_acc'])
plt.plot(history_ICAE_extra.history['val_ICAE_classifier_acc'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# %%
plt.plot(history_ICAE_extra.history['ICAE_classifier_precision_1'])
plt.plot(history_ICAE_extra.history['val_ICAE_classifier_precision_1'])
plt.title('model precision')
plt.ylabel('precision')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# %%
balancing_weights_val = class_weight.compute_sample_weight('balanced',val_label)
val_generator = MyDataGenerator(val_list, processed_dir,to_fit=False, batch_size=2,sample_weight=balancing_weights_val)
pred = ICAE_autoencoder.predict_generator(val_generator)
# Out:
# WARNING:tensorflow:From <ipython-input-24-5366bf302948>:3: Model.predict_generator (from tensorflow.python.keras.engine.training) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use Model.predict, which supports generators.

# %%
from sklearn.metrics import classification_report,accuracy_score
print("acc: ",accuracy_score(labels_to_categorical(val_label),np.round(pred[1])))
print(classification_report(labels_to_categorical(val_label),np.round(pred[1])))
# Out:
# acc:  0.0
#               precision    recall  f1-score   support
#
#            0       0.37      1.00      0.54        36
#            1       0.63      1.00      0.78        62
#
#    micro avg       0.50      1.00      0.67        98
#    macro avg       0.50      1.00      0.66        98
# weighted avg       0.54      1.00      0.69        98
#  samples avg       0.50      1.00      0.67        98

# %%
with open('outputs_AC/trainHistoryDict', 'rb') as file_pi:
  test = pickle.load(file_pi)

# %%
test['loss'][-10:]
# Out:
# [0.6347494125366211,
#  0.6338274478912354,
#  0.6330187320709229,
#  0.6341151595115662,
#  0.6326807141304016,
#  0.6343065500259399,
#  0.6273400783538818,
#  0.6301496624946594,
#  0.6318227052688599,
#  0.6301940083503723]

# %%
plt.imshow(pred[0][2][:,:,15,0])
plt.show()
plt.imshow(pred[0][2][:,:,0,0])

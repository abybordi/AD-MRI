# %%
# %matplotlib inline 
from matplotlib import pyplot as plt
import numpy as np
import pandas as pd
import pickle
import warnings
import tensorflow as tf
import random
import scipy
import cv2
from tensorflow.keras.utils import Sequence
from tensorflow.keras.utils import to_categorical
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.utils import class_weight
from tensorflow import keras
from tensorflow.keras import backend as K
from tensorflow.keras.callbacks import TensorBoard
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import Dense, Conv3D, MaxPool3D, Dropout, \
        Flatten, Conv3DTranspose, UpSampling3D, Reshape, Input, concatenate
from tensorflow.keras.regularizers import l1_l2
from google.colab import drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
import tensorflow as tf
print('Tensorflow version:', tf.__version__)
# Out:
# Tensorflow version: 2.2.0

# %% [markdown]
# #### Create Train/Test Subset

# %%
# %cd /content/drive/My Drive/AD_MRI

# Load list of records
with open('AD_MRI_Master', 'rb') as f:
    master_list = pickle.load(f)
    
master_sheet = pd.DataFrame.from_dict(master_list, orient='index')
display(master_sheet.head())
print()

# Split: 80% train, 10% validation, 10% test
train_list, val_list, train_label, val_label = \
        train_test_split(master_sheet.subject.values, 
                         master_sheet.diagnosis.values, 
                         random_state = 1337, 
                         test_size=0.10)
        
train_list,test_list,train_label,test_label = \
        train_test_split(train_list, 
                         train_label, 
                         random_state = 0, 
                         test_size=0.10)

# Check for ratios of AD to NC to be consistent among sets
AD_count = 0
for lab in train_label:
    if lab == 'AD':
        AD_count +=1
print('train_ratio AD: ', round(AD_count/len(train_label), 3))

AD_count = 0
for lab in val_label:
    if lab == 'AD':
        AD_count +=1
print('val_ratio AD: ', round(AD_count/len(val_label), 3))

AD_count = 0
for lab in test_label:
    if lab == 'AD':
        AD_count +=1
print('test_ratio AD: ', round(AD_count/len(test_label), 3))

print('\nNumber of records\ntrain:', len(train_list), 
      '\nvalidation:', len(val_list), '\ntest:', len(test_list))
# Out:
# /content/drive/.shortcut-targets-by-id/1oU0ruELKPJf457X2y4uyGIpFkyyxaQyv/AD_MRI
#            subject   age diagnosis            scan_ID
# OAS30001  OAS30001  65.0        CN  OAS30001_MR_d0129
# OAS30002  OAS30002  68.0        CN  OAS30002_MR_d0371
# OAS30003  OAS30003  60.0        CN  OAS30003_MR_d0558
# OAS30004  OAS30004  58.0        CN  OAS30004_MR_d1101
# OAS30005  OAS30005  48.0        CN  OAS30005_MR_d0143
# train_ratio AD:  0.367
# val_ratio AD:  0.367
# test_ratio AD:  0.371
#
# Number of records
# train: 793
# validation: 98
# test: 89

# %% [markdown]
# #### Create Generator

# %%
processed_dir = '/content/drive/My Drive/AD_MRI/PROCESSED/'

# custom data generator.
import random
import scipy
import numpy as np
import cv2
from tensorflow.keras.utils import Sequence
from tensorflow.keras.utils import to_categorical
from sklearn.preprocessing import LabelEncoder
import random

import scipy


def labels_to_categorical(labels):
    le = LabelEncoder()
    le.fit(["CN", "AD"])
    num_lab=to_categorical(le.transform(labels),num_classes=2)
    return num_lab

def my_minmax(z):
    return (z-np.min(z))/(np.max(z)-np.min(z))

# Custom data generator
class MyDataGenerator(Sequence):
    """Generates data for Keras Sequence based data generator. 
    Suitable for building data generator for training and prediction.
    """
    def __init__(self, list_IDs, processed_dir, augment=False, 
                 to_fit=True, batch_size=32, dim=(120, 160, 120, 1),
                 n_classes=2, shuffle=True, ventricles_only=True, 
                 slice_start=50, slice_end=66, sample_weight=None):
        """Initialization
        :param list_IDs: list of all 'label' PATHS
        :param processed_dir: path to directory of processed images
        :param augment
        :param to_fit: True to return X and y, False to return X only
        :param batch_size: batch size at each iteration
        :param dim: tuple indicating image dimension
        :param n_classes: number of output masks
        :param shuffle: True to shuffle label indexes after every epoch
        :param ventricles_only: reduce dimensions to relevant slice
        """
        self.list_IDs = list_IDs
        self.processed_dir = processed_dir
        self.augment = augment
        self.to_fit = to_fit
        self.batch_size = batch_size
        self.dim = dim
        self.n_classes = n_classes
        self.shuffle = shuffle
        self.ventricles_only = ventricles_only
        self.on_epoch_end()
        self.slice_start = slice_start
        self.slice_end = slice_end
        if self.ventricles_only == False:
            self.slice_size = 120
        else:
            self.slice_size = slice_end - slice_start
        self.sample_weight = sample_weight
        # sample_weight needs to be provided if to_fit=True


    def __len__(self):
        """Denotes the number of batches per epoch
        :return: number of batches per epoch
        """
        return int(np.floor(len(self.list_IDs) / self.batch_size))


    def __getitem__(self, index):
        """Generate one batch of data
        :param index: index of the batch
        :return: X and y when fitting. X only when predicting
        """
        # Generate indexes of the batch
        indexes = self.indexes[index 
                               * self.batch_size:(index + 1) 
                               * self.batch_size]

        # Find list of IDs
        list_IDs_temp = [self.list_IDs[k] for k in indexes]
        
        # Generate data
        X, y = self._load_data(list_IDs_temp)
        X = my_minmax(np.float32(X))
        if self.ventricles_only == True:
          X = X[:, :, :, self.slice_start:self.slice_end, :]
          w_temp = np.asarray([self.sample_weight[k] for k in indexes])
        if self.to_fit:
            ## broken for noAE
            # y = {'CAE_classifier': y}
            # w = {'CAE_classifier': w_temp}
            w_temp = np.asarray([self.sample_weight[k] for k in indexes])
            return X, y, w_temp
        else:
            return X
        # if self.to_fit:
        #     y = {'CAE_classifier': y, 'CAE_decoder': X}
        #     w = {'CAE_classifier': w_temp,
        #          'CAE_decoder':np.ones(np.shape(X))}
        #     return X, y, w
        # else:
        #     return X


    def on_epoch_end(self):
        """Updates indexes after each epoch
        """
        self.indexes = np.arange(len(self.list_IDs))
        if self.shuffle == True:
            np.random.shuffle(self.indexes)


    def _load_data(self, list_IDs_temp):
        """Generates data containing batch_size images
        :param list_IDs_temp: list of label ids to load
        :return: batch of images
        """
        # Initialization
        X = np.empty((self.batch_size, *self.dim))
        y = np.empty((self.batch_size, self.n_classes), dtype=int)
        
        # Generate data
        for i, ID in enumerate(list_IDs_temp):
            
            # start X
            with open(self.processed_dir+ID+'_data','rb') as f:
                data = pickle.load(f)
                
            # third dimension = 120, error using self.slice_size for value 16
            x_reshape= np.reshape(data['image'], (120, 160, 120, 1))
            if self.augment == True:
                x_reshape = scipy.ndimage.rotate(x_reshape, 
                                axes=random.choice([(0, 1), (0, 2), (1, 2)]), 
                                angle=random.choice([360-15, 15,0]), 
                                reshape=False)
            X[i,] = x_reshape
            
            #start y
            y[i,] = labels_to_categorical([data['diagnosis']])

        return X, y

# %%
print(labels_to_categorical(["CN"]))

balancing_weights = class_weight.compute_sample_weight('balanced',train_label)
print(balancing_weights[0],train_label[0])
print(balancing_weights[1],train_label[1])


# usage:
processed_dir = '/content/drive/My Drive/AD_MRI/PROCESSED/'
mdg = MyDataGenerator(test_list, processed_dir, to_fit=True, augment=True, 
                      sample_weight=balancing_weights,batch_size=2)

#X, pred, weights = mdg.__getitem__(0) #without .__getitem__ obviously
# Out:
# [[0. 1.]]
# 1.3625429553264605 AD
# 0.7898406374501992 CN

# %% [markdown]
# #### Building CAE Encoder

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import backend as K
from tensorflow.keras.callbacks import TensorBoard
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import Dense, Conv3D, MaxPool3D, Dropout, \
    Flatten, Conv3DTranspose, UpSampling3D, Reshape
from tensorflow.keras.layers import Input

# %%
dropout_rate = 0.0
input_img = Input(shape=(120, 160, 16, 1), name='Input')
print('\ninput shape:', input_img.shape)

x = Conv3D(10, (3, 3, 3), activation='relu', padding='same', 
           name='Convolution_1')(input_img)
x = MaxPool3D((2, 2, 2), name='MaxPooling_1')(x)
x = Dropout(dropout_rate, name='DropOut_1')(x)

x = Conv3D(10, (3, 3, 3), activation='relu', padding='same', 
           name='Convolution_2')(x)
x = MaxPool3D((2, 2, 2), name='MaxPooling_2')(x)
x = Dropout(dropout_rate, name='DropOut_2')(x)

x = Conv3D(10, (3, 3, 3), activation='relu', padding='same', 
           name='Convolution_3')(x)
x = MaxPool3D((2, 2, 2), name='MaxPooling_3')(x)
x = Dropout(dropout_rate, name='DropOut_3')(x)

encoded = x
encoded_shape = K.int_shape(encoded)
print('output shape:', encoded_shape, '\n')

CAE_encoder = Model(input_img, encoded, name='CAE_encoder')
CAE_encoder.summary()
# Out:
# input shape: (None, 120, 160, 16, 1)
# output shape: (None, 15, 20, 2, 10)
#
# Model: "CAE_encoder"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# Input (InputLayer)           [(None, 120, 160, 16, 1)] 0
# _________________________________________________________________
# Convolution_1 (Conv3D)       (None, 120, 160, 16, 10)  280
# _________________________________________________________________
# MaxPooling_1 (MaxPooling3D)  (None, 60, 80, 8, 10)     0
# _________________________________________________________________
# DropOut_1 (Dropout)          (None, 60, 80, 8, 10)     0
# _________________________________________________________________
# Convolution_2 (Conv3D)       (None, 60, 80, 8, 10)     2710
# _________________________________________________________________
# MaxPooling_2 (MaxPooling3D)  (None, 30, 40, 4, 10)     0
# _________________________________________________________________
# DropOut_2 (Dropout)          (None, 30, 40, 4, 10)     0
# _________________________________________________________________
# Convolution_3 (Conv3D)       (None, 30, 40, 4, 10)     2710
# _________________________________________________________________
# MaxPooling_3 (MaxPooling3D)  (None, 15, 20, 2, 10)     0
# _________________________________________________________________
# DropOut_3 (Dropout)          (None, 15, 20, 2, 10)     0
# =================================================================
# Total params: 5,700
# Trainable params: 5,700
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# #### Building CAE Decoder

# %%
encoded_shape
# Out:
# (None, 15, 20, 2, 10)

# %%
encoded_input = Input(shape=(encoded_shape[1],encoded_shape[2], 
                             encoded_shape[3], encoded_shape[4],), 
                      name='Encoded')

print('\ninput shape:', encoded_input.shape)
x = encoded_input

x = Conv3DTranspose(10, (3, 3, 3), activation='relu', padding='same', 
                    name='Convolution_3')(x)
x = UpSampling3D((2, 2, 2), name='UpSampling_3')(x)
x = Dropout(dropout_rate, name='DropOut_3')(x)

x = Conv3DTranspose(10, (3, 3, 3), activation='relu', padding='same', 
                    name='Convolution_2')(x)
x = UpSampling3D((2, 2, 2), name='UpSampling_2')(x)
x = Dropout(dropout_rate, name='DropOut_2')(x)

x = Conv3DTranspose(10, (3, 3, 3), activation='relu', padding='same', 
                    name='Convolution_1')(x)
x = UpSampling3D((2, 2, 2), name='UpSampling_1')(x)
x = Dropout(dropout_rate, name='DropOut_1')(x)

decoded = Conv3DTranspose(1, (3, 3, 3), activation='sigmoid', padding='same', 
                          name='Output')(x)

print('output shape:', K.int_shape(decoded), '\n')

CAE_decoder = Model(encoded_input, decoded, name='CAE_decoder')
CAE_decoder.summary()
# Out:
# input shape: (None, 15, 20, 2, 10)
# output shape: (None, 120, 160, 16, 1)
#
# Model: "CAE_decoder"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# Encoded (InputLayer)         [(None, 15, 20, 2, 10)]   0
# _________________________________________________________________
# Convolution_3 (Conv3DTranspo (None, 15, 20, 2, 10)     2710
# _________________________________________________________________
# UpSampling_3 (UpSampling3D)  (None, 30, 40, 4, 10)     0
# _________________________________________________________________
# DropOut_3 (Dropout)          (None, 30, 40, 4, 10)     0
# _________________________________________________________________
# Convolution_2 (Conv3DTranspo (None, 30, 40, 4, 10)     2710
# _________________________________________________________________
# UpSampling_2 (UpSampling3D)  (None, 60, 80, 8, 10)     0
# _________________________________________________________________
# DropOut_2 (Dropout)          (None, 60, 80, 8, 10)     0
# _________________________________________________________________
# Convolution_1 (Conv3DTranspo (None, 60, 80, 8, 10)     2710
# _________________________________________________________________
# UpSampling_1 (UpSampling3D)  (None, 120, 160, 16, 10)  0
# _________________________________________________________________
# DropOut_1 (Dropout)          (None, 120, 160, 16, 10)  0
# _________________________________________________________________
# Output (Conv3DTranspose)     (None, 120, 160, 16, 1)   271
# =================================================================
# Total params: 8,401
# Trainable params: 8,401
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# #### Building CAE Classifier

# %%
# CAE Classifier

encoded_input = Input(shape=(encoded_shape[1], encoded_shape[2], 
                             encoded_shape[3], encoded_shape[4],), 
                      name='Encoded')

y = encoded_input

y = Flatten(name='Flatten')(y)
y = Dense(1024, activation='selu', name='SELU_1')(y)
y = Dense(64, activation='selu', name='SELU_2')(y)
y = Dense(2, activation='softmax', name='Prediction')(y)

CAE_pred = y

CAE_classifier = Model(encoded_input, CAE_pred, name='CAE_classifier')
CAE_classifier.summary()
# Out:
# Model: "CAE_classifier"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# Encoded (InputLayer)         [(None, 15, 20, 2, 10)]   0
# _________________________________________________________________
# Flatten (Flatten)            (None, 6000)              0
# _________________________________________________________________
# SELU_1 (Dense)               (None, 1024)              6145024
# _________________________________________________________________
# SELU_2 (Dense)               (None, 64)                65600
# _________________________________________________________________
# Prediction (Dense)           (None, 2)                 130
# =================================================================
# Total params: 6,210,754
# Trainable params: 6,210,754
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# #### Building CAE Autoencoder

# %%
CAE_autoencoder = Model(inputs=input_img, 
                         outputs=[CAE_decoder(CAE_encoder(input_img)), 
                                  CAE_classifier(CAE_encoder(input_img))],
                   name='CAE_autoencoder')
CAE_autoencoder.summary()
# Out:
# Model: "CAE_autoencoder"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# Input (InputLayer)              [(None, 120, 160, 16 0
# __________________________________________________________________________________________________
# CAE_encoder (Model)             (None, 15, 20, 2, 10 5700        Input[0][0]
#                                                                  Input[0][0]
# __________________________________________________________________________________________________
# CAE_decoder (Model)             (None, 120, 160, 16, 8401        CAE_encoder[1][0]
# __________________________________________________________________________________________________
# CAE_classifier (Model)          (None, 2)            6210754     CAE_encoder[2][0]
# ==================================================================================================
# Total params: 6,224,855
# Trainable params: 6,224,855
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %% [markdown]
# #### NoAE Classifier

# %%
noAE_classifier = Model(inputs=input_img, outputs=CAE_classifier(CAE_encoder(input_img)), name='noAE_classifier')
noAE_classifier.summary()
# Out:
# Model: "noAE_classifier"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# Input (InputLayer)           [(None, 120, 160, 16, 1)] 0
# _________________________________________________________________
# CAE_encoder (Model)          (None, 15, 20, 2, 10)     5700
# _________________________________________________________________
# CAE_classifier (Model)       (None, 2)                 6210754
# =================================================================
# Total params: 6,216,454
# Trainable params: 6,216,454
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# #### Building Classifier Branch

# %%
losses = {'CAE_classifier':'categorical_crossentropy'}
metrics= {'CAE_classifier':[ \
                                            'acc',
                                            tf.keras.metrics.Precision(), 
                                            tf.keras.metrics.Recall(),
                                            tf.keras.metrics.FalseNegatives(), 
                                            tf.keras.metrics.FalsePositives()]}
loss_weights={'CAE_classifier':1.0}

initial_learning_rate = 0.1
lr_schedule = tf.keras.optimizers.schedules.ExponentialDecay(\
    initial_learning_rate,
    decay_steps=100000,
    decay_rate=0.90,
    staircase=True)

noAE_classifier.compile(optimizer='adam', 
                         loss=losses,
                         loss_weights=loss_weights,
                         metrics=metrics)

my_callbacks = [
    tf.keras.callbacks.EarlyStopping(patience=10),
    tf.keras.callbacks.ModelCheckpoint(filepath='outputs_AC/noAE_experiment_nodo_AC_0522p.{epoch:02d}-{val_loss:.2f}.h5'),
    tf.keras.callbacks.TensorBoard(log_dir='./logs_AC'),
]

# %%
balancing_weights = class_weight.compute_sample_weight('balanced',train_label)
balancing_weights_test = class_weight.compute_sample_weight('balanced',test_label)

# %%
train_generator = MyDataGenerator(train_list, processed_dir, to_fit=True, 
                                  augment=True, batch_size=32,sample_weight=balancing_weights)
test_generator = MyDataGenerator(test_list, processed_dir, batch_size=32,sample_weight=balancing_weights_test)

# %%
history_noAE_extra=noAE_classifier.fit_generator(generator=train_generator,epochs=50,
                                       validation_data=test_generator,shuffle=True,
                                       callbacks = my_callbacks)
# Out:
# Epoch 1/50
# 24/24 [==============================] - 459s 19s/step - loss: 1.1135 - acc: 0.5651 - precision_1: 0.5651 - recall_1: 0.5651 - false_negatives_1: 334.0000 - false_positives_1: 334.0000 - val_loss: 0.6966 - val_acc: 0.6250 - val_precision_1: 0.6250 - val_recall_1: 0.6250 - val_false_negatives_1: 24.0000 - val_false_positives_1: 24.0000
# Epoch 2/50
# 24/24 [==============================] - 371s 15s/step - loss: 0.6965 - acc: 0.4062 - precision_1: 0.4062 - recall_1: 0.4062 - false_negatives_1: 456.0000 - false_positives_1: 456.0000 - val_loss: 0.6970 - val_acc: 0.6250 - val_precision_1: 0.6250 - val_recall_1: 0.6250 - val_false_negatives_1: 24.0000 - val_false_positives_1: 24.0000
# Epoch 3/50
# 24/24 [==============================] - 360s 15s/step - loss: 0.6932 - acc: 0.5456 - precision_1: 0.5456 - recall_1: 0.5456 - false_negatives_1: 349.0000 - false_positives_1: 349.0000 - val_loss: 0.6832 - val_acc: 0.6406 - val_precision_1: 0.6406 - val_recall_1: 0.6406 - val_false_negatives_1: 23.0000 - val_false_positives_1: 23.0000
# Epoch 4/50
# 24/24 [==============================] - 362s 15s/step - loss: 0.6942 - acc: 0.4128 - precision_1: 0.4128 - recall_1: 0.4128 - false_negatives_1: 451.0000 - false_positives_1: 451.0000 - val_loss: 0.6898 - val_acc: 0.6406 - val_precision_1: 0.6406 - val_recall_1: 0.6406 - val_false_negatives_1: 23.0000 - val_false_positives_1: 23.0000
# Epoch 5/50
# 24/24 [==============================] - 367s 15s/step - loss: 0.6935 - acc: 0.5560 - precision_1: 0.5560 - recall_1: 0.5560 - false_negatives_1: 341.0000 - false_positives_1: 341.0000 - val_loss: 0.6839 - val_acc: 0.3281 - val_precision_1: 0.3281 - val_recall_1: 0.3281 - val_false_negatives_1: 43.0000 - val_false_positives_1: 43.0000
# Epoch 6/50
# 24/24 [==============================] - 357s 15s/step - loss: 0.6939 - acc: 0.4922 - precision_1: 0.4922 - recall_1: 0.4922 - false_negatives_1: 390.0000 - false_positives_1: 390.0000 - val_loss: 0.7083 - val_acc: 0.5938 - val_precision_1: 0.5938 - val_recall_1: 0.5938 - val_false_negatives_1: 26.0000 - val_false_positives_1: 26.0000
# Epoch 7/50
# 24/24 [==============================] - 370s 15s/step - loss: 0.6959 - acc: 0.4349 - precision_1: 0.4349 - recall_1: 0.4349 - false_negatives_1: 434.0000 - false_positives_1: 434.0000 - val_loss: 0.6808 - val_acc: 0.6562 - val_precision_1: 0.6562 - val_recall_1: 0.6562 - val_false_negatives_1: 22.0000 - val_false_positives_1: 22.0000
# Epoch 8/50
# 24/24 [==============================] - 362s 15s/step - loss: 0.6955 - acc: 0.6367 - precision_1: 0.6367 - recall_1: 0.6367 - false_negatives_1: 279.0000 - false_positives_1: 279.0000 - val_loss: 0.7051 - val_acc: 0.5781 - val_precision_1: 0.5781 - val_recall_1: 0.5781 - val_false_negatives_1: 27.0000 - val_false_positives_1: 27.0000
# Epoch 9/50
# 24/24 [==============================] - 357s 15s/step - loss: 0.6960 - acc: 0.4648 - precision_1: 0.4648 - recall_1: 0.4648 - false_negatives_1: 411.0000 - false_positives_1: 411.0000 - val_loss: 0.6813 - val_acc: 0.5469 - val_precision_1: 0.5469 - val_recall_1: 0.5469 - val_false_negatives_1: 29.0000 - val_false_positives_1: 29.0000
# Epoch 10/50
# 24/24 [==============================] - 360s 15s/step - loss: 0.6947 - acc: 0.4115 - precision_1: 0.4115 - recall_1: 0.4115 - false_negatives_1: 452.0000 - false_positives_1: 452.0000 - val_loss: 0.6869 - val_acc: 0.6406 - val_precision_1: 0.6406 - val_recall_1: 0.6406 - val_false_negatives_1: 23.0000 - val_false_positives_1: 23.0000
# Epoch 11/50
# 24/24 [==============================] - 365s 15s/step - loss: 0.6912 - acc: 0.5951 - precision_1: 0.5951 - recall_1: 0.5951 - false_negatives_1: 311.0000 - false_positives_1: 311.0000 - val_loss: 0.6767 - val_acc: 0.6406 - val_precision_1: 0.6406 - val_recall_1: 0.6406 - val_false_negatives_1: 23.0000 - val_false_positives_1: 23.0000
# Epoch 12/50
# 24/24 [==============================] - 365s 15s/step - loss: 0.6972 - acc: 0.4570 - precision_1: 0.4570 - recall_1: 0.4570 - false_negatives_1: 417.0000 - false_positives_1: 417.0000 - val_loss: 0.6609 - val_acc: 0.6875 - val_precision_1: 0.6875 - val_recall_1: 0.6875 - val_false_negatives_1: 20.0000 - val_false_positives_1: 20.0000
# Epoch 13/50
# 24/24 [==============================] - 376s 16s/step - loss: 0.6922 - acc: 0.6341 - precision_1: 0.6341 - recall_1: 0.6341 - false_negatives_1: 281.0000 - false_positives_1: 281.0000 - val_loss: 0.6995 - val_acc: 0.5781 - val_precision_1: 0.5781 - val_recall_1: 0.5781 - val_false_negatives_1: 27.0000 - val_false_positives_1: 27.0000
# Epoch 14/50
# 24/24 [==============================] - 361s 15s/step - loss: 0.6913 - acc: 0.4609 - precision_1: 0.4609 - recall_1: 0.4609 - false_negatives_1: 414.0000 - false_positives_1: 414.0000 - val_loss: 0.6760 - val_acc: 0.5938 - val_precision_1: 0.5938 - val_recall_1: 0.5938 - val_false_negatives_1: 26.0000 - val_false_positives_1: 26.0000
# Epoch 15/50
# 24/24 [==============================] - 363s 15s/step - loss: 0.7149 - acc: 0.4857 - precision_1: 0.4857 - recall_1: 0.4857 - false_negatives_1: 395.0000 - false_positives_1: 395.0000 - val_loss: 0.6945 - val_acc: 0.3750 - val_precision_1: 0.3750 - val_recall_1: 0.3750 - val_false_negatives_1: 40.0000 - val_false_positives_1: 40.0000
# Epoch 16/50
# 24/24 [==============================] - 362s 15s/step - loss: 0.6950 - acc: 0.4505 - precision_1: 0.4505 - recall_1: 0.4505 - false_negatives_1: 422.0000 - false_positives_1: 422.0000 - val_loss: 0.6907 - val_acc: 0.3594 - val_precision_1: 0.3594 - val_recall_1: 0.3594 - val_false_negatives_1: 41.0000 - val_false_positives_1: 41.0000
# Epoch 17/50
# 24/24 [==============================] - 370s 15s/step - loss: 0.6938 - acc: 0.5729 - precision_1: 0.5729 - recall_1: 0.5729 - false_negatives_1: 328.0000 - false_positives_1: 328.0000 - val_loss: 0.6951 - val_acc: 0.3750 - val_precision_1: 0.3750 - val_recall_1: 0.3750 - val_false_negatives_1: 40.0000 - val_false_positives_1: 40.0000
# Epoch 18/50
# 24/24 [==============================] - 368s 15s/step - loss: 0.6957 - acc: 0.4544 - precision_1: 0.4544 - recall_1: 0.4544 - false_negatives_1: 419.0000 - false_positives_1: 419.0000 - val_loss: 0.7117 - val_acc: 0.5938 - val_precision_1: 0.5938 - val_recall_1: 0.5938 - val_false_negatives_1: 26.0000 - val_false_positives_1: 26.0000
# Epoch 19/50
# 24/24 [==============================] - 369s 15s/step - loss: 0.6959 - acc: 0.5638 - precision_1: 0.5638 - recall_1: 0.5638 - false_negatives_1: 335.0000 - false_positives_1: 335.0000 - val_loss: 0.6843 - val_acc: 0.3438 - val_precision_1: 0.3438 - val_recall_1: 0.3438 - val_false_negatives_1: 42.0000 - val_false_positives_1: 42.0000
# Epoch 20/50
# 24/24 [==============================] - 365s 15s/step - loss: 0.6930 - acc: 0.3854 - precision_1: 0.3854 - recall_1: 0.3854 - false_negatives_1: 472.0000 - false_positives_1: 472.0000 - val_loss: 0.7003 - val_acc: 0.5781 - val_precision_1: 0.5781 - val_recall_1: 0.5781 - val_false_negatives_1: 27.0000 - val_false_positives_1: 27.0000
# Epoch 21/50
# 24/24 [==============================] - 368s 15s/step - loss: 0.6946 - acc: 0.5130 - precision_1: 0.5130 - recall_1: 0.5130 - false_negatives_1: 374.0000 - false_positives_1: 374.0000 - val_loss: 0.7080 - val_acc: 0.5938 - val_precision_1: 0.5938 - val_recall_1: 0.5938 - val_false_negatives_1: 26.0000 - val_false_positives_1: 26.0000
# Epoch 22/50
# 24/24 [==============================] - 366s 15s/step - loss: 0.6928 - acc: 0.4740 - precision_1: 0.4740 - recall_1: 0.4740 - false_negatives_1: 404.0000 - false_positives_1: 404.0000 - val_loss: 0.7052 - val_acc: 0.5938 - val_precision_1: 0.5938 - val_recall_1: 0.5938 - val_false_negatives_1: 26.0000 - val_false_positives_1: 26.0000

# %%
noAE_classifier.save('CnoAE_classifier.h5')
with open('outputs_AC/trainHistoryDict', 'wb') as file_pi:
        pickle.dump(history_noAE_extra.history, file_pi)
plt.plot(history_noAE_extra.history['loss'])
plt.plot(history_noAE_extra.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# %%
history_noAE_extra.history.keys()
# Out:
# dict_keys(['loss', 'acc', 'precision_1', 'recall_1', 'false_negatives_1', 'false_positives_1', 'val_loss', 'val_acc', 'val_precision_1', 'val_recall_1', 'val_false_negatives_1', 'val_false_positives_1'])

# %%
plt.plot(history_noAE_extra.history['acc'])
plt.plot(history_noAE_extra.history['val_acc'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# %%
#CAE_autoencoder.save('autoencoder_100epochs.h5')

plt.plot(history_noAE_extra.history['precision_1'])
plt.plot(history_noAE_extra.history['val_precision_1'])
plt.title('model precision')
plt.ylabel('precision')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# %%
balancing_weights_val = class_weight.compute_sample_weight('balanced',val_label)
val_generator = MyDataGenerator(val_list, processed_dir,to_fit=False, batch_size=2,sample_weight=balancing_weights_val)
pred = noAE_classifier.predict_generator(val_generator)

# %%
from sklearn.metrics import classification_report,accuracy_score
print("acc: ",accuracy_score(labels_to_categorical(val_label),np.round(pred)))
print(classification_report(labels_to_categorical(val_label),np.round(pred)))
# Out:
# acc:  0.5612244897959183
#               precision    recall  f1-score   support
#
#            0       0.41      0.47      0.44        36
#            1       0.67      0.61      0.64        62
#
#    micro avg       0.56      0.56      0.56        98
#    macro avg       0.54      0.54      0.54        98
# weighted avg       0.57      0.56      0.57        98
#  samples avg       0.56      0.56      0.56        98

# %%
with open('outputs_AC/trainHistoryDict', 'rb') as file_pi:
  test = pickle.load(file_pi)

# %%
test['loss'][-10:]
# Out:
# [0.6921717524528503,
#  0.6913339495658875,
#  0.7149133086204529,
#  0.6949504017829895,
#  0.6937828063964844,
#  0.6956753134727478,
#  0.6959020495414734,
#  0.6929907202720642,
#  0.6946057677268982,
#  0.692771852016449]

# %%
# no autoencoder

# plt.imshow(pred[0][2][:,:,15,0])
# plt.show()
# plt.imshow(pred[0][2][:,:,0,0])

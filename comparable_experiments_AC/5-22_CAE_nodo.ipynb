# %%
# %matplotlib inline 
from matplotlib import pyplot as plt
import numpy as np
import pandas as pd
import pickle
import warnings
import tensorflow as tf
import random
import scipy
import cv2
from tensorflow.keras.utils import Sequence
from tensorflow.keras.utils import to_categorical
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.utils import class_weight
from tensorflow import keras
from tensorflow.keras import backend as K
from tensorflow.keras.callbacks import TensorBoard
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import Dense, Conv3D, MaxPool3D, Dropout, \
        Flatten, Conv3DTranspose, UpSampling3D, Reshape, Input, concatenate
from tensorflow.keras.regularizers import l1_l2
from google.colab import drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
import tensorflow as tf
print('Tensorflow version:', tf.__version__)
# Out:
# Tensorflow version: 2.2.0

# %% [markdown]
# #### Create Train/Test Subset

# %%
# %cd /content/drive/My Drive/AD_MRI

# Load list of records
with open('AD_MRI_Master', 'rb') as f:
    master_list = pickle.load(f)
    
master_sheet = pd.DataFrame.from_dict(master_list, orient='index')
display(master_sheet.head())
print()

# Split: 80% train, 10% validation, 10% test
train_list, val_list, train_label, val_label = \
        train_test_split(master_sheet.subject.values, 
                         master_sheet.diagnosis.values, 
                         random_state = 1337, 
                         test_size=0.10)
        
train_list,test_list,train_label,test_label = \
        train_test_split(train_list, 
                         train_label, 
                         random_state = 0, 
                         test_size=0.10)

# Check for ratios of AD to NC to be consistent among sets
AD_count = 0
for lab in train_label:
    if lab == 'AD':
        AD_count +=1
print('train_ratio AD: ', round(AD_count/len(train_label), 3))

AD_count = 0
for lab in val_label:
    if lab == 'AD':
        AD_count +=1
print('val_ratio AD: ', round(AD_count/len(val_label), 3))

AD_count = 0
for lab in test_label:
    if lab == 'AD':
        AD_count +=1
print('test_ratio AD: ', round(AD_count/len(test_label), 3))

print('\nNumber of records\ntrain:', len(train_list), 
      '\nvalidation:', len(val_list), '\ntest:', len(test_list))
# Out:
# /content/drive/.shortcut-targets-by-id/1oU0ruELKPJf457X2y4uyGIpFkyyxaQyv/AD_MRI
#            subject   age diagnosis            scan_ID
# OAS30001  OAS30001  65.0        CN  OAS30001_MR_d0129
# OAS30002  OAS30002  68.0        CN  OAS30002_MR_d0371
# OAS30003  OAS30003  60.0        CN  OAS30003_MR_d0558
# OAS30004  OAS30004  58.0        CN  OAS30004_MR_d1101
# OAS30005  OAS30005  48.0        CN  OAS30005_MR_d0143
# train_ratio AD:  0.367
# val_ratio AD:  0.367
# test_ratio AD:  0.371
#
# Number of records
# train: 793
# validation: 98
# test: 89

# %% [markdown]
# #### Create Generator

# %%
processed_dir = '/content/drive/My Drive/AD_MRI/PROCESSED/'

# custom data generator.
import random
import scipy
import numpy as np
import cv2
from tensorflow.keras.utils import Sequence
from tensorflow.keras.utils import to_categorical
from sklearn.preprocessing import LabelEncoder
import random

import scipy


def labels_to_categorical(labels):
    le = LabelEncoder()
    le.fit(["CN", "AD"])
    num_lab=to_categorical(le.transform(labels),num_classes=2)
    return num_lab

def my_minmax(z):
    return (z-np.min(z))/(np.max(z)-np.min(z))

# Custom data generator
class MyDataGenerator(Sequence):
    """Generates data for Keras Sequence based data generator. 
    Suitable for building data generator for training and prediction.
    """
    def __init__(self, list_IDs, processed_dir, augment=False, 
                 to_fit=True, batch_size=32, dim=(120, 160, 120, 1),
                 n_classes=2, shuffle=True, ventricles_only=True, 
                 slice_start=50, slice_end=66, sample_weight=None):
        """Initialization
        :param list_IDs: list of all 'label' PATHS
        :param processed_dir: path to directory of processed images
        :param augment
        :param to_fit: True to return X and y, False to return X only
        :param batch_size: batch size at each iteration
        :param dim: tuple indicating image dimension
        :param n_classes: number of output masks
        :param shuffle: True to shuffle label indexes after every epoch
        :param ventricles_only: reduce dimensions to relevant slice
        """
        self.list_IDs = list_IDs
        self.processed_dir = processed_dir
        self.augment = augment
        self.to_fit = to_fit
        self.batch_size = batch_size
        self.dim = dim
        self.n_classes = n_classes
        self.shuffle = shuffle
        self.ventricles_only = ventricles_only
        self.on_epoch_end()
        self.slice_start = slice_start
        self.slice_end = slice_end
        if self.ventricles_only == False:
            self.slice_size = 120
        else:
            self.slice_size = slice_end - slice_start
        self.sample_weight = sample_weight
        # sample_weight needs to be provided if to_fit=True


    def __len__(self):
        """Denotes the number of batches per epoch
        :return: number of batches per epoch
        """
        return int(np.floor(len(self.list_IDs) / self.batch_size))


    def __getitem__(self, index):
        """Generate one batch of data
        :param index: index of the batch
        :return: X and y when fitting. X only when predicting
        """
        # Generate indexes of the batch
        indexes = self.indexes[index 
                               * self.batch_size:(index + 1) 
                               * self.batch_size]

        # Find list of IDs
        list_IDs_temp = [self.list_IDs[k] for k in indexes]
        
        # Generate data
        X, y = self._load_data(list_IDs_temp)
        X = my_minmax(np.float32(X))
        if self.ventricles_only == True:
          X = X[:, :, :, self.slice_start:self.slice_end, :]
          w_temp = np.asarray([self.sample_weight[k] for k in indexes])
        if self.to_fit:
            y = {'CAE_classifier': y, 'CAE_decoder': X}
            w = {'CAE_classifier': w_temp,
                 'CAE_decoder':np.ones(np.shape(X))}
            return X, y, w
        else:
            return X


    def on_epoch_end(self):
        """Updates indexes after each epoch
        """
        self.indexes = np.arange(len(self.list_IDs))
        if self.shuffle == True:
            np.random.shuffle(self.indexes)


    def _load_data(self, list_IDs_temp):
        """Generates data containing batch_size images
        :param list_IDs_temp: list of label ids to load
        :return: batch of images
        """
        # Initialization
        X = np.empty((self.batch_size, *self.dim))
        y = np.empty((self.batch_size, self.n_classes), dtype=int)
        
        # Generate data
        for i, ID in enumerate(list_IDs_temp):
            
            # start X
            with open(self.processed_dir+ID+'_data','rb') as f:
                data = pickle.load(f)
                
            # third dimension = 120, error using self.slice_size for value 16
            x_reshape= np.reshape(data['image'], (120, 160, 120, 1))
            if self.augment == True:
                x_reshape = scipy.ndimage.rotate(x_reshape, 
                                axes=random.choice([(0, 1), (0, 2), (1, 2)]), 
                                angle=random.choice([360-15, 15,0]), 
                                reshape=False)
            X[i,] = x_reshape
            
            #start y
            y[i,] = labels_to_categorical([data['diagnosis']])

        return X, y

# %%
print(labels_to_categorical(["CN"]))

balancing_weights = class_weight.compute_sample_weight('balanced',train_label)
print(balancing_weights[0],train_label[0])
print(balancing_weights[1],train_label[1])


# usage:
processed_dir = '/content/drive/My Drive/AD_MRI/PROCESSED/'
mdg = MyDataGenerator(test_list, processed_dir, to_fit=True, augment=True, 
                      sample_weight=balancing_weights,batch_size=2)

#X, pred, weights = mdg.__getitem__(0) #without .__getitem__ obviously
# Out:
# [[0. 1.]]
# 1.3625429553264605 AD
# 0.7898406374501992 CN

# %% [markdown]
# #### Building CAE Encoder

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import backend as K
from tensorflow.keras.callbacks import TensorBoard
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import Dense, Conv3D, MaxPool3D, Dropout, \
    Flatten, Conv3DTranspose, UpSampling3D, Reshape
from tensorflow.keras.layers import Input

# %%
dropout_rate = 0.0
input_img = Input(shape=(120, 160, 16, 1), name='Input')
print('\ninput shape:', input_img.shape)

x = Conv3D(10, (3, 3, 3), activation='relu', padding='same', 
           name='Convolution_1')(input_img)
x = MaxPool3D((2, 2, 2), name='MaxPooling_1')(x)
x = Dropout(dropout_rate, name='DropOut_1')(x)

x = Conv3D(10, (3, 3, 3), activation='relu', padding='same', 
           name='Convolution_2')(x)
x = MaxPool3D((2, 2, 2), name='MaxPooling_2')(x)
x = Dropout(dropout_rate, name='DropOut_2')(x)

x = Conv3D(10, (3, 3, 3), activation='relu', padding='same', 
           name='Convolution_3')(x)
x = MaxPool3D((2, 2, 2), name='MaxPooling_3')(x)
x = Dropout(dropout_rate, name='DropOut_3')(x)

encoded = x
encoded_shape = K.int_shape(encoded)
print('output shape:', encoded_shape, '\n')

CAE_encoder = Model(input_img, encoded, name='CAE_encoder')
CAE_encoder.summary()
# Out:
# input shape: (None, 120, 160, 16, 1)
# output shape: (None, 15, 20, 2, 10)
#
# Model: "CAE_encoder"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# Input (InputLayer)           [(None, 120, 160, 16, 1)] 0
# _________________________________________________________________
# Convolution_1 (Conv3D)       (None, 120, 160, 16, 10)  280
# _________________________________________________________________
# MaxPooling_1 (MaxPooling3D)  (None, 60, 80, 8, 10)     0
# _________________________________________________________________
# DropOut_1 (Dropout)          (None, 60, 80, 8, 10)     0
# _________________________________________________________________
# Convolution_2 (Conv3D)       (None, 60, 80, 8, 10)     2710
# _________________________________________________________________
# MaxPooling_2 (MaxPooling3D)  (None, 30, 40, 4, 10)     0
# _________________________________________________________________
# DropOut_2 (Dropout)          (None, 30, 40, 4, 10)     0
# _________________________________________________________________
# Convolution_3 (Conv3D)       (None, 30, 40, 4, 10)     2710
# _________________________________________________________________
# MaxPooling_3 (MaxPooling3D)  (None, 15, 20, 2, 10)     0
# _________________________________________________________________
# DropOut_3 (Dropout)          (None, 15, 20, 2, 10)     0
# =================================================================
# Total params: 5,700
# Trainable params: 5,700
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# #### Building CAE Decoder

# %%
encoded_shape
# Out:
# (None, 15, 20, 2, 10)

# %%
encoded_input = Input(shape=(encoded_shape[1],encoded_shape[2], 
                             encoded_shape[3], encoded_shape[4],), 
                      name='Encoded')

print('\ninput shape:', encoded_input.shape)
x = encoded_input

x = Conv3DTranspose(10, (3, 3, 3), activation='relu', padding='same', 
                    name='Convolution_3')(x)
x = UpSampling3D((2, 2, 2), name='UpSampling_3')(x)
x = Dropout(dropout_rate, name='DropOut_3')(x)

x = Conv3DTranspose(10, (3, 3, 3), activation='relu', padding='same', 
                    name='Convolution_2')(x)
x = UpSampling3D((2, 2, 2), name='UpSampling_2')(x)
x = Dropout(dropout_rate, name='DropOut_2')(x)

x = Conv3DTranspose(10, (3, 3, 3), activation='relu', padding='same', 
                    name='Convolution_1')(x)
x = UpSampling3D((2, 2, 2), name='UpSampling_1')(x)
x = Dropout(dropout_rate, name='DropOut_1')(x)

decoded = Conv3DTranspose(1, (3, 3, 3), activation='sigmoid', padding='same', 
                          name='Output')(x)

print('output shape:', K.int_shape(decoded), '\n')

CAE_decoder = Model(encoded_input, decoded, name='CAE_decoder')
CAE_decoder.summary()
# Out:
# input shape: (None, 15, 20, 2, 10)
# output shape: (None, 120, 160, 16, 1)
#
# Model: "CAE_decoder"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# Encoded (InputLayer)         [(None, 15, 20, 2, 10)]   0
# _________________________________________________________________
# Convolution_3 (Conv3DTranspo (None, 15, 20, 2, 10)     2710
# _________________________________________________________________
# UpSampling_3 (UpSampling3D)  (None, 30, 40, 4, 10)     0
# _________________________________________________________________
# DropOut_3 (Dropout)          (None, 30, 40, 4, 10)     0
# _________________________________________________________________
# Convolution_2 (Conv3DTranspo (None, 30, 40, 4, 10)     2710
# _________________________________________________________________
# UpSampling_2 (UpSampling3D)  (None, 60, 80, 8, 10)     0
# _________________________________________________________________
# DropOut_2 (Dropout)          (None, 60, 80, 8, 10)     0
# _________________________________________________________________
# Convolution_1 (Conv3DTranspo (None, 60, 80, 8, 10)     2710
# _________________________________________________________________
# UpSampling_1 (UpSampling3D)  (None, 120, 160, 16, 10)  0
# _________________________________________________________________
# DropOut_1 (Dropout)          (None, 120, 160, 16, 10)  0
# _________________________________________________________________
# Output (Conv3DTranspose)     (None, 120, 160, 16, 1)   271
# =================================================================
# Total params: 8,401
# Trainable params: 8,401
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# #### Building CAE Classifier

# %%
# CAE Classifier

encoded_input = Input(shape=(encoded_shape[1], encoded_shape[2], 
                             encoded_shape[3], encoded_shape[4],), 
                      name='Encoded')

y = encoded_input

y = Flatten(name='Flatten')(y)
y = Dense(1024, activation='selu', name='SELU_1')(y)
y = Dense(64, activation='selu', name='SELU_2')(y)
y = Dense(2, activation='softmax', name='Prediction')(y)

CAE_pred = y

CAE_classifier = Model(encoded_input, CAE_pred, name='CAE_classifier')
CAE_classifier.summary()
# Out:
# Model: "CAE_classifier"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# Encoded (InputLayer)         [(None, 15, 20, 2, 10)]   0
# _________________________________________________________________
# Flatten (Flatten)            (None, 6000)              0
# _________________________________________________________________
# SELU_1 (Dense)               (None, 1024)              6145024
# _________________________________________________________________
# SELU_2 (Dense)               (None, 64)                65600
# _________________________________________________________________
# Prediction (Dense)           (None, 2)                 130
# =================================================================
# Total params: 6,210,754
# Trainable params: 6,210,754
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# #### Building CAE Autoencoder

# %%
CAE_autoencoder = Model(inputs=input_img, 
                         outputs=[CAE_decoder(CAE_encoder(input_img)), 
                                  CAE_classifier(CAE_encoder(input_img))],
                   name='CAE_autoencoder')
CAE_autoencoder.summary()
# Out:
# Model: "CAE_autoencoder"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# Input (InputLayer)              [(None, 120, 160, 16 0
# __________________________________________________________________________________________________
# CAE_encoder (Model)             (None, 15, 20, 2, 10 5700        Input[0][0]
#                                                                  Input[0][0]
# __________________________________________________________________________________________________
# CAE_decoder (Model)             (None, 120, 160, 16, 8401        CAE_encoder[1][0]
# __________________________________________________________________________________________________
# CAE_classifier (Model)          (None, 2)            6210754     CAE_encoder[2][0]
# ==================================================================================================
# Total params: 6,224,855
# Trainable params: 6,224,855
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %% [markdown]
# #### Building Classifier Branch

# %%
losses = {"CAE_decoder":'binary_crossentropy','CAE_classifier':'categorical_crossentropy'}
metrics= {'CAE_decoder':'mae', 'CAE_classifier':[ \
                                            'acc',
                                            tf.keras.metrics.Precision(), 
                                            tf.keras.metrics.Recall(),
                                            tf.keras.metrics.FalseNegatives(), 
                                            tf.keras.metrics.FalsePositives()]}
loss_weights={"CAE_decoder":0.5,'CAE_classifier':0.5}

initial_learning_rate = 0.1
lr_schedule = tf.keras.optimizers.schedules.ExponentialDecay(\
    initial_learning_rate,
    decay_steps=100000,
    decay_rate=0.90,
    staircase=True)

CAE_autoencoder.compile(optimizer='adam', 
                         loss=losses,
                         loss_weights = loss_weights,
                         metrics=metrics)

my_callbacks = [
    tf.keras.callbacks.EarlyStopping(patience=10),
    tf.keras.callbacks.ModelCheckpoint(filepath='outputs_AC/CAE_experiment_nodo_AC_0522p.{epoch:02d}-{val_loss:.2f}.h5'),
    tf.keras.callbacks.TensorBoard(log_dir='./logs_AC'),
]

# %%
balancing_weights = class_weight.compute_sample_weight('balanced',train_label)
balancing_weights_test = class_weight.compute_sample_weight('balanced',test_label)

# %%
train_generator = MyDataGenerator(train_list, processed_dir, to_fit=True, 
                                  augment=True, batch_size=32,sample_weight=balancing_weights)
test_generator = MyDataGenerator(test_list, processed_dir, batch_size=32,sample_weight=balancing_weights_test)

# %%
history_CAE_extra=CAE_autoencoder.fit_generator(generator=train_generator,epochs=50,
                                       validation_data=test_generator,shuffle=True,
                                       callbacks = my_callbacks)
# Out:
# WARNING:tensorflow:From <ipython-input-22-9dfb73cc65b5>:3: Model.fit_generator (from tensorflow.python.keras.engine.training) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use Model.fit, which supports generators.
# Epoch 1/50
# 24/24 [==============================] - 552s 23s/step - loss: 0.9739 - CAE_decoder_loss: 0.6667 - CAE_classifier_loss: 1.2810 - CAE_decoder_mae: 0.1986 - CAE_classifier_acc: 0.5039 - CAE_classifier_precision_1: 0.5039 - CAE_classifier_recall_1: 0.5039 - CAE_classifier_false_negatives_1: 381.0000 - CAE_classifier_false_positives_1: 381.0000 - val_loss: 0.6285 - val_CAE_decoder_loss: 0.5530 - val_CAE_classifier_loss: 0.7040 - val_CAE_decoder_mae: 0.1864 - val_CAE_classifier_acc: 0.6094 - val_CAE_classifier_precision_1: 0.6094 - val_CAE_classifier_recall_1: 0.6094 - val_CAE_classifier_false_negatives_1: 25.0000 - val_CAE_classifier_false_positives_1: 25.0000
# Epoch 2/50
# 24/24 [==============================] - 391s 16s/step - loss: 0.6587 - CAE_decoder_loss: 0.6029 - CAE_classifier_loss: 0.7144 - CAE_decoder_mae: 0.1362 - CAE_classifier_acc: 0.5365 - CAE_classifier_precision_1: 0.5365 - CAE_classifier_recall_1: 0.5365 - CAE_classifier_false_negatives_1: 356.0000 - CAE_classifier_false_positives_1: 356.0000 - val_loss: 0.6084 - val_CAE_decoder_loss: 0.5309 - val_CAE_classifier_loss: 0.6859 - val_CAE_decoder_mae: 0.1686 - val_CAE_classifier_acc: 0.5156 - val_CAE_classifier_precision_1: 0.5156 - val_CAE_classifier_recall_1: 0.5156 - val_CAE_classifier_false_negatives_1: 31.0000 - val_CAE_classifier_false_positives_1: 31.0000
# Epoch 3/50
# 24/24 [==============================] - 363s 15s/step - loss: 0.6369 - CAE_decoder_loss: 0.5903 - CAE_classifier_loss: 0.6835 - CAE_decoder_mae: 0.1233 - CAE_classifier_acc: 0.6016 - CAE_classifier_precision_1: 0.6016 - CAE_classifier_recall_1: 0.6016 - CAE_classifier_false_negatives_1: 306.0000 - CAE_classifier_false_positives_1: 306.0000 - val_loss: 0.5934 - val_CAE_decoder_loss: 0.5031 - val_CAE_classifier_loss: 0.6837 - val_CAE_decoder_mae: 0.1424 - val_CAE_classifier_acc: 0.2812 - val_CAE_classifier_precision_1: 0.2812 - val_CAE_classifier_recall_1: 0.2812 - val_CAE_classifier_false_negatives_1: 46.0000 - val_CAE_classifier_false_positives_1: 46.0000
# Epoch 4/50
# 24/24 [==============================] - 378s 16s/step - loss: 0.6359 - CAE_decoder_loss: 0.5791 - CAE_classifier_loss: 0.6927 - CAE_decoder_mae: 0.0903 - CAE_classifier_acc: 0.5130 - CAE_classifier_precision_1: 0.5130 - CAE_classifier_recall_1: 0.5130 - CAE_classifier_false_negatives_1: 374.0000 - CAE_classifier_false_positives_1: 374.0000 - val_loss: 0.5730 - val_CAE_decoder_loss: 0.4768 - val_CAE_classifier_loss: 0.6691 - val_CAE_decoder_mae: 0.1157 - val_CAE_classifier_acc: 0.6562 - val_CAE_classifier_precision_1: 0.6562 - val_CAE_classifier_recall_1: 0.6562 - val_CAE_classifier_false_negatives_1: 22.0000 - val_CAE_classifier_false_positives_1: 22.0000
# Epoch 5/50
# 24/24 [==============================] - 375s 16s/step - loss: 0.6373 - CAE_decoder_loss: 0.5782 - CAE_classifier_loss: 0.6964 - CAE_decoder_mae: 0.0949 - CAE_classifier_acc: 0.5508 - CAE_classifier_precision_1: 0.5508 - CAE_classifier_recall_1: 0.5508 - CAE_classifier_false_negatives_1: 345.0000 - CAE_classifier_false_positives_1: 345.0000 - val_loss: 0.5764 - val_CAE_decoder_loss: 0.4770 - val_CAE_classifier_loss: 0.6758 - val_CAE_decoder_mae: 0.1188 - val_CAE_classifier_acc: 0.7031 - val_CAE_classifier_precision_1: 0.7031 - val_CAE_classifier_recall_1: 0.7031 - val_CAE_classifier_false_negatives_1: 19.0000 - val_CAE_classifier_false_positives_1: 19.0000
# Epoch 6/50
# 24/24 [==============================] - 369s 15s/step - loss: 0.6187 - CAE_decoder_loss: 0.5708 - CAE_classifier_loss: 0.6666 - CAE_decoder_mae: 0.0876 - CAE_classifier_acc: 0.6107 - CAE_classifier_precision_1: 0.6107 - CAE_classifier_recall_1: 0.6107 - CAE_classifier_false_negatives_1: 299.0000 - CAE_classifier_false_positives_1: 299.0000 - val_loss: 0.5518 - val_CAE_decoder_loss: 0.4648 - val_CAE_classifier_loss: 0.6388 - val_CAE_decoder_mae: 0.1066 - val_CAE_classifier_acc: 0.6406 - val_CAE_classifier_precision_1: 0.6406 - val_CAE_classifier_recall_1: 0.6406 - val_CAE_classifier_false_negatives_1: 23.0000 - val_CAE_classifier_false_positives_1: 23.0000
# Epoch 7/50
# 24/24 [==============================] - 361s 15s/step - loss: 0.6131 - CAE_decoder_loss: 0.5686 - CAE_classifier_loss: 0.6577 - CAE_decoder_mae: 0.0833 - CAE_classifier_acc: 0.6120 - CAE_classifier_precision_1: 0.6120 - CAE_classifier_recall_1: 0.6120 - CAE_classifier_false_negatives_1: 298.0000 - CAE_classifier_false_positives_1: 298.0000 - val_loss: 0.5510 - val_CAE_decoder_loss: 0.4818 - val_CAE_classifier_loss: 0.6202 - val_CAE_decoder_mae: 0.1258 - val_CAE_classifier_acc: 0.6094 - val_CAE_classifier_precision_1: 0.6094 - val_CAE_classifier_recall_1: 0.6094 - val_CAE_classifier_false_negatives_1: 25.0000 - val_CAE_classifier_false_positives_1: 25.0000
# Epoch 8/50
# 24/24 [==============================] - 388s 16s/step - loss: 0.6031 - CAE_decoder_loss: 0.5668 - CAE_classifier_loss: 0.6395 - CAE_decoder_mae: 0.0815 - CAE_classifier_acc: 0.6393 - CAE_classifier_precision_1: 0.6393 - CAE_classifier_recall_1: 0.6393 - CAE_classifier_false_negatives_1: 277.0000 - CAE_classifier_false_positives_1: 277.0000 - val_loss: 0.5763 - val_CAE_decoder_loss: 0.4660 - val_CAE_classifier_loss: 0.6867 - val_CAE_decoder_mae: 0.1097 - val_CAE_classifier_acc: 0.6094 - val_CAE_classifier_precision_1: 0.6094 - val_CAE_classifier_recall_1: 0.6094 - val_CAE_classifier_false_negatives_1: 25.0000 - val_CAE_classifier_false_positives_1: 25.0000
# Epoch 9/50
# 24/24 [==============================] - 365s 15s/step - loss: 0.6048 - CAE_decoder_loss: 0.5688 - CAE_classifier_loss: 0.6407 - CAE_decoder_mae: 0.0771 - CAE_classifier_acc: 0.6120 - CAE_classifier_precision_1: 0.6120 - CAE_classifier_recall_1: 0.6120 - CAE_classifier_false_negatives_1: 298.0000 - CAE_classifier_false_positives_1: 298.0000 - val_loss: 0.5802 - val_CAE_decoder_loss: 0.4793 - val_CAE_classifier_loss: 0.6810 - val_CAE_decoder_mae: 0.1214 - val_CAE_classifier_acc: 0.5156 - val_CAE_classifier_precision_1: 0.5156 - val_CAE_classifier_recall_1: 0.5156 - val_CAE_classifier_false_negatives_1: 31.0000 - val_CAE_classifier_false_positives_1: 31.0000
# Epoch 10/50
# 24/24 [==============================] - 371s 15s/step - loss: 0.5894 - CAE_decoder_loss: 0.5650 - CAE_classifier_loss: 0.6138 - CAE_decoder_mae: 0.0776 - CAE_classifier_acc: 0.6745 - CAE_classifier_precision_1: 0.6745 - CAE_classifier_recall_1: 0.6745 - CAE_classifier_false_negatives_1: 250.0000 - CAE_classifier_false_positives_1: 250.0000 - val_loss: 0.5761 - val_CAE_decoder_loss: 0.4638 - val_CAE_classifier_loss: 0.6884 - val_CAE_decoder_mae: 0.1084 - val_CAE_classifier_acc: 0.4531 - val_CAE_classifier_precision_1: 0.4531 - val_CAE_classifier_recall_1: 0.4531 - val_CAE_classifier_false_negatives_1: 35.0000 - val_CAE_classifier_false_positives_1: 35.0000
# Epoch 11/50
# 24/24 [==============================] - 397s 17s/step - loss: 0.5811 - CAE_decoder_loss: 0.5620 - CAE_classifier_loss: 0.6002 - CAE_decoder_mae: 0.0811 - CAE_classifier_acc: 0.6862 - CAE_classifier_precision_1: 0.6862 - CAE_classifier_recall_1: 0.6862 - CAE_classifier_false_negatives_1: 241.0000 - CAE_classifier_false_positives_1: 241.0000 - val_loss: 0.6032 - val_CAE_decoder_loss: 0.4763 - val_CAE_classifier_loss: 0.7302 - val_CAE_decoder_mae: 0.1199 - val_CAE_classifier_acc: 0.5469 - val_CAE_classifier_precision_1: 0.5469 - val_CAE_classifier_recall_1: 0.5469 - val_CAE_classifier_false_negatives_1: 29.0000 - val_CAE_classifier_false_positives_1: 29.0000
# Epoch 12/50
# 24/24 [==============================] - 369s 15s/step - loss: 0.5684 - CAE_decoder_loss: 0.5671 - CAE_classifier_loss: 0.5696 - CAE_decoder_mae: 0.0776 - CAE_classifier_acc: 0.6940 - CAE_classifier_precision_1: 0.6940 - CAE_classifier_recall_1: 0.6940 - CAE_classifier_false_negatives_1: 235.0000 - CAE_classifier_false_positives_1: 235.0000 - val_loss: 0.5273 - val_CAE_decoder_loss: 0.4663 - val_CAE_classifier_loss: 0.5883 - val_CAE_decoder_mae: 0.1059 - val_CAE_classifier_acc: 0.6875 - val_CAE_classifier_precision_1: 0.6875 - val_CAE_classifier_recall_1: 0.6875 - val_CAE_classifier_false_negatives_1: 20.0000 - val_CAE_classifier_false_positives_1: 20.0000
# Epoch 13/50
# 24/24 [==============================] - 362s 15s/step - loss: 0.5644 - CAE_decoder_loss: 0.5593 - CAE_classifier_loss: 0.5695 - CAE_decoder_mae: 0.0733 - CAE_classifier_acc: 0.7122 - CAE_classifier_precision_1: 0.7122 - CAE_classifier_recall_1: 0.7122 - CAE_classifier_false_negatives_1: 221.0000 - CAE_classifier_false_positives_1: 221.0000 - val_loss: 0.5471 - val_CAE_decoder_loss: 0.4683 - val_CAE_classifier_loss: 0.6260 - val_CAE_decoder_mae: 0.1101 - val_CAE_classifier_acc: 0.6250 - val_CAE_classifier_precision_1: 0.6250 - val_CAE_classifier_recall_1: 0.6250 - val_CAE_classifier_false_negatives_1: 24.0000 - val_CAE_classifier_false_positives_1: 24.0000
# Epoch 14/50
# 24/24 [==============================] - 389s 16s/step - loss: 0.5702 - CAE_decoder_loss: 0.5643 - CAE_classifier_loss: 0.5762 - CAE_decoder_mae: 0.0730 - CAE_classifier_acc: 0.7240 - CAE_classifier_precision_1: 0.7240 - CAE_classifier_recall_1: 0.7240 - CAE_classifier_false_negatives_1: 212.0000 - CAE_classifier_false_positives_1: 212.0000 - val_loss: 0.5572 - val_CAE_decoder_loss: 0.4694 - val_CAE_classifier_loss: 0.6451 - val_CAE_decoder_mae: 0.1148 - val_CAE_classifier_acc: 0.6250 - val_CAE_classifier_precision_1: 0.6250 - val_CAE_classifier_recall_1: 0.6250 - val_CAE_classifier_false_negatives_1: 24.0000 - val_CAE_classifier_false_positives_1: 24.0000
# Epoch 15/50
# 24/24 [==============================] - 356s 15s/step - loss: 0.5633 - CAE_decoder_loss: 0.5661 - CAE_classifier_loss: 0.5605 - CAE_decoder_mae: 0.0759 - CAE_classifier_acc: 0.7057 - CAE_classifier_precision_1: 0.7057 - CAE_classifier_recall_1: 0.7057 - CAE_classifier_false_negatives_1: 226.0000 - CAE_classifier_false_positives_1: 226.0000 - val_loss: 0.5553 - val_CAE_decoder_loss: 0.4910 - val_CAE_classifier_loss: 0.6196 - val_CAE_decoder_mae: 0.1319 - val_CAE_classifier_acc: 0.6250 - val_CAE_classifier_precision_1: 0.6250 - val_CAE_classifier_recall_1: 0.6250 - val_CAE_classifier_false_negatives_1: 24.0000 - val_CAE_classifier_false_positives_1: 24.0000
# Epoch 16/50
# 24/24 [==============================] - 364s 15s/step - loss: 0.5569 - CAE_decoder_loss: 0.5642 - CAE_classifier_loss: 0.5496 - CAE_decoder_mae: 0.0746 - CAE_classifier_acc: 0.7370 - CAE_classifier_precision_1: 0.7370 - CAE_classifier_recall_1: 0.7370 - CAE_classifier_false_negatives_1: 202.0000 - CAE_classifier_false_positives_1: 202.0000 - val_loss: 0.5841 - val_CAE_decoder_loss: 0.4781 - val_CAE_classifier_loss: 0.6902 - val_CAE_decoder_mae: 0.1177 - val_CAE_classifier_acc: 0.6406 - val_CAE_classifier_precision_1: 0.6406 - val_CAE_classifier_recall_1: 0.6406 - val_CAE_classifier_false_negatives_1: 23.0000 - val_CAE_classifier_false_positives_1: 23.0000
# Epoch 17/50
# 24/24 [==============================] - 367s 15s/step - loss: 0.5439 - CAE_decoder_loss: 0.5565 - CAE_classifier_loss: 0.5314 - CAE_decoder_mae: 0.0741 - CAE_classifier_acc: 0.7500 - CAE_classifier_precision_1: 0.7500 - CAE_classifier_recall_1: 0.7500 - CAE_classifier_false_negatives_1: 192.0000 - CAE_classifier_false_positives_1: 192.0000 - val_loss: 0.5648 - val_CAE_decoder_loss: 0.4587 - val_CAE_classifier_loss: 0.6709 - val_CAE_decoder_mae: 0.0980 - val_CAE_classifier_acc: 0.6406 - val_CAE_classifier_precision_1: 0.6406 - val_CAE_classifier_recall_1: 0.6406 - val_CAE_classifier_false_negatives_1: 23.0000 - val_CAE_classifier_false_positives_1: 23.0000
# Epoch 18/50
# 24/24 [==============================] - 368s 15s/step - loss: 0.5519 - CAE_decoder_loss: 0.5636 - CAE_classifier_loss: 0.5402 - CAE_decoder_mae: 0.0821 - CAE_classifier_acc: 0.7435 - CAE_classifier_precision_1: 0.7435 - CAE_classifier_recall_1: 0.7435 - CAE_classifier_false_negatives_1: 197.0000 - CAE_classifier_false_positives_1: 197.0000 - val_loss: 0.5642 - val_CAE_decoder_loss: 0.4719 - val_CAE_classifier_loss: 0.6565 - val_CAE_decoder_mae: 0.1146 - val_CAE_classifier_acc: 0.7031 - val_CAE_classifier_precision_1: 0.7031 - val_CAE_classifier_recall_1: 0.7031 - val_CAE_classifier_false_negatives_1: 19.0000 - val_CAE_classifier_false_positives_1: 19.0000
# Epoch 19/50
# 24/24 [==============================] - 360s 15s/step - loss: 0.5444 - CAE_decoder_loss: 0.5582 - CAE_classifier_loss: 0.5307 - CAE_decoder_mae: 0.0714 - CAE_classifier_acc: 0.7474 - CAE_classifier_precision_1: 0.7474 - CAE_classifier_recall_1: 0.7474 - CAE_classifier_false_negatives_1: 194.0000 - CAE_classifier_false_positives_1: 194.0000 - val_loss: 0.5912 - val_CAE_decoder_loss: 0.4669 - val_CAE_classifier_loss: 0.7155 - val_CAE_decoder_mae: 0.1134 - val_CAE_classifier_acc: 0.5312 - val_CAE_classifier_precision_1: 0.5312 - val_CAE_classifier_recall_1: 0.5312 - val_CAE_classifier_false_negatives_1: 30.0000 - val_CAE_classifier_false_positives_1: 30.0000
# Epoch 20/50
# 24/24 [==============================] - 366s 15s/step - loss: 0.5431 - CAE_decoder_loss: 0.5647 - CAE_classifier_loss: 0.5214 - CAE_decoder_mae: 0.0814 - CAE_classifier_acc: 0.7370 - CAE_classifier_precision_1: 0.7370 - CAE_classifier_recall_1: 0.7370 - CAE_classifier_false_negatives_1: 202.0000 - CAE_classifier_false_positives_1: 202.0000 - val_loss: 0.5046 - val_CAE_decoder_loss: 0.4563 - val_CAE_classifier_loss: 0.5529 - val_CAE_decoder_mae: 0.0993 - val_CAE_classifier_acc: 0.7812 - val_CAE_classifier_precision_1: 0.7812 - val_CAE_classifier_recall_1: 0.7812 - val_CAE_classifier_false_negatives_1: 14.0000 - val_CAE_classifier_false_positives_1: 14.0000
# Epoch 21/50
# 24/24 [==============================] - 360s 15s/step - loss: 0.5546 - CAE_decoder_loss: 0.5604 - CAE_classifier_loss: 0.5489 - CAE_decoder_mae: 0.0741 - CAE_classifier_acc: 0.7396 - CAE_classifier_precision_1: 0.7396 - CAE_classifier_recall_1: 0.7396 - CAE_classifier_false_negatives_1: 200.0000 - CAE_classifier_false_positives_1: 200.0000 - val_loss: 0.5488 - val_CAE_decoder_loss: 0.4652 - val_CAE_classifier_loss: 0.6325 - val_CAE_decoder_mae: 0.1066 - val_CAE_classifier_acc: 0.6875 - val_CAE_classifier_precision_1: 0.6875 - val_CAE_classifier_recall_1: 0.6875 - val_CAE_classifier_false_negatives_1: 20.0000 - val_CAE_classifier_false_positives_1: 20.0000
# Epoch 22/50
# 24/24 [==============================] - 364s 15s/step - loss: 0.5452 - CAE_decoder_loss: 0.5658 - CAE_classifier_loss: 0.5245 - CAE_decoder_mae: 0.0723 - CAE_classifier_acc: 0.7474 - CAE_classifier_precision_1: 0.7474 - CAE_classifier_recall_1: 0.7474 - CAE_classifier_false_negatives_1: 194.0000 - CAE_classifier_false_positives_1: 194.0000 - val_loss: 0.5173 - val_CAE_decoder_loss: 0.4503 - val_CAE_classifier_loss: 0.5842 - val_CAE_decoder_mae: 0.0907 - val_CAE_classifier_acc: 0.7812 - val_CAE_classifier_precision_1: 0.7812 - val_CAE_classifier_recall_1: 0.7812 - val_CAE_classifier_false_negatives_1: 14.0000 - val_CAE_classifier_false_positives_1: 14.0000
# Epoch 23/50
# 24/24 [==============================] - 373s 16s/step - loss: 0.5373 - CAE_decoder_loss: 0.5573 - CAE_classifier_loss: 0.5174 - CAE_decoder_mae: 0.0749 - CAE_classifier_acc: 0.7513 - CAE_classifier_precision_1: 0.7513 - CAE_classifier_recall_1: 0.7513 - CAE_classifier_false_negatives_1: 191.0000 - CAE_classifier_false_positives_1: 191.0000 - val_loss: 0.5452 - val_CAE_decoder_loss: 0.4757 - val_CAE_classifier_loss: 0.6148 - val_CAE_decoder_mae: 0.1171 - val_CAE_classifier_acc: 0.7344 - val_CAE_classifier_precision_1: 0.7344 - val_CAE_classifier_recall_1: 0.7344 - val_CAE_classifier_false_negatives_1: 17.0000 - val_CAE_classifier_false_positives_1: 17.0000
# Epoch 24/50
# 24/24 [==============================] - 363s 15s/step - loss: 0.5323 - CAE_decoder_loss: 0.5627 - CAE_classifier_loss: 0.5020 - CAE_decoder_mae: 0.0746 - CAE_classifier_acc: 0.7630 - CAE_classifier_precision_1: 0.7630 - CAE_classifier_recall_1: 0.7630 - CAE_classifier_false_negatives_1: 182.0000 - CAE_classifier_false_positives_1: 182.0000 - val_loss: 0.4915 - val_CAE_decoder_loss: 0.4551 - val_CAE_classifier_loss: 0.5280 - val_CAE_decoder_mae: 0.0988 - val_CAE_classifier_acc: 0.7656 - val_CAE_classifier_precision_1: 0.7656 - val_CAE_classifier_recall_1: 0.7656 - val_CAE_classifier_false_negatives_1: 15.0000 - val_CAE_classifier_false_positives_1: 15.0000
# Epoch 25/50
# 24/24 [==============================] - 367s 15s/step - loss: 0.5375 - CAE_decoder_loss: 0.5559 - CAE_classifier_loss: 0.5191 - CAE_decoder_mae: 0.0678 - CAE_classifier_acc: 0.7591 - CAE_classifier_precision_1: 0.7591 - CAE_classifier_recall_1: 0.7591 - CAE_classifier_false_negatives_1: 185.0000 - CAE_classifier_false_positives_1: 185.0000 - val_loss: 0.5328 - val_CAE_decoder_loss: 0.4545 - val_CAE_classifier_loss: 0.6111 - val_CAE_decoder_mae: 0.0990 - val_CAE_classifier_acc: 0.7344 - val_CAE_classifier_precision_1: 0.7344 - val_CAE_classifier_recall_1: 0.7344 - val_CAE_classifier_false_negatives_1: 17.0000 - val_CAE_classifier_false_positives_1: 17.0000
# Epoch 26/50
# 24/24 [==============================] - 370s 15s/step - loss: 0.5400 - CAE_decoder_loss: 0.5581 - CAE_classifier_loss: 0.5219 - CAE_decoder_mae: 0.0711 - CAE_classifier_acc: 0.7435 - CAE_classifier_precision_1: 0.7435 - CAE_classifier_recall_1: 0.7435 - CAE_classifier_false_negatives_1: 197.0000 - CAE_classifier_false_positives_1: 197.0000 - val_loss: 0.5402 - val_CAE_decoder_loss: 0.4583 - val_CAE_classifier_loss: 0.6221 - val_CAE_decoder_mae: 0.1041 - val_CAE_classifier_acc: 0.6875 - val_CAE_classifier_precision_1: 0.6875 - val_CAE_classifier_recall_1: 0.6875 - val_CAE_classifier_false_negatives_1: 20.0000 - val_CAE_classifier_false_positives_1: 20.0000
# Epoch 27/50
# 24/24 [==============================] - 365s 15s/step - loss: 0.5376 - CAE_decoder_loss: 0.5586 - CAE_classifier_loss: 0.5166 - CAE_decoder_mae: 0.0723 - CAE_classifier_acc: 0.7708 - CAE_classifier_precision_1: 0.7708 - CAE_classifier_recall_1: 0.7708 - CAE_classifier_false_negatives_1: 176.0000 - CAE_classifier_false_positives_1: 176.0000 - val_loss: 0.5854 - val_CAE_decoder_loss: 0.4569 - val_CAE_classifier_loss: 0.7140 - val_CAE_decoder_mae: 0.0986 - val_CAE_classifier_acc: 0.5781 - val_CAE_classifier_precision_1: 0.5781 - val_CAE_classifier_recall_1: 0.5781 - val_CAE_classifier_false_negatives_1: 27.0000 - val_CAE_classifier_false_positives_1: 27.0000
# Epoch 28/50
# 24/24 [==============================] - 370s 15s/step - loss: 0.5239 - CAE_decoder_loss: 0.5575 - CAE_classifier_loss: 0.4903 - CAE_decoder_mae: 0.0740 - CAE_classifier_acc: 0.7500 - CAE_classifier_precision_1: 0.7500 - CAE_classifier_recall_1: 0.7500 - CAE_classifier_false_negatives_1: 192.0000 - CAE_classifier_false_positives_1: 192.0000 - val_loss: 0.5339 - val_CAE_decoder_loss: 0.4759 - val_CAE_classifier_loss: 0.5919 - val_CAE_decoder_mae: 0.1191 - val_CAE_classifier_acc: 0.7188 - val_CAE_classifier_precision_1: 0.7188 - val_CAE_classifier_recall_1: 0.7188 - val_CAE_classifier_false_negatives_1: 18.0000 - val_CAE_classifier_false_positives_1: 18.0000
# Epoch 29/50
# 24/24 [==============================] - 378s 16s/step - loss: 0.5389 - CAE_decoder_loss: 0.5685 - CAE_classifier_loss: 0.5093 - CAE_decoder_mae: 0.0757 - CAE_classifier_acc: 0.7344 - CAE_classifier_precision_1: 0.7344 - CAE_classifier_recall_1: 0.7344 - CAE_classifier_false_negatives_1: 204.0000 - CAE_classifier_false_positives_1: 204.0000 - val_loss: 0.5102 - val_CAE_decoder_loss: 0.4495 - val_CAE_classifier_loss: 0.5709 - val_CAE_decoder_mae: 0.0920 - val_CAE_classifier_acc: 0.7500 - val_CAE_classifier_precision_1: 0.7500 - val_CAE_classifier_recall_1: 0.7500 - val_CAE_classifier_false_negatives_1: 16.0000 - val_CAE_classifier_false_positives_1: 16.0000
# Epoch 30/50
# 24/24 [==============================] - 375s 16s/step - loss: 0.5331 - CAE_decoder_loss: 0.5593 - CAE_classifier_loss: 0.5068 - CAE_decoder_mae: 0.0770 - CAE_classifier_acc: 0.7487 - CAE_classifier_precision_1: 0.7487 - CAE_classifier_recall_1: 0.7487 - CAE_classifier_false_negatives_1: 193.0000 - CAE_classifier_false_positives_1: 193.0000 - val_loss: 0.5614 - val_CAE_decoder_loss: 0.4613 - val_CAE_classifier_loss: 0.6616 - val_CAE_decoder_mae: 0.1042 - val_CAE_classifier_acc: 0.6562 - val_CAE_classifier_precision_1: 0.6562 - val_CAE_classifier_recall_1: 0.6562 - val_CAE_classifier_false_negatives_1: 22.0000 - val_CAE_classifier_false_positives_1: 22.0000
# Epoch 31/50
# 24/24 [==============================] - 371s 15s/step - loss: 0.5549 - CAE_decoder_loss: 0.5811 - CAE_classifier_loss: 0.5287 - CAE_decoder_mae: 0.0951 - CAE_classifier_acc: 0.7448 - CAE_classifier_precision_1: 0.7448 - CAE_classifier_recall_1: 0.7448 - CAE_classifier_false_negatives_1: 196.0000 - CAE_classifier_false_positives_1: 196.0000 - val_loss: 0.5134 - val_CAE_decoder_loss: 0.4704 - val_CAE_classifier_loss: 0.5565 - val_CAE_decoder_mae: 0.1165 - val_CAE_classifier_acc: 0.7188 - val_CAE_classifier_precision_1: 0.7188 - val_CAE_classifier_recall_1: 0.7188 - val_CAE_classifier_false_negatives_1: 18.0000 - val_CAE_classifier_false_positives_1: 18.0000
# Epoch 32/50
# 24/24 [==============================] - 369s 15s/step - loss: 0.5336 - CAE_decoder_loss: 0.5727 - CAE_classifier_loss: 0.4944 - CAE_decoder_mae: 0.0917 - CAE_classifier_acc: 0.7578 - CAE_classifier_precision_1: 0.7578 - CAE_classifier_recall_1: 0.7578 - CAE_classifier_false_negatives_1: 186.0000 - CAE_classifier_false_positives_1: 186.0000 - val_loss: 0.5253 - val_CAE_decoder_loss: 0.5134 - val_CAE_classifier_loss: 0.5373 - val_CAE_decoder_mae: 0.1530 - val_CAE_classifier_acc: 0.7969 - val_CAE_classifier_precision_1: 0.7969 - val_CAE_classifier_recall_1: 0.7969 - val_CAE_classifier_false_negatives_1: 13.0000 - val_CAE_classifier_false_positives_1: 13.0000
# Epoch 33/50
# 24/24 [==============================] - 379s 16s/step - loss: 0.5228 - CAE_decoder_loss: 0.5636 - CAE_classifier_loss: 0.4820 - CAE_decoder_mae: 0.0760 - CAE_classifier_acc: 0.7682 - CAE_classifier_precision_1: 0.7682 - CAE_classifier_recall_1: 0.7682 - CAE_classifier_false_negatives_1: 178.0000 - CAE_classifier_false_positives_1: 178.0000 - val_loss: 0.4964 - val_CAE_decoder_loss: 0.4612 - val_CAE_classifier_loss: 0.5316 - val_CAE_decoder_mae: 0.1027 - val_CAE_classifier_acc: 0.8125 - val_CAE_classifier_precision_1: 0.8125 - val_CAE_classifier_recall_1: 0.8125 - val_CAE_classifier_false_negatives_1: 12.0000 - val_CAE_classifier_false_positives_1: 12.0000
# Epoch 34/50
# 24/24 [==============================] - 378s 16s/step - loss: 0.5095 - CAE_decoder_loss: 0.5645 - CAE_classifier_loss: 0.4545 - CAE_decoder_mae: 0.0714 - CAE_classifier_acc: 0.7839 - CAE_classifier_precision_1: 0.7839 - CAE_classifier_recall_1: 0.7839 - CAE_classifier_false_negatives_1: 166.0000 - CAE_classifier_false_positives_1: 166.0000 - val_loss: 0.5042 - val_CAE_decoder_loss: 0.4564 - val_CAE_classifier_loss: 0.5520 - val_CAE_decoder_mae: 0.0980 - val_CAE_classifier_acc: 0.7656 - val_CAE_classifier_precision_1: 0.7656 - val_CAE_classifier_recall_1: 0.7656 - val_CAE_classifier_false_negatives_1: 15.0000 - val_CAE_classifier_false_positives_1: 15.0000

# %%
CAE_autoencoder.save('5-22_CAE_nodo.h5')
with open('/trainHistoryDict', 'wb') as file_pi:
        pickle.dump(history_CAE_extra.history, file_pi)
plt.plot(history_CAE_extra.history['loss'])
plt.plot(history_CAE_extra.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# %%
history_CAE_extra.history.keys()
# Out:
# dict_keys(['loss', 'CAE_decoder_loss', 'CAE_classifier_loss', 'CAE_decoder_mae', 'CAE_classifier_acc', 'CAE_classifier_precision_1', 'CAE_classifier_recall_1', 'CAE_classifier_false_negatives_1', 'CAE_classifier_false_positives_1', 'val_loss', 'val_CAE_decoder_loss', 'val_CAE_classifier_loss', 'val_CAE_decoder_mae', 'val_CAE_classifier_acc', 'val_CAE_classifier_precision_1', 'val_CAE_classifier_recall_1', 'val_CAE_classifier_false_negatives_1', 'val_CAE_classifier_false_positives_1'])

# %%
plt.plot(history_CAE_extra.history['CAE_classifier_acc'])
plt.plot(history_CAE_extra.history['val_CAE_classifier_acc'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# %%
plt.plot(history_CAE_extra.history['CAE_classifier_precision_1'])
plt.plot(history_CAE_extra.history['val_CAE_classifier_precision_1'])
plt.title('model precision')
plt.ylabel('precision')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# %%
balancing_weights_val = class_weight.compute_sample_weight('balanced',val_label)
val_generator = MyDataGenerator(val_list, processed_dir,to_fit=False, batch_size=2,sample_weight=balancing_weights_val)
pred = CAE_autoencoder.predict_generator(val_generator)
# Out:
# WARNING:tensorflow:From <ipython-input-30-47d1002de5c7>:3: Model.predict_generator (from tensorflow.python.keras.engine.training) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use Model.predict, which supports generators.

# %%
from sklearn.metrics import classification_report,accuracy_score
print("acc: ",accuracy_score(labels_to_categorical(val_label),np.round(pred[1])))
print(classification_report(labels_to_categorical(val_label),np.round(pred[1])))
# Out:
# acc:  0.4897959183673469
#               precision    recall  f1-score   support
#
#            0       0.31      0.31      0.31        36
#            1       0.60      0.60      0.60        62
#
#    micro avg       0.49      0.49      0.49        98
#    macro avg       0.45      0.45      0.45        98
# weighted avg       0.49      0.49      0.49        98
#  samples avg       0.49      0.49      0.49        98

# %%
# !pwd
# Out:
# /content/drive/.shortcut-targets-by-id/1oU0ruELKPJf457X2y4uyGIpFkyyxaQyv/AD_MRI

# %%
with open('outputs_AC/trainHistoryDict', 'rb') as file_pi:
  test = pickle.load(file_pi)

# %%
test['loss'][-10:]
# Out:
# [0.37622034549713135,
#  0.3739084303379059,
#  0.37147292494773865,
#  0.36897268891334534,
#  0.3683229386806488,
#  0.3676804304122925,
#  0.36653366684913635,
#  0.36529776453971863,
#  0.36314380168914795,
#  0.36187875270843506]

# %%
plt.imshow(pred[0][2][:,:,15,0])
plt.show()
plt.imshow(pred[0][2][:,:,0,0])

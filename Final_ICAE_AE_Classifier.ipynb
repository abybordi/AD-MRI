# %%
# %matplotlib inline 
from matplotlib import pyplot as plt
import numpy as np
import pandas as pd
import pickle
import warnings
import tensorflow as tf
import random
import scipy
import cv2
from tensorflow.keras.utils import Sequence
from tensorflow.keras.utils import to_categorical
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.utils import class_weight
from tensorflow import keras
from tensorflow.keras import backend as K
from tensorflow.keras.callbacks import TensorBoard
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import Dense, Conv3D, MaxPool3D, Dropout, \
        Flatten, Conv3DTranspose, UpSampling3D, Reshape, Input, concatenate
from tensorflow.keras.regularizers import l1_l2
from google.colab import drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
import tensorflow as tf
print('Tensorflow version:', tf.__version__)
# Out:
# Tensorflow version: 2.2.0

# %% [markdown]
# #### Create Train/Test Subset

# %%
# %cd /content/drive/My Drive/AD_MRI

# Load list of records
with open('AD_MRI_Master', 'rb') as f:
    master_list = pickle.load(f)
    
master_sheet = pd.DataFrame.from_dict(master_list, orient='index')
display(master_sheet.head())
print()

# Split: 81% train, 10% validation, 10% test
train_list, val_list, train_label, val_label = \
        train_test_split(master_sheet.subject.values, 
                         master_sheet.diagnosis.values, 
                         random_state = 1337, 
                         test_size=0.10)
        
train_list,test_list,train_label,test_label = \
        train_test_split(train_list, 
                         train_label, 
                         random_state = 0, 
                         test_size=0.10)

# Check for ratios of AD to NC to be consistent among sets
AD_count = 0
for lab in train_label:
    if lab == 'AD':
        AD_count +=1
print('train_ratio AD: ', round(AD_count/len(train_label), 3))

AD_count = 0
for lab in val_label:
    if lab == 'AD':
        AD_count +=1
print('val_ratio AD: ', round(AD_count/len(val_label), 3))

AD_count = 0
for lab in test_label:
    if lab == 'AD':
        AD_count +=1
print('test_ratio AD: ', round(AD_count/len(test_label), 3))

print('\nNumber of records\ntrain:', len(train_list), 
      '\nvalidation:', len(val_list), '\ntest:', len(test_list))
# Out:
# /content/drive/My Drive/AD_MRI
#            subject   age diagnosis            scan_ID
# OAS30001  OAS30001  65.0        CN  OAS30001_MR_d0129
# OAS30002  OAS30002  68.0        CN  OAS30002_MR_d0371
# OAS30003  OAS30003  60.0        CN  OAS30003_MR_d0558
# OAS30004  OAS30004  58.0        CN  OAS30004_MR_d1101
# OAS30005  OAS30005  48.0        CN  OAS30005_MR_d0143
# train_ratio AD:  0.367
# val_ratio AD:  0.367
# test_ratio AD:  0.371
#
# Number of records
# train: 793
# validation: 98
# test: 89

# %% [markdown]
# ### Create Generator

# %%
processed_dir = '/content/drive/My Drive/AD_MRI/PROCESSED/'

# custom data generator.
import random
import scipy
import numpy as np
import cv2
from tensorflow.keras.utils import Sequence
from tensorflow.keras.utils import to_categorical
from sklearn.preprocessing import LabelEncoder
import random

import scipy


def labels_to_categorical(labels):
    le = LabelEncoder()
    le.fit(["CN", "AD"])
    num_lab=to_categorical(le.transform(labels),num_classes=2)
    return num_lab

def my_minmax(z):
    return (z-np.min(z))/(np.max(z)-np.min(z))

# Custom data generator
class MyDataGenerator(Sequence):
    """Generates data for Keras Sequence based data generator. 
    Suitable for building data generator for training and prediction.
    """
    def __init__(self, list_IDs, processed_dir, augment=False, 
                 to_fit=True, batch_size=32, dim=(120, 160, 120, 1),
                 n_classes=2, shuffle=True, ventricles_only=True, 
                 slice_start=50, slice_end=66, sample_weight=None):
        """Initialization
        :param list_IDs: list of all 'label' PATHS
        :param processed_dir: path to directory of processed images
        :param augment
        :param to_fit: True to return X and y, False to return X only
        :param batch_size: batch size at each iteration
        :param dim: tuple indicating image dimension
        :param n_classes: number of output masks
        :param shuffle: True to shuffle label indexes after every epoch
        :param ventricles_only: reduce dimensions to relevant slice
        """
        self.list_IDs = list_IDs
        self.processed_dir = processed_dir
        self.augment = augment
        self.to_fit = to_fit
        self.batch_size = batch_size
        self.dim = dim
        self.n_classes = n_classes
        self.shuffle = shuffle
        self.ventricles_only = ventricles_only
        self.on_epoch_end()
        self.slice_start = slice_start
        self.slice_end = slice_end
        if self.ventricles_only == False:
            self.slice_size = 120
        else:
            self.slice_size = slice_end - slice_start
        self.sample_weight = sample_weight
        # sample_weight needs to be provided if to_fit=True


    def __len__(self):
        """Denotes the number of batches per epoch
        :return: number of batches per epoch
        """
        return int(np.floor(len(self.list_IDs) / self.batch_size))


    def __getitem__(self, index):
        """Generate one batch of data
        :param index: index of the batch
        :return: X and y when fitting. X only when predicting
        """
        # Generate indexes of the batch
        indexes = self.indexes[index 
                               * self.batch_size:(index + 1) 
                               * self.batch_size]

        # Find list of IDs
        list_IDs_temp = [self.list_IDs[k] for k in indexes]
        
        # Generate data
        X, y = self._load_data(list_IDs_temp)
        X = my_minmax(np.float32(X))
        if self.ventricles_only == True:
          X = X[:, :, :, self.slice_start:self.slice_end, :]
          w_temp = np.asarray([self.sample_weight[k] for k in indexes])
        if self.to_fit:
            y = {'ICAE_classifier': y, 'ICAE_decoder': X}
            w = {'ICAE_classifier': w_temp,
                 'ICAE_decoder':np.ones(np.shape(X))}
            return X, y, w
        else:
            return X


    def on_epoch_end(self):
        """Updates indexes after each epoch
        """
        self.indexes = np.arange(len(self.list_IDs))
        if self.shuffle == True:
            np.random.shuffle(self.indexes)


    def _load_data(self, list_IDs_temp):
        """Generates data containing batch_size images
        :param list_IDs_temp: list of label ids to load
        :return: batch of images
        """
        # Initialization
        X = np.empty((self.batch_size, *self.dim))
        y = np.empty((self.batch_size, self.n_classes), dtype=int)
        
        # Generate data
        for i, ID in enumerate(list_IDs_temp):
            
            # start X
            with open(self.processed_dir+ID+'_data','rb') as f:
                data = pickle.load(f)
                
            # third dimension = 120, error using self.slice_size for value 16
            x_reshape= np.reshape(data['image'], (120, 160, 120, 1))
            if self.augment == True:
                x_reshape = scipy.ndimage.rotate(x_reshape, 
                                axes=random.choice([(0, 1), (0, 2), (1, 2)]), 
                                angle=random.choice([360-15, 15,0]), 
                                reshape=False)
            X[i,] = x_reshape
            
            #start y
            y[i,] = labels_to_categorical([data['diagnosis']])

        return X, y

# %%
print(labels_to_categorical(["CN"]))

balancing_weights = class_weight.compute_sample_weight('balanced',train_label)
print(balancing_weights[0],train_label[0])
print(balancing_weights[1],train_label[1])


# usage:
processed_dir = '/content/drive/My Drive/AD_MRI/PROCESSED/'
mdg = MyDataGenerator(test_list, processed_dir, to_fit=True, augment=True, 
                      sample_weight=balancing_weights,batch_size=2)

#X, pred, weights = mdg.__getitem__(0) #without .__getitem__ obviously
# Out:
# [[0. 1.]]
# 1.3625429553264605 AD
# 0.7898406374501992 CN

# %% [markdown]
# ##### --- Start adaptation from Arezoo's notebook ---

# %% [markdown]
# #### Building CAE Encoder

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import backend as K
from tensorflow.keras.callbacks import TensorBoard
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import Dense, Conv3D, MaxPool3D, Dropout, \
    Flatten, Conv3DTranspose, UpSampling3D, Reshape
from tensorflow.keras.layers import Input

# %%
input_img = Input(shape=(120, 160, 16, 1), name='Input')
print('\ninput shape:', input_img.shape)

x = Conv3D(10, (3, 3, 3), activation='relu', padding='same', 
           name='Convolution_1')(input_img)
x = MaxPool3D((2, 2, 2), name='MaxPooling_1')(x)
x = Dropout(0.8, name='DropOut_1')(x)

x = Conv3D(10, (3, 3, 3), activation='relu', padding='same', 
           name='Convolution_2')(x)
x = MaxPool3D((2, 2, 2), name='MaxPooling_2')(x)
x = Dropout(0.8, name='DropOut_2')(x)

x = Conv3D(10, (3, 3, 3), activation='relu', padding='same', 
           name='Convolution_3')(x)
x = MaxPool3D((2, 2, 2), name='MaxPooling_3')(x)
x = Dropout(0.8, name='DropOut_3')(x)

encoded = x
encoded_shape = K.int_shape(encoded)
print('output shape:', encoded_shape, '\n')

CAE_encoder = Model(input_img, encoded, name='CAE_encoder')
CAE_encoder.summary()
# Out:
# input shape: (None, 120, 160, 16, 1)
# output shape: (None, 15, 20, 2, 10)
#
# Model: "CAE_encoder"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# Input (InputLayer)           [(None, 120, 160, 16, 1)] 0
# _________________________________________________________________
# Convolution_1 (Conv3D)       (None, 120, 160, 16, 10)  280
# _________________________________________________________________
# MaxPooling_1 (MaxPooling3D)  (None, 60, 80, 8, 10)     0
# _________________________________________________________________
# DropOut_1 (Dropout)          (None, 60, 80, 8, 10)     0
# _________________________________________________________________
# Convolution_2 (Conv3D)       (None, 60, 80, 8, 10)     2710
# _________________________________________________________________
# MaxPooling_2 (MaxPooling3D)  (None, 30, 40, 4, 10)     0
# _________________________________________________________________
# DropOut_2 (Dropout)          (None, 30, 40, 4, 10)     0
# _________________________________________________________________
# Convolution_3 (Conv3D)       (None, 30, 40, 4, 10)     2710
# _________________________________________________________________
# MaxPooling_3 (MaxPooling3D)  (None, 15, 20, 2, 10)     0
# _________________________________________________________________
# DropOut_3 (Dropout)          (None, 15, 20, 2, 10)     0
# =================================================================
# Total params: 5,700
# Trainable params: 5,700
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# #### Building CAE Decoder

# %%
encoded_shape
# Out:
# (None, 15, 20, 2, 10)

# %%
encoded_input = Input(shape=(encoded_shape[1],encoded_shape[2], 
                             encoded_shape[3], encoded_shape[4],), 
                      name='Encoded')

print('\ninput shape:', encoded_input.shape)
x = encoded_input

x = Conv3DTranspose(10, (3, 3, 3), activation='relu', padding='same', 
                    name='Convolution_3')(x)
x = UpSampling3D((2, 2, 2), name='UpSampling_3')(x)
x = Dropout(0.8, name='DropOut_3')(x)

x = Conv3DTranspose(10, (3, 3, 3), activation='relu', padding='same', 
                    name='Convolution_2')(x)
x = UpSampling3D((2, 2, 2), name='UpSampling_2')(x)
x = Dropout(0.8, name='DropOut_2')(x)

x = Conv3DTranspose(10, (3, 3, 3), activation='relu', padding='same', 
                    name='Convolution_1')(x)
x = UpSampling3D((2, 2, 2), name='UpSampling_1')(x)
x = Dropout(0.8, name='DropOut_1')(x)

decoded = Conv3DTranspose(1, (3, 3, 3), activation='sigmoid', padding='same', 
                          name='Output')(x)

print('output shape:', K.int_shape(decoded), '\n')

CAE_decoder = Model(encoded_input, decoded, name='CAE_decoder')
CAE_decoder.summary()
# Out:
# input shape: (None, 15, 20, 2, 10)
# output shape: (None, 120, 160, 16, 1)
#
# Model: "CAE_decoder"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# Encoded (InputLayer)         [(None, 15, 20, 2, 10)]   0
# _________________________________________________________________
# Convolution_3 (Conv3DTranspo (None, 15, 20, 2, 10)     2710
# _________________________________________________________________
# UpSampling_3 (UpSampling3D)  (None, 30, 40, 4, 10)     0
# _________________________________________________________________
# DropOut_3 (Dropout)          (None, 30, 40, 4, 10)     0
# _________________________________________________________________
# Convolution_2 (Conv3DTranspo (None, 30, 40, 4, 10)     2710
# _________________________________________________________________
# UpSampling_2 (UpSampling3D)  (None, 60, 80, 8, 10)     0
# _________________________________________________________________
# DropOut_2 (Dropout)          (None, 60, 80, 8, 10)     0
# _________________________________________________________________
# Convolution_1 (Conv3DTranspo (None, 60, 80, 8, 10)     2710
# _________________________________________________________________
# UpSampling_1 (UpSampling3D)  (None, 120, 160, 16, 10)  0
# _________________________________________________________________
# DropOut_1 (Dropout)          (None, 120, 160, 16, 10)  0
# _________________________________________________________________
# Output (Conv3DTranspose)     (None, 120, 160, 16, 1)   271
# =================================================================
# Total params: 8,401
# Trainable params: 8,401
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# #### Building CAE Autoencoder

# %%
CAE_autoencoder = Model(input_img, CAE_decoder(CAE_encoder(input_img)), 
                        name='CAE_autoencoder')
CAE_autoencoder.summary()

#load pretrained weights!
CAE_autoencoder.load_weights('my_autoencoder_weights_augmented.h5')
# Out:
# Model: "CAE_autoencoder"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# Input (InputLayer)           [(None, 120, 160, 16, 1)] 0
# _________________________________________________________________
# CAE_encoder (Model)          (None, 15, 20, 2, 10)     5700
# _________________________________________________________________
# CAE_decoder (Model)          (None, 120, 160, 16, 1)   8401
# =================================================================
# Total params: 14,101
# Trainable params: 14,101
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### ICAE Inception Model

# %% [markdown]
# #### Building Encoder

# %%
def inception_module(input, filter_operation):
    """
    filter_operation is a list of inception operations for:
        1x1x1 kernel, 
        1x1x1 then 3x3x3 kernels, 
        1x1x1 then 3x3x3 then 3x3x3 kernels, 
        and 3x3x3 maxpooling then 1x1x1 kernels, 
            respectively.
    """
    
    # According to Nature paper (Oh et. al.), l1 and l2 values of 10e-4 
    # performed the best from experimentation with 0.01, 0.001, 0.0001, 0.00001 
    # values.
    l1_value = 10e-4
    l2_value = 10e-4

    # Branch A
    branch_1x1x1 = Conv3D(filter_operation[0], kernel_size=(1, 1, 1), 
                          activation='relu', padding='same', 
                          kernel_regularizer=l1_l2(l1_value, l2_value), 
                          name='Branch_A_1x1x1')(input)

    # Branch B
    branch_3x3x3_initial = Conv3D(filter_operation[1], kernel_size=(1, 1, 1), 
                                  activation='relu', padding='same', 
                                  kernel_regularizer=l1_l2(l1_value, l2_value), 
                                  name='Branch_B_1x1x1')(input)
    branch_3x3x3 = Conv3D(filter_operation[1], kernel_size=(3, 3, 3), 
                          activation='relu', padding='same', 
                          kernel_regularizer=l1_l2(l1_value, l2_value), 
                          name='Branch_B_3x3x3')(branch_3x3x3_initial)

    # Branch C
    branch_double_3x3x3_initial = Conv3D(filter_operation[2], 
                                         kernel_size=(1, 1, 1), 
                                         activation='relu', padding='same', 
                                         kernel_regularizer=l1_l2(l1_value, 
                                                                  l2_value), 
                                         name='Branch_C_1x1x1')(input)
    branch_double_3x3x3_middle = Conv3D(filter_operation[2], 
                                        kernel_size=(3, 3, 3), 
                                        activation='relu', padding='same', 
                                        kernel_regularizer=l1_l2(l1_value, 
                                                                 l2_value), 
                                        name='Branch_C_1st_3x3x3')\
                                        (branch_double_3x3x3_initial)
    branch_double_3x3x3 = Conv3D(filter_operation[2], kernel_size=(3, 3, 3), 
                                 activation='relu', padding='same', 
                                 kernel_regularizer=l1_l2(l1_value, l2_value), 
                                 name='Branch_C_2nd_3x3x3')\
                                 (branch_double_3x3x3_middle)

    # Branch D
    branch_maxpool_3x3x3_initial = MaxPool3D(pool_size=(3, 3, 3), 
                                             strides=(1, 1, 1), padding='same', 
                                             name='Branch_D_3x3x3_maxpool')\
                                             (input)
    branch_maxpool_3x3x3 = Conv3D(filter_operation[3], kernel_size=(1, 1, 1), 
                                  activation='relu', padding='same', 
                                  kernel_regularizer=l1_l2(l1_value, l2_value), 
                                  name='Branch_D_1x1x1')\
                                  (branch_maxpool_3x3x3_initial)
    
    # Merge branches
    modules = [branch_1x1x1, branch_3x3x3, branch_double_3x3x3, 
               branch_maxpool_3x3x3]
    merged_module = concatenate(modules, name='Inception_Merged')
    
    return merged_module

# %%
input_img = Input(shape= (120, 160, 16, 1), name='Input')
print('\ninput shape:', input_img.shape)

x = Conv3D(10, (3, 3, 3), activation='relu', padding='same', 
           name='Convolution_1')(input_img)
x = MaxPool3D((2, 2, 2), name='MaxPooling_1')(x)
x = Dropout(0.8, name='DropOut_1')(x)

x = Conv3D(10, (3, 3, 3), activation='relu', padding='same', 
           name='Convolution_2')(x)
x = MaxPool3D((2, 2, 2), name='MaxPooling_2')(x)
x = Dropout(0.8, name='DropOut_2')(x)

filter_operations = [10, 10, 10, 10]

x = inception_module(x, filter_operations)
x = MaxPool3D((2, 2, 2), name='Inception_MaxPooling')(x)
x = Dropout(0.8, name='DropOut_3')(x)

encoded = x
encoded_shape = K.int_shape(encoded)
print('output shape:', encoded_shape, '\n')

ICAE_encoder = Model(input_img, encoded, name='ICAE_encoder')
ICAE_encoder.summary(positions=[.35, .64, .71, 1.]) 
# `positions` adjusts print settings to minimize truncation
# Out:
# input shape: (None, 120, 160, 16, 1)
# output shape: (None, 15, 20, 2, 40)
#
# Model: "ICAE_encoder"
# __________________________________________________________________________________________________
# Layer (type)                      Output Shape                Param  Connected to
# ==================================================================================================
# Input (InputLayer)                [(None, 120, 160, 16, 1)]   0
# __________________________________________________________________________________________________
# Convolution_1 (Conv3D)            (None, 120, 160, 16, 10)    280    Input[0][0]
# __________________________________________________________________________________________________
# MaxPooling_1 (MaxPooling3D)       (None, 60, 80, 8, 10)       0      Convolution_1[0][0]
# __________________________________________________________________________________________________
# DropOut_1 (Dropout)               (None, 60, 80, 8, 10)       0      MaxPooling_1[0][0]
# __________________________________________________________________________________________________
# Convolution_2 (Conv3D)            (None, 60, 80, 8, 10)       2710   DropOut_1[0][0]
# __________________________________________________________________________________________________
# MaxPooling_2 (MaxPooling3D)       (None, 30, 40, 4, 10)       0      Convolution_2[0][0]
# __________________________________________________________________________________________________
# DropOut_2 (Dropout)               (None, 30, 40, 4, 10)       0      MaxPooling_2[0][0]
# __________________________________________________________________________________________________
# Branch_C_1x1x1 (Conv3D)           (None, 30, 40, 4, 10)       110    DropOut_2[0][0]
# __________________________________________________________________________________________________
# Branch_B_1x1x1 (Conv3D)           (None, 30, 40, 4, 10)       110    DropOut_2[0][0]
# __________________________________________________________________________________________________
# Branch_C_1st_3x3x3 (Conv3D)       (None, 30, 40, 4, 10)       2710   Branch_C_1x1x1[0][0]
# __________________________________________________________________________________________________
# Branch_D_3x3x3_maxpool (MaxPoolin (None, 30, 40, 4, 10)       0      DropOut_2[0][0]
# __________________________________________________________________________________________________
# Branch_A_1x1x1 (Conv3D)           (None, 30, 40, 4, 10)       110    DropOut_2[0][0]
# __________________________________________________________________________________________________
# Branch_B_3x3x3 (Conv3D)           (None, 30, 40, 4, 10)       2710   Branch_B_1x1x1[0][0]
# __________________________________________________________________________________________________
# Branch_C_2nd_3x3x3 (Conv3D)       (None, 30, 40, 4, 10)       2710   Branch_C_1st_3x3x3[0][0]
# __________________________________________________________________________________________________
# Branch_D_1x1x1 (Conv3D)           (None, 30, 40, 4, 10)       110    Branch_D_3x3x3_maxpool[0][0]
# __________________________________________________________________________________________________
# Inception_Merged (Concatenate)    (None, 30, 40, 4, 40)       0      Branch_A_1x1x1[0][0]
#                                                                      Branch_B_3x3x3[0][0]
#                                                                      Branch_C_2nd_3x3x3[0][0]
#                                                                      Branch_D_1x1x1[0][0]
# __________________________________________________________________________________________________
# Inception_MaxPooling (MaxPooling3 (None, 15, 20, 2, 40)       0      Inception_Merged[0][0]
# __________________________________________________________________________________________________
# DropOut_3 (Dropout)               (None, 15, 20, 2, 40)       0      Inception_MaxPooling[0][0]
# ==================================================================================================
# Total params: 11,560
# Trainable params: 11,560
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %% [markdown]
# #### Building Decoder

# %%
encoded_input= Input(shape=(encoded_shape[1],encoded_shape[2], 
                            encoded_shape[3], encoded_shape[4],), 
                     name='Encoded')
print('\ninput shape:', encoded_input.shape)

combined_dim = sum(filter_operations) 
# `filter_operations` taken from ICAE encoder

x = encoded_input

x = inception_module(x, filter_operations)
x = UpSampling3D((2, 2, 2), name='Inception_Upsampling')(x)
x = Dropout(0.8, name='DropOut_3')(x)

x = Conv3DTranspose(10, (3, 3, 3), activation='relu', padding='same', 
                    name='Convolution_2')(x)
x = UpSampling3D((2, 2, 2), name='Upsampling_2')(x)
x = Dropout(0.8, name='DropOut_2')(x)

x = Conv3DTranspose(10, (3, 3, 3), activation='relu', padding='same', 
                    name='Convolution_1')(x)
x = UpSampling3D((2, 2, 2), name='Upsampling_1')(x)
x = Dropout(0.8, name='DropOut_1')(x)

decoded = Conv3DTranspose(1, (3, 3, 3), activation='sigmoid', padding='same', 
                          name='Output')(x)

print('output shape:', K.int_shape(decoded), '\n')

ICAE_decoder = Model(encoded_input, decoded, name='ICAE_decoder')
ICAE_decoder.summary(positions=[.35, .64, .71, 1.])
# Out:
# input shape: (None, 15, 20, 2, 40)
# output shape: (None, 120, 160, 16, 1)
#
# Model: "ICAE_decoder"
# __________________________________________________________________________________________________
# Layer (type)                      Output Shape                Param  Connected to
# ==================================================================================================
# Encoded (InputLayer)              [(None, 15, 20, 2, 40)]     0
# __________________________________________________________________________________________________
# Branch_C_1x1x1 (Conv3D)           (None, 15, 20, 2, 10)       410    Encoded[0][0]
# __________________________________________________________________________________________________
# Branch_B_1x1x1 (Conv3D)           (None, 15, 20, 2, 10)       410    Encoded[0][0]
# __________________________________________________________________________________________________
# Branch_C_1st_3x3x3 (Conv3D)       (None, 15, 20, 2, 10)       2710   Branch_C_1x1x1[0][0]
# __________________________________________________________________________________________________
# Branch_D_3x3x3_maxpool (MaxPoolin (None, 15, 20, 2, 40)       0      Encoded[0][0]
# __________________________________________________________________________________________________
# Branch_A_1x1x1 (Conv3D)           (None, 15, 20, 2, 10)       410    Encoded[0][0]
# __________________________________________________________________________________________________
# Branch_B_3x3x3 (Conv3D)           (None, 15, 20, 2, 10)       2710   Branch_B_1x1x1[0][0]
# __________________________________________________________________________________________________
# Branch_C_2nd_3x3x3 (Conv3D)       (None, 15, 20, 2, 10)       2710   Branch_C_1st_3x3x3[0][0]
# __________________________________________________________________________________________________
# Branch_D_1x1x1 (Conv3D)           (None, 15, 20, 2, 10)       410    Branch_D_3x3x3_maxpool[0][0]
# __________________________________________________________________________________________________
# Inception_Merged (Concatenate)    (None, 15, 20, 2, 40)       0      Branch_A_1x1x1[0][0]
#                                                                      Branch_B_3x3x3[0][0]
#                                                                      Branch_C_2nd_3x3x3[0][0]
#                                                                      Branch_D_1x1x1[0][0]
# __________________________________________________________________________________________________
# Inception_Upsampling (UpSampling3 (None, 30, 40, 4, 40)       0      Inception_Merged[0][0]
# __________________________________________________________________________________________________
# DropOut_3 (Dropout)               (None, 30, 40, 4, 40)       0      Inception_Upsampling[0][0]
# __________________________________________________________________________________________________
# Convolution_2 (Conv3DTranspose)   (None, 30, 40, 4, 10)       10810  DropOut_3[0][0]
# __________________________________________________________________________________________________
# Upsampling_2 (UpSampling3D)       (None, 60, 80, 8, 10)       0      Convolution_2[0][0]
# __________________________________________________________________________________________________
# DropOut_2 (Dropout)               (None, 60, 80, 8, 10)       0      Upsampling_2[0][0]
# __________________________________________________________________________________________________
# Convolution_1 (Conv3DTranspose)   (None, 60, 80, 8, 10)       2710   DropOut_2[0][0]
# __________________________________________________________________________________________________
# Upsampling_1 (UpSampling3D)       (None, 120, 160, 16, 10)    0      Convolution_1[0][0]
# __________________________________________________________________________________________________
# DropOut_1 (Dropout)               (None, 120, 160, 16, 10)    0      Upsampling_1[0][0]
# __________________________________________________________________________________________________
# Output (Conv3DTranspose)          (None, 120, 160, 16, 1)     271    DropOut_1[0][0]
# ==================================================================================================
# Total params: 23,561
# Trainable params: 23,561
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %% [markdown]
# #### Building Classifier Branch

# %%
# ICAE Classifier

encoded_input = Input(shape=(encoded_shape[1], encoded_shape[2], 
                             encoded_shape[3], encoded_shape[4],), 
                      name='Encoded')

y = encoded_input

y = Flatten(name='Flatten')(y)
y = Dense(1024, activation='selu', name='SELU_1')(y)
y = Dense(64, activation='selu', name='SELU_2')(y)
y = Dense(2, activation='softmax', name='Prediction')(y)

ICAE_pred = y

ICAE_classifier = Model(encoded_input, ICAE_pred, name='ICAE_classifier')
ICAE_classifier.summary()
# Out:
# Model: "ICAE_classifier"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# Encoded (InputLayer)         [(None, 15, 20, 2, 40)]   0
# _________________________________________________________________
# Flatten (Flatten)            (None, 24000)             0
# _________________________________________________________________
# SELU_1 (Dense)               (None, 1024)              24577024
# _________________________________________________________________
# SELU_2 (Dense)               (None, 64)                65600
# _________________________________________________________________
# Prediction (Dense)           (None, 2)                 130
# =================================================================
# Total params: 24,642,754
# Trainable params: 24,642,754
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# # Full ICAE Autoencoder

# %%
ICAE_autoencoder = Model(inputs=input_img, 
                         outputs=[ICAE_decoder(ICAE_encoder(input_img)), 
                                  ICAE_classifier(ICAE_encoder(input_img))],
                   name='ICAE_autoencoder')
ICAE_autoencoder.summary()
# Out:
# Model: "ICAE_autoencoder"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# Input (InputLayer)              [(None, 120, 160, 16 0
# __________________________________________________________________________________________________
# ICAE_encoder (Model)            (None, 15, 20, 2, 40 11560       Input[0][0]
#                                                                  Input[0][0]
# __________________________________________________________________________________________________
# ICAE_decoder (Model)            (None, 120, 160, 16, 23561       ICAE_encoder[1][0]
# __________________________________________________________________________________________________
# ICAE_classifier (Model)         (None, 2)            24642754    ICAE_encoder[2][0]
# ==================================================================================================
# Total params: 24,677,875
# Trainable params: 24,677,875
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
losses = {"ICAE_decoder":'binary_crossentropy','ICAE_classifier':'categorical_crossentropy'}
metrics= {'ICAE_decoder':'mae', 'ICAE_classifier':[ \
                                            'acc',
                                            tf.keras.metrics.Precision(), 
                                            tf.keras.metrics.Recall(),
                                            tf.keras.metrics.FalseNegatives(), 
                                            tf.keras.metrics.FalsePositives()]}
loss_weights={"ICAE_decoder":0.5,'ICAE_classifier':0.5}


ICAE_autoencoder.compile(optimizer='adam', 
                         loss=losses,
                         loss_weights = loss_weights,
                         metrics=metrics)

my_callbacks = [
    tf.keras.callbacks.EarlyStopping(patience=100),
    tf.keras.callbacks.ModelCheckpoint(filepath='epoch_history/long_ICAE_autoencoder.{epoch:02d}-{val_loss:.2f}.h5'),
    tf.keras.callbacks.TensorBoard(log_dir='./logs_long'),
]

# %%
balancing_weights.shape
# Out:
# (793,)

# %%
train_generator = MyDataGenerator(train_list, processed_dir, to_fit=True, 
                                  augment=True, batch_size=32,sample_weight=balancing_weights)
test_generator = MyDataGenerator(test_list, processed_dir, batch_size=32,sample_weight=balancing_weights)

# %%
history_ICAE=ICAE_autoencoder.fit_generator(generator=train_generator,epochs=100,
                                       validation_data=test_generator,shuffle=True,
                                       callbacks = my_callbacks)
# Out:
# Epoch 1/100
# 24/24 [==============================] - 381s 16s/step - loss: 4.3941 - ICAE_decoder_loss: 1.8030 - ICAE_classifier_loss: 4.2744 - ICAE_decoder_mae: 0.2945 - ICAE_classifier_acc: 0.4948 - ICAE_classifier_precision_1: 0.4948 - ICAE_classifier_recall_1: 0.4948 - ICAE_classifier_false_negatives_1: 388.0000 - ICAE_classifier_false_positives_1: 388.0000 - val_loss: 2.1323 - val_ICAE_decoder_loss: 0.6832 - val_ICAE_classifier_loss: 1.0101 - val_ICAE_decoder_mae: 0.2884 - val_ICAE_classifier_acc: 0.3438 - val_ICAE_classifier_precision_1: 0.3438 - val_ICAE_classifier_recall_1: 0.3438 - val_ICAE_classifier_false_negatives_1: 42.0000 - val_ICAE_classifier_false_positives_1: 42.0000
# Epoch 2/100
# 24/24 [==============================] - 448s 19s/step - loss: 1.9103 - ICAE_decoder_loss: 0.6794 - ICAE_classifier_loss: 0.7282 - ICAE_decoder_mae: 0.2107 - ICAE_classifier_acc: 0.5247 - ICAE_classifier_precision_1: 0.5247 - ICAE_classifier_recall_1: 0.5247 - ICAE_classifier_false_negatives_1: 365.0000 - ICAE_classifier_false_positives_1: 365.0000 - val_loss: 1.8867 - val_ICAE_decoder_loss: 0.6638 - val_ICAE_classifier_loss: 0.8689 - val_ICAE_decoder_mae: 0.2719 - val_ICAE_classifier_acc: 0.3906 - val_ICAE_classifier_precision_1: 0.3906 - val_ICAE_classifier_recall_1: 0.3906 - val_ICAE_classifier_false_negatives_1: 39.0000 - val_ICAE_classifier_false_positives_1: 39.0000
# Epoch 3/100
# 24/24 [==============================] - 468s 19s/step - loss: 1.7265 - ICAE_decoder_loss: 0.6631 - ICAE_classifier_loss: 0.7005 - ICAE_decoder_mae: 0.1973 - ICAE_classifier_acc: 0.5143 - ICAE_classifier_precision_1: 0.5143 - ICAE_classifier_recall_1: 0.5143 - ICAE_classifier_false_negatives_1: 373.0000 - ICAE_classifier_false_positives_1: 373.0000 - val_loss: 1.7189 - val_ICAE_decoder_loss: 0.6397 - val_ICAE_classifier_loss: 0.8660 - val_ICAE_decoder_mae: 0.2539 - val_ICAE_classifier_acc: 0.3594 - val_ICAE_classifier_precision_1: 0.3594 - val_ICAE_classifier_recall_1: 0.3594 - val_ICAE_classifier_false_negatives_1: 41.0000 - val_ICAE_classifier_false_positives_1: 41.0000
# Epoch 4/100
# 24/24 [==============================] - 477s 20s/step - loss: 1.5765 - ICAE_decoder_loss: 0.6468 - ICAE_classifier_loss: 0.7032 - ICAE_decoder_mae: 0.1823 - ICAE_classifier_acc: 0.4987 - ICAE_classifier_precision_1: 0.4987 - ICAE_classifier_recall_1: 0.4987 - ICAE_classifier_false_negatives_1: 385.0000 - ICAE_classifier_false_positives_1: 385.0000 - val_loss: 1.5616 - val_ICAE_decoder_loss: 0.6167 - val_ICAE_classifier_loss: 0.8351 - val_ICAE_decoder_mae: 0.2326 - val_ICAE_classifier_acc: 0.3438 - val_ICAE_classifier_precision_1: 0.3438 - val_ICAE_classifier_recall_1: 0.3438 - val_ICAE_classifier_false_negatives_1: 42.0000 - val_ICAE_classifier_false_positives_1: 42.0000
# Epoch 5/100
# 24/24 [==============================] - 505s 21s/step - loss: 1.4675 - ICAE_decoder_loss: 0.6320 - ICAE_classifier_loss: 0.7351 - ICAE_decoder_mae: 0.1678 - ICAE_classifier_acc: 0.4857 - ICAE_classifier_precision_1: 0.4857 - ICAE_classifier_recall_1: 0.4857 - ICAE_classifier_false_negatives_1: 395.0000 - ICAE_classifier_false_positives_1: 395.0000 - val_loss: 1.4151 - val_ICAE_decoder_loss: 0.5912 - val_ICAE_classifier_loss: 0.7750 - val_ICAE_decoder_mae: 0.2138 - val_ICAE_classifier_acc: 0.3438 - val_ICAE_classifier_precision_1: 0.3438 - val_ICAE_classifier_recall_1: 0.3438 - val_ICAE_classifier_false_negatives_1: 42.0000 - val_ICAE_classifier_false_positives_1: 42.0000
# Epoch 6/100
# 24/24 [==============================] - 539s 22s/step - loss: 1.3602 - ICAE_decoder_loss: 0.6211 - ICAE_classifier_loss: 0.7173 - ICAE_decoder_mae: 0.1537 - ICAE_classifier_acc: 0.4883 - ICAE_classifier_precision_1: 0.4883 - ICAE_classifier_recall_1: 0.4883 - ICAE_classifier_false_negatives_1: 393.0000 - ICAE_classifier_false_positives_1: 393.0000 - val_loss: 1.3150 - val_ICAE_decoder_loss: 0.5706 - val_ICAE_classifier_loss: 0.7601 - val_ICAE_decoder_mae: 0.1970 - val_ICAE_classifier_acc: 0.3281 - val_ICAE_classifier_precision_1: 0.3281 - val_ICAE_classifier_recall_1: 0.3281 - val_ICAE_classifier_false_negatives_1: 43.0000 - val_ICAE_classifier_false_positives_1: 43.0000
# Epoch 7/100
# 24/24 [==============================] - 479s 20s/step - loss: 1.2743 - ICAE_decoder_loss: 0.6112 - ICAE_classifier_loss: 0.7037 - ICAE_decoder_mae: 0.1462 - ICAE_classifier_acc: 0.5443 - ICAE_classifier_precision_1: 0.5443 - ICAE_classifier_recall_1: 0.5443 - ICAE_classifier_false_negatives_1: 350.0000 - ICAE_classifier_false_positives_1: 350.0000 - val_loss: 1.2447 - val_ICAE_decoder_loss: 0.5553 - val_ICAE_classifier_loss: 0.7674 - val_ICAE_decoder_mae: 0.1859 - val_ICAE_classifier_acc: 0.3438 - val_ICAE_classifier_precision_1: 0.3438 - val_ICAE_classifier_recall_1: 0.3438 - val_ICAE_classifier_false_negatives_1: 42.0000 - val_ICAE_classifier_false_positives_1: 42.0000
# Epoch 8/100
# 24/24 [==============================] - 487s 20s/step - loss: 1.2120 - ICAE_decoder_loss: 0.6088 - ICAE_classifier_loss: 0.7036 - ICAE_decoder_mae: 0.1397 - ICAE_classifier_acc: 0.5078 - ICAE_classifier_precision_1: 0.5078 - ICAE_classifier_recall_1: 0.5078 - ICAE_classifier_false_negatives_1: 378.0000 - ICAE_classifier_false_positives_1: 378.0000 - val_loss: 1.1790 - val_ICAE_decoder_loss: 0.5435 - val_ICAE_classifier_loss: 0.7594 - val_ICAE_decoder_mae: 0.1783 - val_ICAE_classifier_acc: 0.3125 - val_ICAE_classifier_precision_1: 0.3125 - val_ICAE_classifier_recall_1: 0.3125 - val_ICAE_classifier_false_negatives_1: 44.0000 - val_ICAE_classifier_false_positives_1: 44.0000
# Epoch 9/100
# 24/24 [==============================] - 499s 21s/step - loss: 1.1629 - ICAE_decoder_loss: 0.6102 - ICAE_classifier_loss: 0.7076 - ICAE_decoder_mae: 0.1362 - ICAE_classifier_acc: 0.5234 - ICAE_classifier_precision_1: 0.5234 - ICAE_classifier_recall_1: 0.5234 - ICAE_classifier_false_negatives_1: 366.0000 - ICAE_classifier_false_positives_1: 366.0000 - val_loss: 1.1133 - val_ICAE_decoder_loss: 0.5392 - val_ICAE_classifier_loss: 0.7281 - val_ICAE_decoder_mae: 0.1740 - val_ICAE_classifier_acc: 0.3594 - val_ICAE_classifier_precision_1: 0.3594 - val_ICAE_classifier_recall_1: 0.3594 - val_ICAE_classifier_false_negatives_1: 41.0000 - val_ICAE_classifier_false_positives_1: 41.0000
# Epoch 10/100
# 24/24 [==============================] - 476s 20s/step - loss: 1.1208 - ICAE_decoder_loss: 0.6065 - ICAE_classifier_loss: 0.7166 - ICAE_decoder_mae: 0.1345 - ICAE_classifier_acc: 0.5091 - ICAE_classifier_precision_1: 0.5091 - ICAE_classifier_recall_1: 0.5091 - ICAE_classifier_false_negatives_1: 377.0000 - ICAE_classifier_false_positives_1: 377.0000 - val_loss: 1.0543 - val_ICAE_decoder_loss: 0.5368 - val_ICAE_classifier_loss: 0.6956 - val_ICAE_decoder_mae: 0.1732 - val_ICAE_classifier_acc: 0.4219 - val_ICAE_classifier_precision_1: 0.4219 - val_ICAE_classifier_recall_1: 0.4219 - val_ICAE_classifier_false_negatives_1: 37.0000 - val_ICAE_classifier_false_positives_1: 37.0000
# Epoch 11/100
# 24/24 [==============================] - 507s 21s/step - loss: 1.0702 - ICAE_decoder_loss: 0.6001 - ICAE_classifier_loss: 0.6997 - ICAE_decoder_mae: 0.1373 - ICAE_classifier_acc: 0.5026 - ICAE_classifier_precision_1: 0.5026 - ICAE_classifier_recall_1: 0.5026 - ICAE_classifier_false_negatives_1: 382.0000 - ICAE_classifier_false_positives_1: 382.0000 - val_loss: 1.0139 - val_ICAE_decoder_loss: 0.5332 - val_ICAE_classifier_loss: 0.6911 - val_ICAE_decoder_mae: 0.1712 - val_ICAE_classifier_acc: 0.3125 - val_ICAE_classifier_precision_1: 0.3125 - val_ICAE_classifier_recall_1: 0.3125 - val_ICAE_classifier_false_negatives_1: 44.0000 - val_ICAE_classifier_false_positives_1: 44.0000
# Epoch 12/100
# 24/24 [==============================] - 458s 19s/step - loss: 1.0355 - ICAE_decoder_loss: 0.6018 - ICAE_classifier_loss: 0.6967 - ICAE_decoder_mae: 0.1354 - ICAE_classifier_acc: 0.5078 - ICAE_classifier_precision_1: 0.5078 - ICAE_classifier_recall_1: 0.5078 - ICAE_classifier_false_negatives_1: 378.0000 - ICAE_classifier_false_positives_1: 378.0000 - val_loss: 0.9648 - val_ICAE_decoder_loss: 0.5313 - val_ICAE_classifier_loss: 0.6580 - val_ICAE_decoder_mae: 0.1702 - val_ICAE_classifier_acc: 0.6406 - val_ICAE_classifier_precision_1: 0.6406 - val_ICAE_classifier_recall_1: 0.6406 - val_ICAE_classifier_false_negatives_1: 23.0000 - val_ICAE_classifier_false_positives_1: 23.0000
# Epoch 13/100
# 24/24 [==============================] - 482s 20s/step - loss: 1.0035 - ICAE_decoder_loss: 0.5998 - ICAE_classifier_loss: 0.6938 - ICAE_decoder_mae: 0.1339 - ICAE_classifier_acc: 0.5299 - ICAE_classifier_precision_1: 0.5299 - ICAE_classifier_recall_1: 0.5299 - ICAE_classifier_false_negatives_1: 361.0000 - ICAE_classifier_false_positives_1: 361.0000 - val_loss: 0.9419 - val_ICAE_decoder_loss: 0.5257 - val_ICAE_classifier_loss: 0.6727 - val_ICAE_decoder_mae: 0.1658 - val_ICAE_classifier_acc: 0.6094 - val_ICAE_classifier_precision_1: 0.6094 - val_ICAE_classifier_recall_1: 0.6094 - val_ICAE_classifier_false_negatives_1: 25.0000 - val_ICAE_classifier_false_positives_1: 25.0000
# Epoch 14/100
# 24/24 [==============================] - 517s 22s/step - loss: 0.9808 - ICAE_decoder_loss: 0.5959 - ICAE_classifier_loss: 0.7038 - ICAE_decoder_mae: 0.1283 - ICAE_classifier_acc: 0.4987 - ICAE_classifier_precision_1: 0.4987 - ICAE_classifier_recall_1: 0.4987 - ICAE_classifier_false_negatives_1: 385.0000 - ICAE_classifier_false_positives_1: 385.0000 - val_loss: 0.9792 - val_ICAE_decoder_loss: 0.6558 - val_ICAE_classifier_loss: 0.6655 - val_ICAE_decoder_mae: 0.1870 - val_ICAE_classifier_acc: 0.6719 - val_ICAE_classifier_precision_1: 0.6719 - val_ICAE_classifier_recall_1: 0.6719 - val_ICAE_classifier_false_negatives_1: 21.0000 - val_ICAE_classifier_false_positives_1: 21.0000
# Epoch 15/100
# 21/24 [=========================>....] - ETA: 48s - loss: 0.9608 - ICAE_decoder_loss: 0.5981 - ICAE_classifier_loss: 0.7045 - ICAE_decoder_mae: 0.1255 - ICAE_classifier_acc: 0.4598 - ICAE_classifier_precision_1: 0.4598 - ICAE_classifier_recall_1: 0.4598 - ICAE_classifier_false_negatives_1: 363.0000 - ICAE_classifier_false_positives_1: 363.0000

# %%
losses = {"ICAE_decoder":'binary_crossentropy','ICAE_classifier':'categorical_crossentropy'}
metrics= {'ICAE_decoder':'mae', 'ICAE_classifier':[ \
                                            tf.keras.metrics.Accuracy(),
                                            tf.keras.metrics.Precision(), 
                                            tf.keras.metrics.Recall(),
                                            tf.keras.metrics.FalseNegatives(), 
                                            tf.keras.metrics.FalsePositives()]}
loss_weights={"ICAE_decoder":0.5,'ICAE_classifier':0.5}


ICAE_autoencoder.compile(optimizer='adam', 
                         loss=losses,
                         loss_weights = loss_weights,
                         metrics=metrics)

my_callbacks = [
    tf.keras.callbacks.EarlyStopping(patience=100),
    tf.keras.callbacks.ModelCheckpoint(filepath='epoch_history/long_ICAE_autoencoder_aug.{epoch:02d}-{val_loss:.2f}.h5'),
    tf.keras.callbacks.TensorBoard(log_dir='./long_aug_logs'),
]

# %%
train_generator = MyDataGenerator(train_list, processed_dir, to_fit=True, 
                                  augment=True, batch_size=32,sample_weight=balancing_weights)
test_generator = MyDataGenerator(test_list, processed_dir, batch_size=32,sample_weight=balancing_weights)

# %%
history_ICAE_aug=ICAE_autoencoder.fit_generator(generator=train_generator,epochs=100,
                                       validation_data=test_generator,shuffle=True,
                                       callbacks = my_callbacks)
